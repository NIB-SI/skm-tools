# %%
import os
ALREADY_RUN_CY_CONNECT = False
if os.getenv("COLAB_RELEASE_TAG"):
   print("Running in Colab")
   COLAB = True
else:
   print("NOT in Colab")
   COLAB = False
# Out:
# Running in Colab

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PSS-paths-for-case-1-(ABA/RD29)" data-toc-modified-id="PSS-paths-for-case-1-(ABA/RD29)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PSS paths for case 1 (ABA/RD29)</a></span><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Description</a></span></li></ul></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Library-import" data-toc-modified-id="Library-import-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Library import</a></span></li><li><span><a href="#Hany-functions" data-toc-modified-id="Hany-functions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Hany functions</a></span></li><li><span><a href="#Path-and-Parameter-definitions" data-toc-modified-id="Path-and-Parameter-definitions-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Path and Parameter definitions</a></span></li><li><span><a href="#Load-PSS" data-toc-modified-id="Load-PSS-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Load PSS</a></span></li><li><span><a href="#Filtering" data-toc-modified-id="Filtering-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Filtering</a></span></li></ul></li><li><span><a href="#Path-extraction" data-toc-modified-id="Path-extraction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Path extraction</a></span><ul class="toc-item"><li><span><a href="#ABA--->-RD29" data-toc-modified-id="ABA--->-RD29-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>ABA --&gt; RD29</a></span></li><li><span><a href="#JA--->-RD29" data-toc-modified-id="JA--->-RD29-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>JA --&gt; RD29</a></span></li><li><span><a href="#SA--->-RD29" data-toc-modified-id="SA--->-RD29-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SA --&gt; RD29</a></span></li></ul></li><li><span><a href="#Cytoscape" data-toc-modified-id="Cytoscape-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cytoscape</a></span><ul class="toc-item"><li><span><a href="#Load-the-PSS-network-into-Cytoscape" data-toc-modified-id="Load-the-PSS-network-into-Cytoscape-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Load the PSS network into Cytoscape</a></span></li><li><span><a href="#Extract-subnetworks-in-Cytoscape" data-toc-modified-id="Extract-subnetworks-in-Cytoscape-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Extract subnetworks in Cytoscape</a></span><ul class="toc-item"><li><span><a href="#The-edge-induced-network" data-toc-modified-id="The-edge-induced-network-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>The edge induced network</a></span></li><li><span><a href="#The-node-induced-network" data-toc-modified-id="The-node-induced-network-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>The node induced network</a></span></li><li><span><a href="#Neighbours" data-toc-modified-id="Neighbours-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Neighbours</a></span></li><li><span><a href="#Filtered-neighbours" data-toc-modified-id="Filtered-neighbours-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Filtered neighbours</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # PSS paths for case 1 (ABA/RD29)
#
# ## Description
#
# This notebook contains the analysis of PSS for the first use case of the SKM publication.
#
# Experimental results showed that ABA is able to induce expression of RD29 in both arabidopsis and potato plants. However, the addition of SA or JA showed attenuation of this induction (while alone they had no effect).
#
# Here, we interogate the PSS network of stress signalling to identify potential points of intersection between the ABA activation of RD29 and SA or JA pathways, to identify potential mechanistic explainations of the observed experimental results.

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries
#
# The non-default libries are networkX (https://networkx.org/) and py4cytoscape (https://py4cytoscape.readthedocs.io/, only necessary if you wish to view the results in Cytoscape).
#
# You will also need the skm-tools package provided in the same repository as this notebook.

# %%
import sys
from pathlib import Path
from datetime import datetime
from IPython.display import Markdown, display

import networkx as nx

# %% [markdown]
# The following allows us to import functions from the skm-tools package.
# On Colab, it fetches the git repository, locally, we assume the folder structure as in the repository.
#
# Note the relative path to the folder containing the
# "skm-tools" directory.

# %%
if COLAB:
  from IPython.display import clear_output
  u = input('username ')
  key = input('passcode ')
  clear_output()
  # !git clone https://$u:$key@github.com/NIB-SI/skm-tools.git
  sys.path.append("./skm-tools")

else:
  sys.path.append("../skm-tools")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-95abab72b2a9> in <cell line: 1>()
#       1 if COLAB:
#       2   from IPython.display import clear_output
# ----> 3   u = input('username ')
#       4   key = input('passcode ')
#       5   clear_output()
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from skm_tools import load_networks, pss_utils

# %% [markdown]
# ## Hany functions

# %%
# allows viewing colour codes within a notebook
def swatches(colors, sep=' ', width=6):
    display(Markdown(sep.join(
        f'<span style="font-family: monospace">{color} <span style="color: {color}">{chr(9608)*width}</span></span>'
        for color in colors
    )))

# %%
today = datetime.today().strftime('%Y.%m.%d'); today
# Out:
# '2023.08.11'

# %% [markdown]
# ## Path and parameter definitions

# %%
base_dir = Path("./skm-tools")
data_dir = base_dir / "data"
output_dir = base_dir / "output"

# %%
# data_dir.mkdir()
if not output_dir.exists():
  output_dir.mkdir()

if not data_dir.exists():
  data_dir.mkdir()

# %%
pss_edge_path = data_dir / f"rxn-edges-public-{today}.tsv"
pss_node_path = data_dir / f"rxn-nodes-public-{today}.tsv"

# %% [markdown]
# ## Load PSS

# %%
g = load_networks.pss_to_networkx(
    edge_path=pss_edge_path,
    node_path=pss_node_path
)

print(f"\nNumber of nodes: {g.number_of_nodes()}\nNumber of edges: {g.number_of_edges()}")
# Out:
# Attempting to download the edge list to skm-tools/data/rxn-edges-public-2023.08.11.tsv. Success.
# Attempting to download the node annotations to skm-tools/data/rxn-nodes-public-2023.08.11.tsv. Success.
#
# Number of nodes: 528
# Number of edges: 893

# %% [markdown]
# We can draw the networks using networkX functions:

# %%
nx.draw_networkx(
    g,
    labels = {n:d['display_label'] for n, d in g.nodes(data=True)}
)

# %% [markdown]
# NetworkX is not primarily a graph drawing package, instead of restyling this image we will use Cytoscape, as demonstrated in the last section.

# %% [markdown]
# ## Filtering

# %% [markdown]
# PSS contains some processes that are not relevent to this study, such as viral proteins (Foreign nodes) and FunctionalClusters that do not include either arabidopsis or potato functional homologues.
#
# Here, we remove them from the network.

# %%
# see the types of nodes present
set([data['node_type'] for n, data in g.nodes(data=True)])
# Out:
# {'Complex',
#  'ForeignAbiotic',
#  'ForeignCoding',
#  'ForeignEntity',
#  'ForeignNonCoding',
#  'Metabolite',
#  'PlantAbstract',
#  'PlantCoding',
#  'PlantNonCoding',
#  'Process'}

# %%
# Define the types we want to keep
keep_types = [
    'Complex',
    'Condition',
    'ForeignAbiotic',
    'Metabolite',
    'PlantAbstract',
    'PlantCoding',
    'PlantNonCoding',
    'Process'
]

# %%
# Define the species we want to keep
species = ['ath', 'stu']

# %%
# Use the util function to filter PSS
removed = pss_utils.filter_pss_nodes(g, node_types=keep_types, species=species, remove_isolates=True)
# Out:
# Removed 77 nodes from network.

# %% [markdown]
# You can inspect the `removed` object to see the nodes that were removed,
# and the reasons for the removal.
#
# New network size:

# %%
print(f"\nNumber of nodes: {g.number_of_nodes()}\nNumber of edges: {g.number_of_edges()}")
# Out:
# Number of nodes: 451
# Number of edges: 707

# %% [markdown]
# # Path extraction
#
# First we identify the nodes of interest.

# %%
ABA = [x for x,y in g.nodes(data=True) if y['name']=="ABA"][0]
RD29 = [x for x,y in g.nodes(data=True) if y['short_name']=="RD29"][0]
JA = [x for x,y in g.nodes(data=True) if y['name']=="JA"][0]
SA = [x for x,y in g.nodes(data=True) if y['name']=="SA"][0];

print(ABA)
print(RD29)
print(JA)
print(SA)
# Out:
# ABA
# RD29[AT5G52300,AT5G52310,SOTUB03G014340.1.1]
# JA
# SA

# %% [markdown]
# We use the networkx function `all_shortest_paths` to find paths between our nodes of interest:
#
# * From ABA to RD29
# * From JA to RD29
# * From SA to RD29

# %% [markdown]
# ## ABA --> RD29

# %%
ABA_RD29_paths = [p for p in nx.all_shortest_paths(g, source=ABA, target=RD29)]
ABA_RD29_paths
# Out:
# [['ABA',
#   'PYL[AT1G01360,AT2G40330]',
#   'PP2C[AT3G11410,SOLTU.DM.03G012480.1,SOLTU.DM.06G031720.1,SOTUB03G021270.1.1,SOTUB06G032210.1.1]',
#   'SNRK2[AT1G10940,AT1G78290,AT4G33950,SOTUB02G032470.1.1]',
#   'AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000]',
#   'RD29[AT5G52300,AT5G52310,SOTUB03G014340.1.1]']]

# %% [markdown]
# ## JA --> RD29

# %%
JA_paths = [p for p in nx.all_shortest_paths(g, source=JA, target=RD29)]
JA_paths
# Out:
# [['JA',
#   'JA-Ile',
#   'COI1|JA-Ile|SCF',
#   'JAZ[AT1G17380,AT1G19180,AT1G30135,AT1G48500,AT1G70700,AT1G72450,AT1G74950,AT2G34600,AT3G17860,AT3G43440,AT5G13220,AT5G20900]',
#   'MYC2[AT1G32640]',
#   'PYL[AT1G01360,AT2G40330]',
#   'PP2C[AT3G11410,SOLTU.DM.03G012480.1,SOLTU.DM.06G031720.1,SOTUB03G021270.1.1,SOTUB06G032210.1.1]',
#   'SNRK2[AT1G10940,AT1G78290,AT4G33950,SOTUB02G032470.1.1]',
#   'AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000]',
#   'RD29[AT5G52300,AT5G52310,SOTUB03G014340.1.1]']]

# %% [markdown]
# ## SA --> RD29

# %%
SA_paths = [p for p in nx.all_shortest_paths(g, source=SA, target=RD29)]
SA_paths
# Out:
# [['SA',
#   'NPR1[AT1G64280]',
#   'MYC2[AT1G32640]',
#   'PYL[AT1G01360,AT2G40330]',
#   'PP2C[AT3G11410,SOLTU.DM.03G012480.1,SOLTU.DM.06G031720.1,SOTUB03G021270.1.1,SOTUB06G032210.1.1]',
#   'SNRK2[AT1G10940,AT1G78290,AT4G33950,SOTUB02G032470.1.1]',
#   'AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000]',
#   'RD29[AT5G52300,AT5G52310,SOTUB03G014340.1.1]']]

# %% [markdown]
# # Cytoscape

# %% [markdown]
# Load the required library, and make sure you can connect to Cytoscape.
#
# More py4cytoscape documentation is here: https://py4cytoscape.readthedocs.io/

# %%
# !pip install git+https://github.com/cytoscape/py4cytoscape.git@1.9.0
# Out:
# Collecting git+https://github.com/cytoscape/py4cytoscape.git@1.9.0
#   Cloning https://github.com/cytoscape/py4cytoscape.git (to revision 1.9.0) to /tmp/pip-req-build-3od0hw30
#   Running command git clone --filter=blob:none --quiet https://github.com/cytoscape/py4cytoscape.git /tmp/pip-req-build-3od0hw30
#   Running command git checkout -b 1.9.0 --track origin/1.9.0
#   Switched to a new branch '1.9.0'
#   Branch '1.9.0' set up to track remote branch '1.9.0' from 'origin'.
#   Resolved https://github.com/cytoscape/py4cytoscape.git to commit a786010f539969d62763effdc354aa49947d8fde
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from py4cytoscape==1.9.0) (1.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from py4cytoscape==1.9.0) (3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from py4cytoscape==1.9.0) (2.31.0)
# Collecting igraph (from py4cytoscape==1.9.0)
#   Downloading igraph-0.10.6-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 27.2 MB/s eta 0:00:00
# Collecting colorbrewer (from py4cytoscape==1.9.0)
#   Downloading colorbrewer-0.2.0-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from py4cytoscape==1.9.0) (4.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from py4cytoscape==1.9.0) (4.4.2)
# Collecting backoff (from py4cytoscape==1.9.0)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting colour (from py4cytoscape==1.9.0)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from colorbrewer->py4cytoscape==1.9.0) (1.16.0)
# Collecting texttable>=1.6.2 (from igraph->py4cytoscape==1.9.0)
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->py4cytoscape==1.9.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->py4cytoscape==1.9.0) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->py4cytoscape==1.9.0) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->py4cytoscape==1.9.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->py4cytoscape==1.9.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->py4cytoscape==1.9.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->py4cytoscape==1.9.0) (2023.7.22)
# Building wheels for collected packages: py4cytoscape
#   Building wheel for py4cytoscape (setup.py) ... done
#   Created wheel for py4cytoscape: filename=py4cytoscape-1.9.0-py3-none-any.whl size=177722 sha256=5a9b5f929f7b0672b32a1c99c6804eee6bacf5dd5fbc157ff2fed54c16f0dca6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tq0p38kn/wheels/c0/0c/51/23966f4487705f32ccdc8aca90087e8dc92bf2933d530b5093
# Successfully built py4cytoscape
# Installing collected packages: texttable, colour, igraph, colorbrewer, backoff, py4cytoscape
# Successfully installed backoff-2.2.1 colorbrewer-0.2.0 colour-0.1.5 igraph-0.10.6 py4cytoscape-1.9.0 texttable-1.6.7

# %%
import py4cytoscape as p4c

# silence overwheling "DEBUG" logging messages in colab...
import logging
p4c.py4cytoscape_logger.detail_logger.setLevel(logging.INFO)

# %%
import py4cytoscape as p4c

# %%
if COLAB:# and not ALREADY_RUN_CY_CONNECT:
  ALREADY_RUN_CY_CONNECT = True
  import IPython
  print(f'Loading Javascript client ... {p4c.get_browser_client_channel()} on {p4c.get_jupyter_bridge_url()}')

  browser_client_js = p4c.get_browser_client_js()
  IPython.display.Javascript(browser_client_js) # Start browser client
# Out:
# Loading Javascript client ... a63ef925-ae63-476c-85e0-47cf58742aad on https://jupyter-bridge.cytoscape.org

# %%
p4c.cytoscape_ping()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-e23b697e1b2c> in <cell line: 1>()
# ----> 1 p4c.cytoscape_ping()
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/cytoscape_system.py in cytoscape_ping(base_url)
#      56     """
#      57     from .py4cytoscape_utils import verify_supported_versions
# ---> 58     verify_supported_versions(1, 3.6, base_url=base_url)
#      59     return narrate('You are connected to Cytoscape!')
#      60
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_utils.py in verify_supported_versions(cyrest, cytoscape, base_url, caller)
#     811         >>> verify_supported_versions(1, '3.10')
#     812     """
# --> 813     nogo = check_supported_versions(cyrest=cyrest, cytoscape=cytoscape, base_url=base_url)
#     814
#     815     if nogo:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_utils.py in check_supported_versions(cyrest, cytoscape, base_url, caller)
#     760     if isinstance(cytoscape, float): cytoscape = str(cytoscape)
#     761
# --> 762     v = cytoscape_system.cytoscape_version_info(base_url=base_url)
#     763     v_api_str = v['apiVersion']
#     764     v_cy_str = v['cytoscapeVersion']
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/cytoscape_system.py in cytoscape_version_info(base_url)
#      79         {'apiVersion': 'v1', 'cytoscapeVersion': '3.8.1', 'automationAPIVersion': '0.0.0', 'py4cytoscapeVersion': '0.0.2'}
#      80     """
# ---> 81     versions = commands.cyrest_get('version', base_url=base_url)
#      82     if len(versions) == 0:
#      83         raise CyError('CyREST connection problem. py4cytoscape cannot continue!')
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in cyrest_get(operation, parameters, base_url, require_json, raw_get)
#     147     try:
#     148         url = build_url(base_url, operation)
# --> 149         r = _do_request('GET', url, params=parameters, base_url=base_url, raw_request=raw_get)
#     150         r.raise_for_status()
#     151         try:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _do_request(method, url, base_url, raw_request, **kwargs)
#     693 def _do_request(method, url, base_url=DEFAULT_BASE_URL, raw_request=False, **kwargs):
#     694     # Determine whether actual call is local or remote
# --> 695     requester, default_sandbox = _get_requester(base_url)
#     696
#     697     if not raw_request:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _get_requester(base_url)
#     777 def _get_requester(base_url):
#     778     # Figure out whether CyREST available only via Jupyter-Bridge and what the default sandbox should be
# --> 779     environment = _find_execution_environment(base_url)
#     780     if environment == ExecutionEnvironment.REMOTE_JUPYTER_BRIDGE:
#     781         default_sandbox = set_default_sandbox(**sandbox_initializer(sandboxName=PREDEFINED_SANDBOX_NAME))
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _find_execution_environment(base_url)
#     799
#     800 def _find_execution_environment(base_url):
# --> 801     environment = check_execution_environment(base_url)
#     802     if environment == ExecutionEnvironment.UNKNOWN:
#     803         raise requests.exceptions.RequestException('Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.')
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_notebook.py in check_execution_environment(base_url)
#     227             try:
#     228                 detail_logger.debug(f'Attempting to connect to remote Cytoscape because of error {_error_content(e1)}')
# --> 229                 do_request_jupyter_bridge('GET', _CYREST_URL_V1, headers={'Content-Type': 'application/json'})
#     230                 _execution_environment = ExecutionEnvironment.REMOTE_JUPYTER_BRIDGE
#     231                 detail_logger.debug(f'Detected Cytoscape via Jupyter-Bridge')
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_notebook.py in do_request_jupyter_bridge(method, url, **kwargs)
#     112     try:
#     113         while True:
# --> 114             r = requests.request('GET', f'{_JUPYTER_BRIDGE_URL}/dequeue_reply?channel={_CHANNEL}')
#     115             if r.status_code != 408: break  # keep waiting for a result as long as we keep getting connection timeouts
#     116         r.raise_for_status()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712
#     713             # Make the request on the httplib connection object.
# --> 714             httplib_response = self._make_request(
#     715                 conn,
#     716                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     464                     # Python 3 (including for exceptions like SystemExit).
#     465                     # Otherwise it looks like a bug in the code.
# --> 466                     six.raise_from(e, None)
#     467         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459                 # Python 3
#     460                 try:
# --> 461                     httplib_response = conn.getresponse()
#     462                 except BaseException as e:
#     463                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1272                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273                   self.__class__)
# -> 1274             return self.read(nbytes, buffer)
#    1275         else:
#    1276             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1128         try:
#    1129             if buffer is not None:
# -> 1130                 return self._sslobj.read(len, buffer)
#    1131             else:
#    1132                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Also import the functions from skm-tools to easily load and visualise SKM networks in Cytoscape.

# %%
from skm_tools import cytoscape_utils

# %% [markdown]
# We set the Cytoscape collection name for this notebook.

# %%
COLLECTION = f"Case 1: PSS ({today})"
COLLECTION
# Out:
# 'Case 1: PSS (2023.08.11)'

# %% [markdown]
# We're going to highlight the identified paths in Cytoscape, and we set the colours here:

# %%
ABA_COLOUR = "#dc1c1c"
JA_COLOUR = "#66a61e"
SA_COLOUR = "#34858d"

swatches([ABA_COLOUR, JA_COLOUR, SA_COLOUR])
# Out:
# <span style="font-family: monospace">#dc1c1c <span style="color: #dc1c1c">██████</span></span> <span style="font-family: monospace">#66a61e <span style="color: #66a61e">██████</span></span> <span style="font-family: monospace">#34858d <span style="color: #34858d">██████</span></span>

# %% [markdown]
# ## Load the PSS network into Cytoscape
#
# We load the network, set a visual style, and apply the CoSE layout.
#
# With skm-tools, we provide a default style for PSS, colouring the nodes bypathway.
#
# Returned is the ID of the network view in Cytoscape.

# %%
pss_network_suid = p4c.networks.create_network_from_networkx(g, title="Complete PSS", collection=COLLECTION)
# cytoscape_utils.apply_builtin_style(pss_network_suid, 'pss')
# p4c.layout_network("cose", network=pss_network_suid)
pss_network_suid
# Out:
# DEBUG:py4...:Calling create_network_from_networkx(<networkx.classes.multidigraph.MultiDiGraph object at 0x7b5699eee200>, title='Complete PSS', collection='Case 1: PSS (2023.08.11)')
# DEBUG:py4...:ǀCalling create_network_from_data_frames(nodes=                                                  name       node_type  \
# 0                   CRT[AT1G08450,AT1G09210,AT1G56340]     PlantCoding
# 1                                              Drought  ForeignAbiotic
# 2                                     OSCA1[AT4G04340]     PlantCoding
# 3    SNRK2[AT1G10940,AT1G78290,AT4G33950,SOTUB02G03...     PlantCoding
# 4    AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000]     PlantCoding
# ..                                                 ...             ...
# 446  MSL[AT1G53470,AT1G58200,AT1G78610,AT2G17000,AT...     PlantCoding
# 447                                   MES10[AT3G50440]     PlantCoding
# 448                                     ACT[AT5G61160]     PlantCoding
# 449                                    MYC3[AT5G46760]     PlantCoding
# 450                                    MYC4[AT4G17880]     PlantCoding
#
#     short_name functional_cluster_id  reaction_id  reaction_type  \
# 0          CRT               fc00048          NaN            NaN
# 1          NaN                   NaN          NaN            NaN
# 2        OSCA1               fc00389          NaN            NaN
# 3        SNRK2               fc00318          NaN            NaN
# 4     AREB/ABF               fc00397          NaN            NaN
# ..         ...                   ...          ...            ...
# 446        MSL               fc00388          NaN            NaN
# 447      MES10               fc00401          NaN            NaN
# 448        ACT               fc00380          NaN            NaN
# 449       MYC3               fc00403          NaN            NaN
# 450       MYC4               fc00402          NaN            NaN
#
#      reaction_effect                             additional_information  \
# 0                NaN  Non-receptor component required for EFR-mediat...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# ..               ...                                                ...
# 446              NaN                                                NaN
# 447              NaN                                                NaN
# 448              NaN                                                NaN
# 449              NaN                                                NaN
# 450              NaN                                                NaN
#
#                            pathway                   all_pathways  ... family  \
# 0             Signalling - Calcium           Signalling - Calcium  ...    CRT
# 1                 Stress - Drought               Stress - Drought  ...    NaN
# 2                 Stress - Drought               Stress - Drought  ...    NaN
# 3    Hormone - Abscisic acid (ABA)  Hormone - Abscisic acid (ABA)  ...    NaN
# 4    Hormone - Abscisic acid (ABA)  Hormone - Abscisic acid (ABA)  ...    NaN
# ..                             ...                            ...  ...    ...
# 446          Stress - Waterlogging          Stress - Waterlogging  ...    NaN
# 447                            NaN                            NaN  ...    NaN
# 448                            NaN                            NaN  ...    NaN
# 449       Hormone - Jasmonate (JA)       Hormone - Jasmonate (JA)  ...    NaN
# 450       Hormone - Jasmonate (JA)       Hormone - Jasmonate (JA)  ...    NaN
#
#      function  classification components  \
# 0         NaN             NaN        NaN
# 1         NaN             NaN        NaN
# 2         NaN             NaN        NaN
# 3         NaN             NaN        NaN
# 4         NaN             NaN        NaN
# ..        ...             ...        ...
# 446       NaN             NaN        NaN
# 447       NaN             NaN        NaN
# 448       NaN             NaN        NaN
# 449       NaN             NaN        NaN
# 450       NaN             NaN        NaN
#
#                                         ath_homologues  nta_homologues  \
# 0                    [AT1G08450, AT1G09210, AT1G56340]             NaN
# 1                                                 None             NaN
# 2                                          [AT4G04340]             NaN
# 3                    [AT1G10940, AT1G78290, AT4G33950]             NaN
# 4         [AT1G45249, AT3G19290, AT1G49720, AT4G34000]             NaN
# ..                                                 ...             ...
# 446  [AT4G00290, AT5G10490, AT1G58200, AT1G53470, A...             NaN
# 447                                        [AT3G50440]             NaN
# 448                                        [AT5G61160]             NaN
# 449                                        [AT5G46760]             NaN
# 450                                        [AT4G17880]             NaN
#
#      osa_homologues        stu_homologues sly_homologues  display_label
# 0              None                  None           None            CRT
# 1              None                  None           None        Drought
# 2              None                  None           None          OSCA1
# 3              None  [SOTUB02G032470.1.1]           None          SNRK2
# 4              None                  None           None       AREB/ABF
# ..              ...                   ...            ...            ...
# 446            None                  None           None            MSL
# 447            None                  None           None          MES10
# 448            None                  None           None            ACT
# 449            None                  None           None           MYC3
# 450            None                  None           None           MYC4
#
# [451 rows x 24 columns], edges=    interaction_type directed            reaction_type reaction_effect  \
# 0            binding    False  binding/oligomerisation      activation
# 1         activation     True  binding/oligomerisation      activation
# 2         inhibition    False  binding/oligomerisation      inhibition
# 3         activation     True       protein activation      activation
# 4      translocation     True            translocation      activation
# ..               ...      ...                      ...             ...
# 702       activation     True  binding/oligomerisation      activation
# 703    translocation     True            translocation      activation
# 704       activation     True                catalysis      activation
# 705       inhibition    False  binding/oligomerisation      inhibition
# 706       inhibition    False  binding/oligomerisation      inhibition
#
#     reaction_id source_edge_type     source_location     source_form  \
# 0       rx00228        SUBSTRATE           cytoplasm  protein_active
# 1       rx00228        SUBSTRATE           cytoplasm  protein_active
# 2       rx00194        SUBSTRATE           cytoplasm  protein_active
# 3       rx00568        ACTIVATES           cytoplasm         abiotic
# 4       rx00603          PRODUCT           cytoplasm  protein_active
# ..          ...              ...                 ...             ...
# 702     rx00626        SUBSTRATE  putative:cytoplasm         protein
# 703     rx00517        ACTIVATES         chloroplast  protein_active
# 704     rx00696        ACTIVATES  putative:cytoplasm  protein_active
# 705     rx00444        SUBSTRATE           cytoplasm  protein_active
# 706     rx00446        SUBSTRATE           cytoplasm  protein_active
#
#     target_edge_type        target_location     target_form  \
# 0          SUBSTRATE  endoplasmic reticulum         protein
# 1            PRODUCT              cytoplasm  complex_active
# 2          SUBSTRATE              cytoplasm      metabolite
# 3            PRODUCT              cytoplasm  protein_active
# 4          SUBSTRATE              cytoplasm      metabolite
# ..               ...                    ...             ...
# 702          PRODUCT     putative:cytoplasm         complex
# 703          PRODUCT            chloroplast      metabolite
# 704          PRODUCT             peroxisome      metabolite
# 705        SUBSTRATE                nucleus  protein_active
# 706        SUBSTRATE                nucleus  protein_active
#
#                                  source  \
# 0    CRT[AT1G08450,AT1G09210,AT1G56340]
# 1    CRT[AT1G08450,AT1G09210,AT1G56340]
# 2    CRT[AT1G08450,AT1G09210,AT1G56340]
# 3                               Drought
# 4                      OSCA1[AT4G04340]
# ..                                  ...
# 702                     AGO7[AT1G69440]
# 703                     EDS5[AT4G39030]
# 704                    MES10[AT3G50440]
# 705                     MYC3[AT5G46760]
# 706                     MYC4[AT4G17880]
#
#                                                 target
# 0    ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT...
# 1                                              CRT|ETR
# 2                                                 Ca2+
# 3                                     OSCA1[AT4G04340]
# 4                                                 Ca2+
# ..                                                 ...
# 702                                      RISC - miR390
# 703                                            IsoChor
# 704                                                 JA
# 705                                    NPR1[AT1G64280]
# 706                                    NPR1[AT1G64280]
#
# [707 rows x 13 columns], title='Complete PSS', collection='Case 1: PSS (2023.08.11)', base_url='http://127.0.0.1:1234/v1', node_id_list='name')
# DEBUG:py4...:ǀǀCalling cyrest_post('networks', parameters={'title': 'Complete PSS', 'collection': 'Case 1: PSS (2023.08.11)'}, body={'data': [{'name': 'Complete PSS'}], 'elements': {'nodes': [{'data': {'id': 'CRT[AT1G08450,AT1G09210,AT1G56340]'}}, {'data': {'id': 'Drought'}}, {'data': {'id': 'OSCA1[AT4G04340]'}}, {'data': {'id': 'SNRK2[AT1G10940,AT1G78290,AT4G33950,SOTUB02G032470.1.1]'}}, {'data': {'id': 'AREB/ABF[AT1G45249,AT1G49720,AT3G19290,AT4G34000]'}}, {'data': {'id': 'ARR-A[AT1G10470,AT1G19050,AT1G59940,AT1G74890,AT2G40670,AT2G41310,AT3G48100,AT3G56380,AT3G57040,AT5G62920]'}}, {'data': {'id': 'CML[AT1G66410,AT3G01830,AT4G20780,SOTUB02G034770.1.1]'}}, {'data': {'id': 'CA'}}, {'data': {'id': 'CA-CoA'}}, {'data': {'id': 'BZO1[AT1G65880]'}}, {'data': {'id': 'EDS1[AT3G48090]'}}, {'data': {'id': 'PAD4[AT3G52430]'}}, {'data': {'id': 'EDS1|PAD4'}}, {'data': {'id': 'MPK3,6[AT2G43790,AT3G45640]'}}, {'data': {'id': 'EDS1|MPK3|PAD4'}}, {'data': {'id': 'RBC[AT1G67090,AT5G38430,ATCG00490]'}}, {'data': {'id': 'OBE1[AT3G07780]'}}, {'data': {'id': 'ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]'}}, {'data': {'id': 'CRT|ETR'}}, {'data': {'id': 'Ca2+'}}, {'data': {'id': 'SAMS[AT1G02500,AT2G36880,AT3G17390,AT4G01850]'}}, {'data': {'id': 'SAHH[AT3G23810]'}}, {'data': {'id': 'HSP90[AT2G04030,AT3G07770,AT4G24190,AT5G52640,AT5G56000,AT5G56010,AT5G56030]'}}, {'data': {'id': 'SGT1[AT4G11260,AT4G23570]'}}, {'data': {'id': 'RAR1[AT5G51700]'}}, {'data': {'id': 'HSP90|RAR1|SGT1'}}, {'data': {'id': 'PR5[AT1G75040]'}}, {'data': {'id': 'AGO1[AT1G48410]'}}, {'data': {'id': 'SAGs[AT5G14930,AT5G45890]'}}, {'data': {'id': 'EDS1|PAD4|SAG'}
# DEBUG:py4...:Attempting to direct connect to Cytoscape on http://127.0.0.1:1234/v1
# DEBUG:py4...:Attempting to connect to remote Cytoscape because of error HTTPConnectionPool(host='127.0.0.1', port=1234): Max retries exceeded with url: /v1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7b5691eaa410>: Failed to establish a new connection: [Errno 111] Connection refused'))
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1)
# DEBUG:py4...:Error initially contacting Jupyter-bridge: Error posting to Jupyter-bridge: Channel 2c04dd61-4f18-44a8-bc64-ae3eebe5dfe1:request contains unprocessed message
# In cyrest_post: Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.
# DEBUG:py4...:ǀǀ'cyrest_post' exception RequestException('Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.')
# DEBUG:py4...:ǀ'create_network_from_data_frames' exception RequestException('Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.')
# DEBUG:py4...:'create_network_from_networkx' exception RequestException('Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.')
# DEBUG:py4...:--------------------
# ---------------------------------------------------------------------------
# RequestException                          Traceback (most recent call last)
# <ipython-input-34-778c7613fcdf> in <cell line: 1>()
# ----> 1 pss_network_suid = p4c.networks.create_network_from_networkx(g, title="Complete PSS", collection=COLLECTION)
#       2 # cytoscape_utils.apply_builtin_style(pss_network_suid, 'pss')
#       3 # p4c.layout_network("cose", network=pss_network_suid)
#       4 pss_network_suid
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     131             return log_return(func, value)
#     132         except Exception as e:
# --> 133             log_exception(func, e)
#     134         finally:
#     135             log_finally()
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/networks.py in create_network_from_networkx(netx, title, collection, base_url)
#    1033     if len(edge_df.index) == 0: edge_df = None
#    1034
# -> 1035     return create_network_from_data_frames(nodes=node_df, edges=edge_df, title=title, collection=collection,
#    1036                                            base_url=base_url, node_id_list='name')
#    1037
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     131             return log_return(func, value)
#     132         except Exception as e:
# --> 133             log_exception(func, e)
#     134         finally:
#     135             log_finally()
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/networks.py in create_network_from_data_frames(nodes, edges, title, collection, base_url, node_id_list, source_id_list, target_id_list, interaction_type_list)
#    1129
#    1130     # call Cytoscape to create this network and return the SUID
# -> 1131     network_suid = commands.cyrest_post('networks', parameters={'title': title, 'collection': collection},
#    1132                                         body=json_network, base_url=base_url)['networkSUID']
#    1133     # TODO: There appears to be a race condition here ... the view isn't set for a while. Without an explicit delay, the
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     131             return log_return(func, value)
#     132         except Exception as e:
# --> 133             log_exception(func, e)
#     134         finally:
#     135             log_finally()
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/py4cytoscape_logger.py in wrapper_log(*args, **kwargs)
#     128         log_incoming(func, *args, **kwargs)
#     129         try:
# --> 130             value = func(*args, **kwargs) # Call function being logged
#     131             return log_return(func, value)
#     132         except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in cyrest_post(operation, parameters, body, base_url, require_json)
#     198                 return r.text
#     199     except requests.exceptions.RequestException as e:
# --> 200         _handle_error(e)
#     201
#     202
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in cyrest_post(operation, parameters, body, base_url, require_json)
#     188     try:
#     189         url = build_url(base_url, operation)
# --> 190         r = _do_request('POST', url, params=parameters, json=body, headers = {'Content-Type': 'application/json'}, base_url=base_url)
#     191         r.raise_for_status()
#     192         try:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _do_request(method, url, base_url, raw_request, **kwargs)
#     693 def _do_request(method, url, base_url=DEFAULT_BASE_URL, raw_request=False, **kwargs):
#     694     # Determine whether actual call is local or remote
# --> 695     requester, default_sandbox = _get_requester(base_url)
#     696
#     697     if not raw_request:
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _get_requester(base_url)
#     777 def _get_requester(base_url):
#     778     # Figure out whether CyREST available only via Jupyter-Bridge and what the default sandbox should be
# --> 779     environment = _find_execution_environment(base_url)
#     780     if environment == ExecutionEnvironment.REMOTE_JUPYTER_BRIDGE:
#     781         default_sandbox = set_default_sandbox(**sandbox_initializer(sandboxName=PREDEFINED_SANDBOX_NAME))
#
# /usr/local/lib/python3.10/dist-packages/py4cytoscape/commands.py in _find_execution_environment(base_url)
#     801     environment = check_execution_environment(base_url)
#     802     if environment == ExecutionEnvironment.UNKNOWN:
# --> 803         raise requests.exceptions.RequestException('Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.')
#     804     return environment
#
# RequestException: Cannot find local or remote Cytoscape. Start Cytoscape and then proceed.

# %% [markdown]
# Now we're going to highlight the paths we identified in the network by applying style bypasses.
#
# We don't want to recolour already highlighted path elements, so we keep track of them here:

# %%
done_nodes, done_edges = [], []

# %% [markdown]
# First we highligh the aba path(s), and add the coloured elements to the done lists. You will see the Cytoscaep session incrementally update, as new node and edge style are applied.

# %%
for p in ABA_RD29_paths:
    done_nodes_now, done_edges_now = cytoscape_utils.highlight_path(p, ABA_COLOUR, skip_nodes=done_nodes, skip_edges=done_edges)
    done_nodes += done_nodes_now
    done_edges += done_edges_now
# Out:
# DEBUG:py4...:Calling get_current_style(None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling get_network_view_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 379352
# DEBUG:py4...:ǀCalling cyrest_get('networks/374660/views/379352/currentStyle', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views/379352/currentStyle)
# DEBUG:py4...:ǀOK[200], content: {
#   "title" : "PSS-default",
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#848484"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#525252"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#CCCCCC"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#F7FBFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "SansSerif.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 75.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ],
#   "mappings" : [ {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_SHAPE",
#     "map" : [ {
#       "key" : "PlantCoding",
#       "value" : "ELLIPSE"
#     }, {
#       "key" : "ForeignAbiotic",
#       "value" : "RECTANGLE"
#     }, {
#       "key" : "Metabolite",
#       "value" : "DIAMOND"
#     }, {
#       "key" : "PlantNonCoding",
#       "value" : "HEXAGON"
#     }, {
#       "key" : "Process",
#       "value" : "ROUND_RECTANGLE"
#     }, {
#       "key" : "PlantAbstract",
#       "value" : "OCTAGON"
#     }, {
#       "key" : "Complex",
#       "value" : "ROUND_RECTANGLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "DASH_DOT"
#     }, {
#       "key" : "binding",
#       "value" : "LONG_DASH"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_WIDTH",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "60.0"
#     }, {
#       "key" : "Process",
#       "value" : "100.0"
#     }, {
#       "key" : "Complex",
#       "value" : "80.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_HEIGHT",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "50.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "pathway",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_FILL_COLOR",
#     "map" : [ {
#       "key" : "Hormone - Peptides",
#       "value" : "#D0D4E3"
#     }, {
#       "key" : "Secondary metabolism - Terpenoids",
#       "value" : "#ECF4C2"
#     }, {
#       "key" : "Signalling - Perception and resistance genes",
#       "value" : "#F8EABD"
#     }, {
#       "key" : "Signalling - Other",
#       "value" : "#FBEDB7"
#     }, {
#       "key" : "Degradation - Autophagy",
#       "value" : "#B3E2CD"
#     }, {
#       "key" : "Hormone - Gibberellin (GA)",
#       "value" : "#E5D1C9"
#     }, {
#       "key" : "Hormone - Cytokinins (CK)",
#       "value" : "#FACDB0"
#     }, {
#       "key" : "Stress - Heat",
#       "value" : "#D4D1CC"
#     }, {
#       "key" : "Hormone - Strigolactones (SL)",
#       "value" : "#D9D1E7"
#     }, {
#       "key" : "Regulation - Silencing",
#       "value" : "#F1D2DF"
#     }, {
#       "key" : "Signalling - Reactive oxygen species (ROS)",
#       "value" : "#F5E6C4"
#     }, {
#       "key" : "Hormone - Brassinosteroids (BS)",
#       "value" : "#F2D0B1"
#     }, {
#       "key" : "Hormone - Salicylic acid (SA)",
#       "value" : "#D0D4E8"
#     }, {
#       "key" : "Stress - Waterlogging",
#       "value" : "#CCCCCC"
#     }, {
#       "key" : "Signalling - Growth",
#       "value" : "#F7F3B7"
#     }, {
#       "key" : "Stress - Biotic",
#       "value" : "#E4DACC"
#     }, {
#       "key" : "Primary metabolism - Amino-acids",
#       "value" : "#E1CFE6"
#     }, {
#       "key" : "Hormone - Auxins (AUX)",
#       "value" : "#E2D5B8"
#     }, {
#       "key" : "Primary metabolism - Photosynthesis",
#       "value" : "#EACDE5"
#     }, {
#       "key" : "Signalling - Calcium",
#       "value" : "#F1F4BD"
#     }, {
#       "key" : "Secondary metabolism - Alkaloids",
#       "value" : "#E9EDCE"
#     }, {
#       "key" : "Hormone - Ethylene (ET)",
#       "value" : "#EFCFBC"
#     }, {
#       "key" : "Hormone - Jasmonate (JA)",
#       "value" : "#DAD3D6"
#     }, {
#       "key" : "Degradation - Ubiquitination",
#       "value" : "#C3DEC6"
#     }, {
#       "key" : "Regulation - Transport",
#       "value" : "#ECE4D4"
#     }, {
#       "key" : "Regulation - Transcription & Translation",
#       "value" : "#EEDBD9"
#     }, {
#       "key" : "Signalling - Heat-shock proteins (HSPs)",
#       "value" : "#FCF2B1"
#     }, {
#       "key" : "Secondary metabolism - Anthocyanins",
#       "value" : "#E7F5C8"
#     }, {
#       "key" : "Signalling - Senescence",
#       "value" : "#F2E3CA"
#     }, {
#       "key" : "Primary metabolism - Respiration",
#       "value" : "#F3CAE4"
#     }, {
#       "key" : "Stress - Drought",
#       "value" : "#DCD5CC"
#     }, {
#       "key" : "Hormone - Abscisic acid (ABA)",
#       "value" : "#D2D9BF"
#     }, {
#       "key" : "Signalling - MAP kinases (MAPKs)",
#       "value" : "#FEF1B1"
#     }, {
#       "key" : "Signalling - Tuberisation",
#       "value" : "#EBDFCC"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "CROSS_OPEN_DELTA"
#     }, {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     }, {
#       "key" : "inhibition",
#       "value" : "T"
#     }, {
#       "key" : "activation",
#       "value" : "ARROW"
#     } ]
#   }, {
#     "mappingType" : "passthrough",
#     "mappingColumn" : "display_label",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_LABEL"
#   } ]
# }
# DEBUG:py4...:ǀReturning 'cyrest_get': {'title': 'PSS-default', 'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#848484'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#525252'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 2.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#CCCCCC'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_WIDTH', 'value': 2.0}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_1', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_2', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_3', 'value': ' ...
# DEBUG:py4...:Returning 'get_current_style': 'PSS-default'
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling select_nodes(['ABA', 'PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1]', 'SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1]', 'AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000]', 'RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1]', 'PYL[AT1G01360\\,AT2G40330]'], by_col='name', network=None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling commands_post('network select network=SUID:"374660" nodeList="name:ABA,name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:PYL[AT1G01360\\,AT2G40330]"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'network': 'SUID:374660', 'nodeList': 'name:ABA,name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:PYL[AT1G01360\\,AT2G40330]'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   375924,
#   374703,
#   375906,
#   374700,
#   375150,
#   375432
# ], "edges":[]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [375924, 374703, 375906, 374700, 375150, 375432], 'edges': []}
# DEBUG:py4...:Returning 'select_nodes': {'nodes': [375924, 374703, 375906, 374700, 375150, 375432], 'edges': []}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling set_node_color_bypass(node_names=[375924, 374703, 375906, 374700, 375150, 375432], new_colors='#dc1c1c', network=None)
# DEBUG:py4...:ǀCalling set_node_property_bypass([375924, 374703, 375906, 374700, 375150, 375432], '#dc1c1c', 'NODE_FILL_COLOR', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀǀCalling get_table_columns('node', ['name'], 'default', None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, 'http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling get_table_column_types('node', namespace='default', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks/374660/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"id","type":"String","immutable":false,"primaryKey":false},{"name":"node_type","type":"String","immutable":false,"primaryKey":false},{"name":"short_name","type":"String","immutable":false,"primaryKey":false},{"name":"functional_cluster_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_type","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_effect","type":"String","immutable":false,"primaryKey":false},{"name":"additional_information","type":"String","immutable":false,"primaryKey":false},{"name":"pathway","type":"String","immutable":false,"primaryKey":false},{"name":"all_pathways","type":"String","immutable":false,"primaryKey":false},{"name":"description","type":"String","immutable":false,"primaryKey":false},{"name":"evidence_sentence","type":"String","immutable":false,"primaryKey":false},{"name":"experimental_techniques","type":"String","immutable":false,"primaryKey":false},{"name":"external_links","type":"String","immutable":false,"primaryKey":false},{"name":"family","type":"String","immutable":false,"primaryKey":false},{"name":"function","type":"String","immutable":false,"primaryKey":false},{"name":"classification","type":"String","immutable":false,"primaryKey":false},{"name":"components","type":"String","immutable":false,"primaryKey":false},{"name":"ath_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"nta_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"osa_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"stu_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"sly_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"display_label","type":"String","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'node_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'short_name', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'functional_cluster_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_effect', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'additional_information', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'pathway', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'all_pathways', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'description', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'evidence_sentence', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'experimental_techniques', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'external_links', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'family', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 
HK2,3,4[AT1G27320,AT2G01830,AT5G35750]","NPR4[AT4G19660] (interacts with) NPR1[AT1G64280]","DZ-riboside (interacts with) DZ","RAPTOR2[AT3G08850,AT5G01770] (interacts with) TORC1","NPR3[AT5G45110] (interacts with) NPR1[AT1G64280]","tZ (interacts with) tZ-glucoside","Trp (interacts with) IAM","Trp (interacts with) IPA","MKD1[AT5G11850] (interacts with) MKK1[AT4G26070]","tZ (interacts with) tZ-riboside","IAM (interacts with) IAA","DZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]","tZ (interacts with) tZ-ribotide","AHK2,3,4[AT1G27320,AT2G01830,AT5G35750] (interacts with) AHP[AT1G03430,AT1G80100,AT3G16360,AT3G21510,AT3G29350,AT5G39340]","Trp (interacts with) IAOx","DZ (interacts with) DZ-riboside","DZ (interacts with) DZ-ribotide","SARD1[AT1G73805] (interacts with) TCP8[AT1G58100]","DZ (interacts with) DZ-glucosides","iaaM[unknown] (interacts with) IAM","SARD1[AT1G73805] (interacts with) ICS[AT1G18870,AT1G74710]","iP (interacts with) iP-riboside","S-alkyl-thiohydroximate (interacts with) Thiohydroximate","SUR1[AT2G20610] (interacts with) Thiohydroximate","SARD1[AT1G73805] (interacts with) SARD1|TCP8","iP (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]","MVA (interacts with) 5-phosphomevalonate","L-Met (interacts with) SAMe","iP (interacts with) iP-glucosides","iP (interacts with) iP-ribotide","OSCA1.3[AT1G11960] (interacts with) Ca2+","SAMe (interacts with) SAH","NIMIN[AT1G02450,AT1G09415,AT3G25882] (interacts with) NPR1[AT1G64280]","TCP8[AT1G58100] (interacts with) SARD1[AT1G73805]","SAMe (interacts with) ACC","MVK[AT5G27450] (interacts with) 5-phosphomevalonate","TCP8[AT1G58100] (interacts with) ICS[AT1G18870,AT1G74710]","ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC","TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]","TCP8[AT1G58100] (interacts with) TCP8|WRKY28","TCP8[AT1G58100] (interacts with) SARD1|TCP8","ACC (interacts with) ET","TCP8[AT1G58100] (interacts with) NAC019|TCP8","ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET","ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]","ET (interacts with) ET|ETR","TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]","ALA (interacts with) 13-HPOT","ROS (interacts with) MDA","IAA (interacts with) IAA-Asp","ALA (interacts with) MDA","IAA-Ala (interacts with) IAA","IAA (interacts with) IAA-Glu","ROS (interacts with) GRX480[AT1G28480]","IAR[AT1G51760,AT1G68100] (interacts with) IAA","IPA (interacts with) IAA","IAA (interacts with) TIR1[AT3G62980]","ROS (interacts with) TRX-H[AT1G45145,AT5G42980]","BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]","Ile (interacts with) JA-Ile","ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]","Thr (interacts with) Ile","TAA1[AT1G70560] (interacts with) IPA","13-HPOT (interacts with) 12,13-EOT","LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT","Brassinolide (interacts with) BAK1|BRI1","OMR1[AT3G10050] (interacts with) Ile","BRI1[AT4G3 ...
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get
T1G58100] (interacts with) ICS[AT1G18870,AT1G74710]', 'ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC', 'TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]', 'TCP8[AT1G58100] (interacts with) TCP8|WRKY28', 'TCP8[AT1G58100] (interacts with) SARD1|TCP8', 'ACC (interacts with) ET', 'TCP8[AT1G58100] (interacts with) NAC019|TCP8', 'ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET', 'ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]', 'ET (interacts with) ET|ETR', 'TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]', 'ALA (interacts with) 13-HPOT', 'ROS (interacts with) MDA', 'IAA (interacts with) IAA-Asp', 'ALA (interacts with) MDA', 'IAA-Ala (interacts with) IAA', 'IAA (interacts with) IAA-Glu', 'ROS (interacts with) GRX480[AT1G28480]', 'IAR[AT1G51760,AT1G68100] (interacts with) IAA', 'IPA (interacts with) IAA', 'IAA (interacts with) TIR1[AT3G62980]', 'ROS (interacts with) TRX-H[AT1G45145,AT5G42980]', 'BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]', 'Ile (interacts with) JA-Ile', 'ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]', 'Thr (interacts with) Ile', 'TAA1[AT1G70560] (interacts with) IPA', '13-HPOT (interacts with) 12,13-EOT', 'LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT', ' ...
# DEBUG:py4...:ǀǀReturning 'get_table_columns':                                                      name
# 376836                    cZ (interacts with) cZ-ribotide
# 376839                 Glu (interacts with) cZ-glucosides
# 377862  GH3[AT2G47750,AT4G27260] (interacts with) IAA-Asp
# 376833                    cZ (interacts with) cZ-riboside
# 377856              TOR[AT1G50030] (interacts with) TORC1
# ...                                                   ...
# 377853  TOR[AT1G50030] (interacts with) RAPTOR2[AT3G08...
# 376830  cZ (interacts with) AHK2,3,4[AT1G27320,AT2G018...
# 376824  UGT[AT1G22400,AT2G36750,AT2G36800,AT5G05860,AT...
# 376827                  cZ (interacts with) cZ-glucosides
# 377850  TOR[AT1G50030] (interacts with) LST8[AT2G22040...
#
# [707 rows x 1 columns]
# DEBUG:py4...:ǀǀCalling cyrest_put('networks/374660/views/379352/edges', parameters={'bypass': True}, body=[{'SUID': '376068', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '377124', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '378048', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '377439', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '376095', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '376065', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP PUT(http://127.0.0.1:1234/v1/networks/374660/views/379352/edges), params: {'bypass': True}, json: [{'SUID': '376068', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '377124', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '378048', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '377439', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '376095', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}, {'SUID': '376065', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#dc1c1c'}]}]
# DEBUG:py4...:ǀǀOK[200], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_put': ''
# DEBUG:py4...:ǀReturning 'set_edge_property_bypass': ''
# DEBUG:py4...:Returning 'set_edge_color_bypass': ''
# DEBUG:py4...:--------------------

# %% [markdown]
# Now we do the next pathways:

# %%
for p in JA_paths:
    done_nodes_now, done_edges_now = cytoscape_utils.highlight_path(p, JA_COLOUR, skip_nodes=done_nodes, skip_edges=done_edges)
    done_nodes += done_nodes_now
    done_edges += done_edges_now
# Out:
# DEBUG:py4...:Calling get_current_style(None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling get_network_view_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 379352
# DEBUG:py4...:ǀCalling cyrest_get('networks/374660/views/379352/currentStyle', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views/379352/currentStyle)
# DEBUG:py4...:ǀOK[200], content: {
#   "title" : "PSS-default",
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#848484"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#525252"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#CCCCCC"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#F7FBFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "SansSerif.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 75.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ],
#   "mappings" : [ {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_SHAPE",
#     "map" : [ {
#       "key" : "PlantCoding",
#       "value" : "ELLIPSE"
#     }, {
#       "key" : "ForeignAbiotic",
#       "value" : "RECTANGLE"
#     }, {
#       "key" : "Metabolite",
#       "value" : "DIAMOND"
#     }, {
#       "key" : "PlantNonCoding",
#       "value" : "HEXAGON"
#     }, {
#       "key" : "Process",
#       "value" : "ROUND_RECTANGLE"
#     }, {
#       "key" : "PlantAbstract",
#       "value" : "OCTAGON"
#     }, {
#       "key" : "Complex",
#       "value" : "ROUND_RECTANGLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "DASH_DOT"
#     }, {
#       "key" : "binding",
#       "value" : "LONG_DASH"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_WIDTH",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "60.0"
#     }, {
#       "key" : "Process",
#       "value" : "100.0"
#     }, {
#       "key" : "Complex",
#       "value" : "80.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_HEIGHT",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "50.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "pathway",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_FILL_COLOR",
#     "map" : [ {
#       "key" : "Hormone - Peptides",
#       "value" : "#D0D4E3"
#     }, {
#       "key" : "Secondary metabolism - Terpenoids",
#       "value" : "#ECF4C2"
#     }, {
#       "key" : "Signalling - Perception and resistance genes",
#       "value" : "#F8EABD"
#     }, {
#       "key" : "Signalling - Other",
#       "value" : "#FBEDB7"
#     }, {
#       "key" : "Degradation - Autophagy",
#       "value" : "#B3E2CD"
#     }, {
#       "key" : "Hormone - Gibberellin (GA)",
#       "value" : "#E5D1C9"
#     }, {
#       "key" : "Hormone - Cytokinins (CK)",
#       "value" : "#FACDB0"
#     }, {
#       "key" : "Stress - Heat",
#       "value" : "#D4D1CC"
#     }, {
#       "key" : "Hormone - Strigolactones (SL)",
#       "value" : "#D9D1E7"
#     }, {
#       "key" : "Regulation - Silencing",
#       "value" : "#F1D2DF"
#     }, {
#       "key" : "Signalling - Reactive oxygen species (ROS)",
#       "value" : "#F5E6C4"
#     }, {
#       "key" : "Hormone - Brassinosteroids (BS)",
#       "value" : "#F2D0B1"
#     }, {
#       "key" : "Hormone - Salicylic acid (SA)",
#       "value" : "#D0D4E8"
#     }, {
#       "key" : "Stress - Waterlogging",
#       "value" : "#CCCCCC"
#     }, {
#       "key" : "Signalling - Growth",
#       "value" : "#F7F3B7"
#     }, {
#       "key" : "Stress - Biotic",
#       "value" : "#E4DACC"
#     }, {
#       "key" : "Primary metabolism - Amino-acids",
#       "value" : "#E1CFE6"
#     }, {
#       "key" : "Hormone - Auxins (AUX)",
#       "value" : "#E2D5B8"
#     }, {
#       "key" : "Primary metabolism - Photosynthesis",
#       "value" : "#EACDE5"
#     }, {
#       "key" : "Signalling - Calcium",
#       "value" : "#F1F4BD"
#     }, {
#       "key" : "Secondary metabolism - Alkaloids",
#       "value" : "#E9EDCE"
#     }, {
#       "key" : "Hormone - Ethylene (ET)",
#       "value" : "#EFCFBC"
#     }, {
#       "key" : "Hormone - Jasmonate (JA)",
#       "value" : "#DAD3D6"
#     }, {
#       "key" : "Degradation - Ubiquitination",
#       "value" : "#C3DEC6"
#     }, {
#       "key" : "Regulation - Transport",
#       "value" : "#ECE4D4"
#     }, {
#       "key" : "Regulation - Transcription & Translation",
#       "value" : "#EEDBD9"
#     }, {
#       "key" : "Signalling - Heat-shock proteins (HSPs)",
#       "value" : "#FCF2B1"
#     }, {
#       "key" : "Secondary metabolism - Anthocyanins",
#       "value" : "#E7F5C8"
#     }, {
#       "key" : "Signalling - Senescence",
#       "value" : "#F2E3CA"
#     }, {
#       "key" : "Primary metabolism - Respiration",
#       "value" : "#F3CAE4"
#     }, {
#       "key" : "Stress - Drought",
#       "value" : "#DCD5CC"
#     }, {
#       "key" : "Hormone - Abscisic acid (ABA)",
#       "value" : "#D2D9BF"
#     }, {
#       "key" : "Signalling - MAP kinases (MAPKs)",
#       "value" : "#FEF1B1"
#     }, {
#       "key" : "Signalling - Tuberisation",
#       "value" : "#EBDFCC"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "CROSS_OPEN_DELTA"
#     }, {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     }, {
#       "key" : "inhibition",
#       "value" : "T"
#     }, {
#       "key" : "activation",
#       "value" : "ARROW"
#     } ]
#   }, {
#     "mappingType" : "passthrough",
#     "mappingColumn" : "display_label",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_LABEL"
#   } ]
# }
# DEBUG:py4...:ǀReturning 'cyrest_get': {'title': 'PSS-default', 'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#848484'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#525252'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 2.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#CCCCCC'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_WIDTH', 'value': 2.0}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_1', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_2', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_3', 'value': ' ...
# DEBUG:py4...:Returning 'get_current_style': 'PSS-default'
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling select_nodes(['PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1]', 'JA', 'MYC2[AT1G32640]', 'JAZ[AT1G17380\\,AT1G19180\\,AT1G30135\\,AT1G48500\\,AT1G70700\\,AT1G72450\\,AT1G74950\\,AT2G34600\\,AT3G17860\\,AT3G43440\\,AT5G13220\\,AT5G20900]', 'COI1|JA-Ile|SCF', 'SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1]', 'AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000]', 'RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1]', 'JA-Ile', 'PYL[AT1G01360\\,AT2G40330]'], by_col='name', network=None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling commands_post('network select network=SUID:"374660" nodeList="name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:JA,name:MYC2[AT1G32640],name:JAZ[AT1G17380\\,AT1G19180\\,AT1G30135\\,AT1G48500\\,AT1G70700\\,AT1G72450\\,AT1G74950\\,AT2G34600\\,AT3G17860\\,AT3G43440\\,AT5G13220\\,AT5G20900],name:COI1|JA-Ile|SCF,name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:JA-Ile,name:PYL[AT1G01360\\,AT2G40330]"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'network': 'SUID:374660', 'nodeList': 'name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:JA,name:MYC2[AT1G32640],name:JAZ[AT1G17380\\,AT1G19180\\,AT1G30135\\,AT1G48500\\,AT1G70700\\,AT1G72450\\,AT1G74950\\,AT2G34600\\,AT3G17860\\,AT3G43440\\,AT5G13220\\,AT5G20900],name:COI1|JA-Ile|SCF,name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:JA-Ile,name:PYL[AT1G01360\\,AT2G40330]'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   375924,
#   374703,
#   375090,
#   375906,
#   374700,
#   374844,
#   375291,
#   375150,
#   375102,
#   374919
# ], "edges":[
#   376068,
#   377124,
#   378048,
#   376095,
#   377439,
#   376065
# ]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [375924, 374703, 375090, 375906, 374700, 374844, 375291, 375150, 375102, 374919], 'edges': [376068, 377124, 378048, 376095, 377439, 376065]}
# DEBUG:py4...:Returning 'select_nodes': {'nodes': [375924, 374703, 375090, 375906, 374700, 374844, 375291, 375150, 375102, 374919], 'edges': [376068, 377124, 378048, 376095, 377439, 376065]}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling set_node_color_bypass(node_names=[375924, 374703, 375090, 375906, 374700, 374844, 375291, 375150, 375102, 374919], new_colors='#66a61e', network=None)
# DEBUG:py4...:ǀCalling set_node_property_bypass([375924, 374703, 375090, 375906, 374700, 374844, 375291, 375150, 375102, 374919], '#66a61e', 'NODE_FILL_COLOR', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀǀCalling get_table_columns('node', ['name'], 'default', None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, 'http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling get_table_column_types('node', namespace='default', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks/374660/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"id","type":"String","immutable":false,"primaryKey":false},{"name":"node_type","type":"String","immutable":false,"primaryKey":false},{"name":"short_name","type":"String","immutable":false,"primaryKey":false},{"name":"functional_cluster_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_type","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_effect","type":"String","immutable":false,"primaryKey":false},{"name":"additional_information","type":"String","immutable":false,"primaryKey":false},{"name":"pathway","type":"String","immutable":false,"primaryKey":false},{"name":"all_pathways","type":"String","immutable":false,"primaryKey":false},{"name":"description","type":"String","immutable":false,"primaryKey":false},{"name":"evidence_sentence","type":"String","immutable":false,"primaryKey":false},{"name":"experimental_techniques","type":"String","immutable":false,"primaryKey":false},{"name":"external_links","type":"String","immutable":false,"primaryKey":false},{"name":"family","type":"String","immutable":false,"primaryKey":false},{"name":"function","type":"String","immutable":false,"primaryKey":false},{"name":"classification","type":"String","immutable":false,"primaryKey":false},{"name":"components","type":"String","immutable":false,"primaryKey":false},{"name":"ath_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"nta_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"osa_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"stu_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"sly_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"display_label","type":"String","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'node_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'short_name', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'functional_cluster_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_effect', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'additional_information', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'pathway', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'all_pathways', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'description', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'evidence_sentence', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'experimental_techniques', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'external_links', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'family', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'function', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'classification', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'components', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'ath_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'nta_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'osa_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'stu_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'sly_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 
HK2,3,4[AT1G27320,AT2G01830,AT5G35750]","tZ (interacts with) tZ-ribotide","AHK2,3,4[AT1G27320,AT2G01830,AT5G35750] (interacts with) AHP[AT1G03430,AT1G80100,AT3G16360,AT3G21510,AT3G29350,AT5G39340]","Trp (interacts with) IAOx","DZ (interacts with) DZ-riboside","DZ (interacts with) DZ-ribotide","SARD1[AT1G73805] (interacts with) TCP8[AT1G58100]","DZ (interacts with) DZ-glucosides","iaaM[unknown] (interacts with) IAM","SARD1[AT1G73805] (interacts with) ICS[AT1G18870,AT1G74710]","iP (interacts with) iP-riboside","S-alkyl-thiohydroximate (interacts with) Thiohydroximate","SUR1[AT2G20610] (interacts with) Thiohydroximate","SARD1[AT1G73805] (interacts with) SARD1|TCP8","iP (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]","MVA (interacts with) 5-phosphomevalonate","L-Met (interacts with) SAMe","iP (interacts with) iP-glucosides","iP (interacts with) iP-ribotide","OSCA1.3[AT1G11960] (interacts with) Ca2+","SAMe (interacts with) SAH","NIMIN[AT1G02450,AT1G09415,AT3G25882] (interacts with) NPR1[AT1G64280]","TCP8[AT1G58100] (interacts with) SARD1[AT1G73805]","SAMe (interacts with) ACC","MVK[AT5G27450] (interacts with) 5-phosphomevalonate","TCP8[AT1G58100] (interacts with) ICS[AT1G18870,AT1G74710]","ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC","TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]","TCP8[AT1G58100] (interacts with) TCP8|WRKY28","TCP8[AT1G58100] (interacts with) SARD1|TCP8","ACC (interacts with) ET","TCP8[AT1G58100] (interacts with) NAC019|TCP8","ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET","ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]","ET (interacts with) ET|ETR","TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]","ALA (interacts with) 13-HPOT","ROS (interacts with) MDA","IAA (interacts with) IAA-Asp","ALA (interacts with) MDA","IAA-Ala (interacts with) IAA","IAA (interacts with) IAA-Glu","ROS (interacts with) GRX480[AT1G28480]","IAR[AT1G51760,AT1G68100] (interacts with) IAA","IPA (interacts with) IAA","IAA (interacts with) TIR1[AT3G62980]","ROS (interacts with) TRX-H[AT1G45145,AT5G42980]","BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]","Ile (interacts with) JA-Ile","ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]","Thr (interacts with) Ile","TAA1[AT1G70560] (interacts with) IPA","13-HPOT (interacts with) 12,13-EOT","LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT","Brassinolide (interacts with) BAK1|BRI1","OMR1[AT3G10050] (interacts with) Ile","BRI1[AT4G3 ...
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'name': 'name', 'values': ['cZ (interacts with) cZ-ribotide', 'Glu (interacts with) cZ-glucosides', 'GH3[AT2G47750,AT4G27260] (interacts with) IAA-Asp', 'cZ (interacts with) cZ-riboside', 'TOR[AT1G50030] (interacts with) TORC1', 'GH3[AT2G47750,AT4G27260] (interacts with) SA-Asp', 'Glu (interacts with) tZ-glucoside', 'LST8[AT2G22040,AT3G18140] (interacts with) RAPTOR2[AT3G08850,AT5G01770]', 'LST8[AT2G22040,AT3G18140] (interacts with) TORC1', 'LST8[AT2G22040,AT3G18140] (interacts with) TOR[AT1G50030]', 'Glu (interacts with) DZ-glucosides', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) LST8[AT2G22040,AT3G18140]', 'DZ-riboside (interacts with) DZ-ribotide', 'Glu (interacts with) iP-glucosides', 'Glu (interacts with) IsoChor-9-Glu', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) TOR[AT1G50030]', 'DZ-ribotide (interacts with) DZ-riboside', 'tZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'NPR4[AT4G19660] (interacts with) NPR1[AT1G64280]', 'DZ-riboside (interacts with) DZ', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) TORC1', 'NPR3[AT5G45110] (interacts with) NPR1[AT1G64280]', 'tZ (interacts with) tZ-glucoside', 'Trp (interacts with) IAM', 'Trp (interacts with) IPA', 'MKD1[AT5G11850] (interacts with) MKK1[AT4G26070]', 'tZ (interacts with) tZ-riboside', 'IAM (interacts with) IAA', 'DZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'tZ (interacts with) tZ-ribotide', 'AHK2,3,4[AT1G27320,AT2G01830,AT5G35750] (interacts with) AHP[AT1G03430,AT1G80100,AT3G16360,AT3G21510,AT3G29350,AT5G39340]', 'Trp (interacts with) IAOx', 'DZ (interacts with) DZ-riboside', 'DZ (interacts with) DZ-ribotide', 'SARD1[AT1G73805] (interacts with) TCP8[AT1G58100]', 'DZ (interacts with) DZ-glucosides', 'iaaM[unknown] (interacts with) IAM', 'SARD1[AT1G73805] (interacts with) ICS[AT1G18870,AT1G74710]', 'iP (interacts with) iP-riboside', 'S-alkyl-thiohydroximate (interacts with) Thiohydroximate', 'SUR1[AT2G20610] (interacts with) Thiohydroximate', 'SARD1[AT1G73805] (interacts with) SARD1|TCP8', 'iP (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'MVA (interacts with) 5-phosphomevalonate', 'L-Met (interacts with) SAMe', 'iP (interacts with) iP-glucosides', 'iP (interacts with) iP-ribotide', 'OSCA1.3[AT1G11960] (interacts with) Ca2+', 'SAMe (interacts with) SAH', 'NIMIN[AT1G02450,AT1G09415,AT3G25882] (interacts with) NPR1[AT1G64280]', 'TCP8[AT1G58100] (interacts with) SARD1[AT1G73805]', 'SAMe (interacts with) ACC', 'MVK[AT5G27450] (interacts with) 5-phosphomevalonate', 'TCP8[AT1G58100] (interacts with) ICS[AT1G18870,AT1G74710]', 'ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC', 'TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]', 'TCP8[AT1G58100] (interacts with) TCP8|WRKY28', 'TCP8[AT1G58100] (interacts with) SARD1|TCP8', 'ACC (interacts with) ET', 'TCP8[AT1G58100] (interacts with) NAC019|TCP8', 'ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET', 'ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]', 'ET (interacts with) ET|ETR', 'TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]', 'ALA (interacts with) 13-HPOT', 'ROS (interacts with) MDA', 'IAA (interacts with) IAA-Asp', 'ALA (interacts with) MDA', 'IAA-Ala (interacts with) IAA', 'IAA (interacts with) IAA-Glu', 'ROS (interacts with) GRX480[AT1G28480]', 'IAR[AT1G51760,AT1G68100] (interacts with) IAA', 'IPA (interacts with) IAA', 'IAA (interacts with) TIR1[AT3G62980]', 'ROS (interacts with) TRX-H[AT1G45145,AT5G42980]', 'BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]', 'Ile (interacts with) JA-Ile', 'ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]', 'Thr (interacts with) Ile', 'TAA1[AT1G70560] (interacts with) IPA', '13-HPOT (interacts with) 12,13-EOT', 'LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT', ' ...
# DEBUG:py4...:ǀǀReturning 'get_table_columns':                                                      name
# 376836                    cZ (interacts with) cZ-ribotide
# 376839                 Glu (interacts with) cZ-glucosides
# 377862  GH3[AT2G47750,AT4G27260] (interacts with) IAA-Asp
# 376833                    cZ (interacts with) cZ-riboside
# 377856              TOR[AT1G50030] (interacts with) TORC1
# ...                                                   ...
# 377853  TOR[AT1G50030] (interacts with) RAPTOR2[AT3G08...
# 376830  cZ (interacts with) AHK2,3,4[AT1G27320,AT2G018...
# 376824  UGT[AT1G22400,AT2G36750,AT2G36800,AT5G05860,AT...
# 376827                  cZ (interacts with) cZ-glucosides
# 377850  TOR[AT1G50030] (interacts with) LST8[AT2G22040...
#
# [707 rows x 1 columns]
# DEBUG:py4...:ǀǀCalling cyrest_put('networks/374660/views/379352/edges', parameters={'bypass': True}, body=[{'SUID': '377283', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '376470', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '376662', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '377061', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '377040', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP PUT(http://127.0.0.1:1234/v1/networks/374660/views/379352/edges), params: {'bypass': True}, json: [{'SUID': '377283', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '376470', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '376662', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '377061', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}, {'SUID': '377040', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#66a61e'}]}]
# DEBUG:py4...:ǀǀOK[200], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_put': ''
# DEBUG:py4...:ǀReturning 'set_edge_property_bypass': ''
# DEBUG:py4...:Returning 'set_edge_color_bypass': ''
# DEBUG:py4...:--------------------

# %%
for p in SA_paths:
    done_nodes_now, done_edges_now = cytoscape_utils.highlight_path(p, SA_COLOUR, skip_nodes=done_nodes, skip_edges=done_edges)
    done_nodes += done_nodes_now
    done_edges += done_edges_now
# Out:
# DEBUG:py4...:Calling get_current_style(None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling get_network_view_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀReturning 'get_network_view_suid': 379352
# DEBUG:py4...:ǀCalling cyrest_get('networks/374660/views/379352/currentStyle', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views/379352/currentStyle)
# DEBUG:py4...:ǀOK[200], content: {
#   "title" : "PSS-default",
#   "defaults" : [ {
#     "visualProperty" : "COMPOUND_NODE_PADDING",
#     "value" : 10.0
#   }, {
#     "visualProperty" : "COMPOUND_NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "DING_RENDERING_ENGINE_ROOT",
#     "value" : "org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9"
#   }, {
#     "visualProperty" : "EDGE",
#     "value" : "DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)"
#   }, {
#     "visualProperty" : "EDGE_BEND",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_CURVED",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_FACE",
#     "value" : "Dialog.plain,plain,10"
#   }, {
#     "visualProperty" : "EDGE_LABEL_FONT_SIZE",
#     "value" : 10
#   }, {
#     "visualProperty" : "EDGE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "EDGE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "EDGE_PAINT",
#     "value" : "#323232"
#   }, {
#     "visualProperty" : "EDGE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "EDGE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_SOURCE_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_STACKING",
#     "value" : "AUTO_BEND"
#   }, {
#     "visualProperty" : "EDGE_STACKING_DENSITY",
#     "value" : 0.5
#   }, {
#     "visualProperty" : "EDGE_STROKE_SELECTED_PAINT",
#     "value" : "#FF0000"
#   }, {
#     "visualProperty" : "EDGE_STROKE_UNSELECTED_PAINT",
#     "value" : "#848484"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "value" : "NONE"
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_SIZE",
#     "value" : 6.0
#   }, {
#     "visualProperty" : "EDGE_TARGET_ARROW_UNSELECTED_PAINT",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "EDGE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "EDGE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "EDGE_UNSELECTED_PAINT",
#     "value" : "#525252"
#   }, {
#     "visualProperty" : "EDGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "EDGE_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "EDGE_Z_ORDER",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK",
#     "value" : "DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)"
#   }, {
#     "visualProperty" : "NETWORK_ANNOTATION_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_BACKGROUND_PAINT",
#     "value" : "#FFFFFF"
#   }, {
#     "visualProperty" : "NETWORK_CENTER_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_CENTER_Z_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NETWORK_EDGE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_FORCE_HIGH_DETAIL",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_HEIGHT",
#     "value" : 400.0
#   }, {
#     "visualProperty" : "NETWORK_NODE_LABEL_SELECTION",
#     "value" : false
#   }, {
#     "visualProperty" : "NETWORK_NODE_SELECTION",
#     "value" : true
#   }, {
#     "visualProperty" : "NETWORK_SCALE_FACTOR",
#     "value" : 1.0
#   }, {
#     "visualProperty" : "NETWORK_SIZE",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NETWORK_TITLE",
#     "value" : ""
#   }, {
#     "visualProperty" : "NETWORK_WIDTH",
#     "value" : 550.0
#   }, {
#     "visualProperty" : "NODE",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)"
#   }, {
#     "visualProperty" : "NODE_BORDER_PAINT",
#     "value" : "#CCCCCC"
#   }, {
#     "visualProperty" : "NODE_BORDER_STROKE",
#     "value" : "SOLID"
#   }, {
#     "visualProperty" : "NODE_BORDER_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_BORDER_WIDTH",
#     "value" : 2.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_1",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_2",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_3",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_4",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_5",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_6",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_7",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_8",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_9",
#     "value" : "org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_1",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_2",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_3",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_4",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_5",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_6",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_7",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_8",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_POSITION_9",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_1",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_2",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_3",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_4",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_5",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_6",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_7",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_8",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMGRAPHICS_SIZE_9",
#     "value" : 50.0
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_1",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_1, name=Node Custom Paint 1)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_2",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_2, name=Node Custom Paint 2)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_3",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_3, name=Node Custom Paint 3)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_4",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_4, name=Node Custom Paint 4)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_5",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_5, name=Node Custom Paint 5)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_6",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_6, name=Node Custom Paint 6)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_7",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_7, name=Node Custom Paint 7)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_8",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_8, name=Node Custom Paint 8)"
#   }, {
#     "visualProperty" : "NODE_CUSTOMPAINT_9",
#     "value" : "DefaultVisualizableVisualProperty(id=NODE_CUSTOMPAINT_9, name=Node Custom Paint 9)"
#   }, {
#     "visualProperty" : "NODE_DEPTH",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_FILL_COLOR",
#     "value" : "#F7FBFF"
#   }, {
#     "visualProperty" : "NODE_HEIGHT",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_LABEL",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_LABEL_COLOR",
#     "value" : "#000000"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_FACE",
#     "value" : "SansSerif.plain,plain,12"
#   }, {
#     "visualProperty" : "NODE_LABEL_FONT_SIZE",
#     "value" : 12
#   }, {
#     "visualProperty" : "NODE_LABEL_POSITION",
#     "value" : "C,C,c,0.00,0.00"
#   }, {
#     "visualProperty" : "NODE_LABEL_ROTATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_LABEL_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_LABEL_WIDTH",
#     "value" : 200.0
#   }, {
#     "visualProperty" : "NODE_NESTED_NETWORK_IMAGE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_PAINT",
#     "value" : "#1E90FF"
#   }, {
#     "visualProperty" : "NODE_SELECTED",
#     "value" : false
#   }, {
#     "visualProperty" : "NODE_SELECTED_PAINT",
#     "value" : "#FFFF00"
#   }, {
#     "visualProperty" : "NODE_SHAPE",
#     "value" : "ROUND_RECTANGLE"
#   }, {
#     "visualProperty" : "NODE_SIZE",
#     "value" : 35.0
#   }, {
#     "visualProperty" : "NODE_TOOLTIP",
#     "value" : ""
#   }, {
#     "visualProperty" : "NODE_TRANSPARENCY",
#     "value" : 255
#   }, {
#     "visualProperty" : "NODE_VISIBLE",
#     "value" : true
#   }, {
#     "visualProperty" : "NODE_WIDTH",
#     "value" : 75.0
#   }, {
#     "visualProperty" : "NODE_X_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Y_LOCATION",
#     "value" : 0.0
#   }, {
#     "visualProperty" : "NODE_Z_LOCATION",
#     "value" : 0.0
#   } ],
#   "mappings" : [ {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_SHAPE",
#     "map" : [ {
#       "key" : "PlantCoding",
#       "value" : "ELLIPSE"
#     }, {
#       "key" : "ForeignAbiotic",
#       "value" : "RECTANGLE"
#     }, {
#       "key" : "Metabolite",
#       "value" : "DIAMOND"
#     }, {
#       "key" : "PlantNonCoding",
#       "value" : "HEXAGON"
#     }, {
#       "key" : "Process",
#       "value" : "ROUND_RECTANGLE"
#     }, {
#       "key" : "PlantAbstract",
#       "value" : "OCTAGON"
#     }, {
#       "key" : "Complex",
#       "value" : "ROUND_RECTANGLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_LINE_TYPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "DASH_DOT"
#     }, {
#       "key" : "binding",
#       "value" : "LONG_DASH"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_SOURCE_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_WIDTH",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "60.0"
#     }, {
#       "key" : "Process",
#       "value" : "100.0"
#     }, {
#       "key" : "Complex",
#       "value" : "80.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "node_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_HEIGHT",
#     "map" : [ {
#       "key" : "Metabolite",
#       "value" : "50.0"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "pathway",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_FILL_COLOR",
#     "map" : [ {
#       "key" : "Hormone - Peptides",
#       "value" : "#D0D4E3"
#     }, {
#       "key" : "Secondary metabolism - Terpenoids",
#       "value" : "#ECF4C2"
#     }, {
#       "key" : "Signalling - Perception and resistance genes",
#       "value" : "#F8EABD"
#     }, {
#       "key" : "Signalling - Other",
#       "value" : "#FBEDB7"
#     }, {
#       "key" : "Degradation - Autophagy",
#       "value" : "#B3E2CD"
#     }, {
#       "key" : "Hormone - Gibberellin (GA)",
#       "value" : "#E5D1C9"
#     }, {
#       "key" : "Hormone - Cytokinins (CK)",
#       "value" : "#FACDB0"
#     }, {
#       "key" : "Stress - Heat",
#       "value" : "#D4D1CC"
#     }, {
#       "key" : "Hormone - Strigolactones (SL)",
#       "value" : "#D9D1E7"
#     }, {
#       "key" : "Regulation - Silencing",
#       "value" : "#F1D2DF"
#     }, {
#       "key" : "Signalling - Reactive oxygen species (ROS)",
#       "value" : "#F5E6C4"
#     }, {
#       "key" : "Hormone - Brassinosteroids (BS)",
#       "value" : "#F2D0B1"
#     }, {
#       "key" : "Hormone - Salicylic acid (SA)",
#       "value" : "#D0D4E8"
#     }, {
#       "key" : "Stress - Waterlogging",
#       "value" : "#CCCCCC"
#     }, {
#       "key" : "Signalling - Growth",
#       "value" : "#F7F3B7"
#     }, {
#       "key" : "Stress - Biotic",
#       "value" : "#E4DACC"
#     }, {
#       "key" : "Primary metabolism - Amino-acids",
#       "value" : "#E1CFE6"
#     }, {
#       "key" : "Hormone - Auxins (AUX)",
#       "value" : "#E2D5B8"
#     }, {
#       "key" : "Primary metabolism - Photosynthesis",
#       "value" : "#EACDE5"
#     }, {
#       "key" : "Signalling - Calcium",
#       "value" : "#F1F4BD"
#     }, {
#       "key" : "Secondary metabolism - Alkaloids",
#       "value" : "#E9EDCE"
#     }, {
#       "key" : "Hormone - Ethylene (ET)",
#       "value" : "#EFCFBC"
#     }, {
#       "key" : "Hormone - Jasmonate (JA)",
#       "value" : "#DAD3D6"
#     }, {
#       "key" : "Degradation - Ubiquitination",
#       "value" : "#C3DEC6"
#     }, {
#       "key" : "Regulation - Transport",
#       "value" : "#ECE4D4"
#     }, {
#       "key" : "Regulation - Transcription & Translation",
#       "value" : "#EEDBD9"
#     }, {
#       "key" : "Signalling - Heat-shock proteins (HSPs)",
#       "value" : "#FCF2B1"
#     }, {
#       "key" : "Secondary metabolism - Anthocyanins",
#       "value" : "#E7F5C8"
#     }, {
#       "key" : "Signalling - Senescence",
#       "value" : "#F2E3CA"
#     }, {
#       "key" : "Primary metabolism - Respiration",
#       "value" : "#F3CAE4"
#     }, {
#       "key" : "Stress - Drought",
#       "value" : "#DCD5CC"
#     }, {
#       "key" : "Hormone - Abscisic acid (ABA)",
#       "value" : "#D2D9BF"
#     }, {
#       "key" : "Signalling - MAP kinases (MAPKs)",
#       "value" : "#FEF1B1"
#     }, {
#       "key" : "Signalling - Tuberisation",
#       "value" : "#EBDFCC"
#     } ]
#   }, {
#     "mappingType" : "discrete",
#     "mappingColumn" : "interaction_type",
#     "mappingColumnType" : "String",
#     "visualProperty" : "EDGE_TARGET_ARROW_SHAPE",
#     "map" : [ {
#       "key" : "translocation",
#       "value" : "CROSS_OPEN_DELTA"
#     }, {
#       "key" : "binding",
#       "value" : "CIRCLE"
#     }, {
#       "key" : "inhibition",
#       "value" : "T"
#     }, {
#       "key" : "activation",
#       "value" : "ARROW"
#     } ]
#   }, {
#     "mappingType" : "passthrough",
#     "mappingColumn" : "display_label",
#     "mappingColumnType" : "String",
#     "visualProperty" : "NODE_LABEL"
#   } ]
# }
# DEBUG:py4...:ǀReturning 'cyrest_get': {'title': 'PSS-default', 'defaults': [{'visualProperty': 'COMPOUND_NODE_PADDING', 'value': 10.0}, {'visualProperty': 'COMPOUND_NODE_SHAPE', 'value': 'ROUND_RECTANGLE'}, {'visualProperty': 'DING_RENDERING_ENGINE_ROOT', 'value': 'org.cytoscape.view.presentation.property.NullVisualProperty$NullDataTypeImpl@13ea9bc9'}, {'visualProperty': 'EDGE', 'value': 'DefaultVisualizableVisualProperty(id=EDGE, name=Edge Visual Property)'}, {'visualProperty': 'EDGE_BEND', 'value': ''}, {'visualProperty': 'EDGE_CURVED', 'value': True}, {'visualProperty': 'EDGE_LABEL', 'value': ''}, {'visualProperty': 'EDGE_LABEL_COLOR', 'value': '#000000'}, {'visualProperty': 'EDGE_LABEL_FONT_FACE', 'value': 'Dialog.plain,plain,10'}, {'visualProperty': 'EDGE_LABEL_FONT_SIZE', 'value': 10}, {'visualProperty': 'EDGE_LABEL_ROTATION', 'value': 0.0}, {'visualProperty': 'EDGE_LABEL_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_LABEL_WIDTH', 'value': 200.0}, {'visualProperty': 'EDGE_LINE_TYPE', 'value': 'SOLID'}, {'visualProperty': 'EDGE_PAINT', 'value': '#323232'}, {'visualProperty': 'EDGE_SELECTED', 'value': False}, {'visualProperty': 'EDGE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_SOURCE_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_SOURCE_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_STACKING', 'value': 'AUTO_BEND'}, {'visualProperty': 'EDGE_STACKING_DENSITY', 'value': 0.5}, {'visualProperty': 'EDGE_STROKE_SELECTED_PAINT', 'value': '#FF0000'}, {'visualProperty': 'EDGE_STROKE_UNSELECTED_PAINT', 'value': '#848484'}, {'visualProperty': 'EDGE_TARGET_ARROW_SELECTED_PAINT', 'value': '#FFFF00'}, {'visualProperty': 'EDGE_TARGET_ARROW_SHAPE', 'value': 'NONE'}, {'visualProperty': 'EDGE_TARGET_ARROW_SIZE', 'value': 6.0}, {'visualProperty': 'EDGE_TARGET_ARROW_UNSELECTED_PAINT', 'value': '#000000'}, {'visualProperty': 'EDGE_TOOLTIP', 'value': ''}, {'visualProperty': 'EDGE_TRANSPARENCY', 'value': 255}, {'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#525252'}, {'visualProperty': 'EDGE_VISIBLE', 'value': True}, {'visualProperty': 'EDGE_WIDTH', 'value': 2.0}, {'visualProperty': 'EDGE_Z_ORDER', 'value': 0.0}, {'visualProperty': 'NETWORK', 'value': 'DefaultVisualizableVisualProperty(id=NETWORK, name=Network Visual Property)'}, {'visualProperty': 'NETWORK_ANNOTATION_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_BACKGROUND_PAINT', 'value': '#FFFFFF'}, {'visualProperty': 'NETWORK_CENTER_X_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Y_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_CENTER_Z_LOCATION', 'value': 0.0}, {'visualProperty': 'NETWORK_DEPTH', 'value': 0.0}, {'visualProperty': 'NETWORK_EDGE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_FORCE_HIGH_DETAIL', 'value': False}, {'visualProperty': 'NETWORK_HEIGHT', 'value': 400.0}, {'visualProperty': 'NETWORK_NODE_LABEL_SELECTION', 'value': False}, {'visualProperty': 'NETWORK_NODE_SELECTION', 'value': True}, {'visualProperty': 'NETWORK_SCALE_FACTOR', 'value': 1.0}, {'visualProperty': 'NETWORK_SIZE', 'value': 550.0}, {'visualProperty': 'NETWORK_TITLE', 'value': ''}, {'visualProperty': 'NETWORK_WIDTH', 'value': 550.0}, {'visualProperty': 'NODE', 'value': 'DefaultVisualizableVisualProperty(id=NODE, name=Node Visual Property)'}, {'visualProperty': 'NODE_BORDER_PAINT', 'value': '#CCCCCC'}, {'visualProperty': 'NODE_BORDER_STROKE', 'value': 'SOLID'}, {'visualProperty': 'NODE_BORDER_TRANSPARENCY', 'value': 255}, {'visualProperty': 'NODE_BORDER_WIDTH', 'value': 2.0}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_1', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_2', 'value': 'org.cytoscape.cg.model.NullCustomGraphics,0,[ Remove Graphics ],'}, {'visualProperty': 'NODE_CUSTOMGRAPHICS_3', 'value': ' ...
# DEBUG:py4...:Returning 'get_current_style': 'PSS-default'
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling select_nodes(['PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1]', 'SA', 'MYC2[AT1G32640]', 'NPR1[AT1G64280]', 'SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1]', 'AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000]', 'RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1]', 'PYL[AT1G01360\\,AT2G40330]'], by_col='name', network=None)
# DEBUG:py4...:ǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀCalling commands_post('network select network=SUID:"374660" nodeList="name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:SA,name:MYC2[AT1G32640],name:NPR1[AT1G64280],name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:PYL[AT1G01360\\,AT2G40330]"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/select), json: {'network': 'SUID:374660', 'nodeList': 'name:PP2C[AT3G11410\\,SOLTU.DM.03G012480.1\\,SOLTU.DM.06G031720.1\\,SOTUB03G021270.1.1\\,SOTUB06G032210.1.1],name:SA,name:MYC2[AT1G32640],name:NPR1[AT1G64280],name:SNRK2[AT1G10940\\,AT1G78290\\,AT4G33950\\,SOTUB02G032470.1.1],name:AREB/ABF[AT1G45249\\,AT1G49720\\,AT3G19290\\,AT4G34000],name:RD29[AT5G52300\\,AT5G52310\\,SOTUB03G014340.1.1],name:PYL[AT1G01360\\,AT2G40330]'}
# DEBUG:py4...:ǀOK[200], content: {
#  "data": {"nodes":[
#   375924,
#   374703,
#   374799,
#   375906,
#   374700,
#   375150,
#   374856,
#   374919
# ], "edges":[
#   376068,
#   377124,
#   377283,
#   376470,
#   376662,
#   377061,
#   377040,
#   378048,
#   376095,
#   377439,
#   376065
# ]},
#  "errors":[]
# }
# DEBUG:py4...:ǀReturning 'commands_post': {'nodes': [375924, 374703, 374799, 375906, 374700, 375150, 374856, 374919], 'edges': [376068, 377124, 377283, 376470, 376662, 377061, 377040, 378048, 376095, 377439, 376065]}
# DEBUG:py4...:Returning 'select_nodes': {'nodes': [375924, 374703, 374799, 375906, 374700, 375150, 374856, 374919], 'edges': [376068, 377124, 377283, 376470, 376662, 377061, 377040, 378048, 376095, 377439, 376065]}
# DEBUG:py4...:--------------------
# DEBUG:py4...:Calling set_node_color_bypass(node_names=[375924, 374703, 374799, 375906, 374700, 375150, 374856, 374919], new_colors='#34858d', network=None)
# DEBUG:py4...:ǀCalling set_node_property_bypass([375924, 374703, 374799, 375906, 374700, 375150, 374856, 374919], '#34858d', 'NODE_FILL_COLOR', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀCalling get_network_views(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(374660, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [3009,374660,4421,23045,26760,101064,34571,353224,99599,7119,24399,4880,356117,34513,33875,34259,11668,31318,34455,600,5017,33753,34201,34397,353368,71455,3361,5218,14178,101283,33831,38506,26923,27307,22380,3053,93420,98860,26992,2931,100914,26804,16567,26682,95163,4156,12479]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [3009, 374660, 4421, 23045, 26760, 101064, 34571, 353224, 99599, 7119, 24399, 4880, 356117, 34513, 33875, 34259, 11668, 31318, 34455, 600, 5017, 33753, 34201, 34397, 353368, 71455, 3361, 5218, 14178, 101283, 33831, 38506, 26923, 27307, 22380, 3053, 93420, 98860, 26992, 2931, 100914, 26804, 16567, 26682, 95163, 4156, 12479]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling cyrest_get('networks/374660/views', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/views)
# DEBUG:py4...:ǀǀǀOK[200], content: [379352]
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': [379352]
# DEBUG:py4...:ǀǀReturning 'get_network_views': [379352]
# DEBUG:py4...:ǀǀCalling get_table_columns('node', ['name'], 'default', None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀCalling get_network_suid(None, 'http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀCalling get_table_column_types('node', namespace='default', network=None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀCalling get_network_suid(None, base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀCalling commands_post('network get attribute network="current" namespace="default" columnList="SUID"', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀǀHTTP POST(http://127.0.0.1:1234/v1/commands/network/get%20attribute), json: {'network': 'current', 'namespace': 'default', 'columnList': 'SUID'}
# DEBUG:py4...:ǀǀǀǀǀOK[200], content: {
#  "data": [ {
#   "SUID": 374660
# }
# ],
#  "errors":[]
# }
# DEBUG:py4...:ǀǀǀǀǀReturning 'commands_post': [{'SUID': 374660}]
# DEBUG:py4...:ǀǀǀǀReturning 'get_network_suid': 374660
# DEBUG:py4...:ǀǀǀǀCalling cyrest_get('networks/374660/tables/defaultnode/columns', base_url='http://127.0.0.1:1234/v1')
# DEBUG:py4...:ǀǀǀǀHTTP GET(http://127.0.0.1:1234/v1/networks/374660/tables/defaultnode/columns)
# DEBUG:py4...:ǀǀǀǀOK[200], content: [{"name":"SUID","type":"Long","immutable":true,"primaryKey":true},{"name":"shared name","type":"String","immutable":true,"primaryKey":false},{"name":"name","type":"String","immutable":true,"primaryKey":false},{"name":"selected","type":"Boolean","immutable":true,"primaryKey":false},{"name":"id","type":"String","immutable":false,"primaryKey":false},{"name":"node_type","type":"String","immutable":false,"primaryKey":false},{"name":"short_name","type":"String","immutable":false,"primaryKey":false},{"name":"functional_cluster_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_id","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_type","type":"String","immutable":false,"primaryKey":false},{"name":"reaction_effect","type":"String","immutable":false,"primaryKey":false},{"name":"additional_information","type":"String","immutable":false,"primaryKey":false},{"name":"pathway","type":"String","immutable":false,"primaryKey":false},{"name":"all_pathways","type":"String","immutable":false,"primaryKey":false},{"name":"description","type":"String","immutable":false,"primaryKey":false},{"name":"evidence_sentence","type":"String","immutable":false,"primaryKey":false},{"name":"experimental_techniques","type":"String","immutable":false,"primaryKey":false},{"name":"external_links","type":"String","immutable":false,"primaryKey":false},{"name":"family","type":"String","immutable":false,"primaryKey":false},{"name":"function","type":"String","immutable":false,"primaryKey":false},{"name":"classification","type":"String","immutable":false,"primaryKey":false},{"name":"components","type":"String","immutable":false,"primaryKey":false},{"name":"ath_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"nta_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"osa_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"stu_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"sly_homologues","type":"String","immutable":false,"primaryKey":false},{"name":"display_label","type":"String","immutable":false,"primaryKey":false}]
# DEBUG:py4...:ǀǀǀǀReturning 'cyrest_get': [{'name': 'SUID', 'type': 'Long', 'immutable': True, 'primaryKey': True}, {'name': 'shared name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'name', 'type': 'String', 'immutable': True, 'primaryKey': False}, {'name': 'selected', 'type': 'Boolean', 'immutable': True, 'primaryKey': False}, {'name': 'id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'node_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'short_name', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'functional_cluster_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_id', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_type', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'reaction_effect', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'additional_information', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'pathway', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'all_pathways', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'description', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'evidence_sentence', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'experimental_techniques', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'external_links', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'family', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'function', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'classification', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'components', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'ath_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'nta_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'osa_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 'stu_homologues', 'type': 'String', 'immutable': False, 'primaryKey': False}, {'name': 
HK2,3,4[AT1G27320,AT2G01830,AT5G35750]","NPR4[AT4G19660] (interacts with) NPR1[AT1G64280]","DZ-riboside (interacts with) DZ","RAPTOR2[AT3G08850,AT5G01770] (interacts with) TORC1","NPR3[AT5G45110] (interacts with) NPR1[AT1G64280]","tZ (interacts with) tZ-glucoside","Trp (interacts with) IAM","Trp (interacts with) IPA","MKD1[AT5G11850] (interacts with) MKK1[AT4G26070]","tZ (interacts with) tZ-riboside","IAM (interacts with) IAA","DZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]","tZ (interacts with) tZ-ribotide","AHK2,3,4[AT1G27320,AT2G01830,AT5G35750] (interacts with) AHP[AT1G03430,AT1G80100,AT3G16360,AT3G21510,AT3G29350,AT5G39340]","Trp (interacts with) IAOx","DZ (interacts with) DZ-riboside","DZ (interacts with) DZ-ribotide","SARD1[AT1G73805] (interacts with) TCP8[AT1G58100]","DZ (interacts with) DZ-glucosides","iaaM[unknown] (interacts with) IAM","SARD1[AT1G73805] (interacts with) ICS[AT1G18870,AT1G74710]","iP (interacts with) iP-riboside","S-alkyl-thiohydroximate (interacts with) Thiohydroximate","SUR1[AT2G20610] (interacts with) Thiohydroximate","SARD1[AT1G73805] (interacts with) SARD1|TCP8","iP (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]","MVA (interacts with) 5-phosphomevalonate","L-Met (interacts with) SAMe","iP (interacts with) iP-glucosides","iP (interacts with) iP-ribotide","OSCA1.3[AT1G11960] (interacts with) Ca2+","SAMe (interacts with) SAH","NIMIN[AT1G02450,AT1G09415,AT3G25882] (interacts with) NPR1[AT1G64280]","TCP8[AT1G58100] (interacts with) SARD1[AT1G73805]","SAMe (interacts with) ACC","MVK[AT5G27450] (interacts with) 5-phosphomevalonate","TCP8[AT1G58100] (interacts with) ICS[AT1G18870,AT1G74710]","ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC","TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]","TCP8[AT1G58100] (interacts with) TCP8|WRKY28","TCP8[AT1G58100] (interacts with) SARD1|TCP8","ACC (interacts with) ET","TCP8[AT1G58100] (interacts with) NAC019|TCP8","ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET","ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]","ET (interacts with) ET|ETR","TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]","ALA (interacts with) 13-HPOT","ROS (interacts with) MDA","IAA (interacts with) IAA-Asp","ALA (interacts with) MDA","IAA-Ala (interacts with) IAA","IAA (interacts with) IAA-Glu","ROS (interacts with) GRX480[AT1G28480]","IAR[AT1G51760,AT1G68100] (interacts with) IAA","IPA (interacts with) IAA","IAA (interacts with) TIR1[AT3G62980]","ROS (interacts with) TRX-H[AT1G45145,AT5G42980]","BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]","Ile (interacts with) JA-Ile","ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]","Thr (interacts with) Ile","TAA1[AT1G70560] (interacts with) IPA","13-HPOT (interacts with) 12,13-EOT","LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT","Brassinolide (interacts with) BAK1|BRI1","OMR1[AT3G10050] (interacts with) Ile","BRI1[AT4G3 ...
# DEBUG:py4...:ǀǀǀReturning 'cyrest_get': {'name': 'name', 'values': ['cZ (interacts with) cZ-ribotide', 'Glu (interacts with) cZ-glucosides', 'GH3[AT2G47750,AT4G27260] (interacts with) IAA-Asp', 'cZ (interacts with) cZ-riboside', 'TOR[AT1G50030] (interacts with) TORC1', 'GH3[AT2G47750,AT4G27260] (interacts with) SA-Asp', 'Glu (interacts with) tZ-glucoside', 'LST8[AT2G22040,AT3G18140] (interacts with) RAPTOR2[AT3G08850,AT5G01770]', 'LST8[AT2G22040,AT3G18140] (interacts with) TORC1', 'LST8[AT2G22040,AT3G18140] (interacts with) TOR[AT1G50030]', 'Glu (interacts with) DZ-glucosides', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) LST8[AT2G22040,AT3G18140]', 'DZ-riboside (interacts with) DZ-ribotide', 'Glu (interacts with) iP-glucosides', 'Glu (interacts with) IsoChor-9-Glu', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) TOR[AT1G50030]', 'DZ-ribotide (interacts with) DZ-riboside', 'tZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'NPR4[AT4G19660] (interacts with) NPR1[AT1G64280]', 'DZ-riboside (interacts with) DZ', 'RAPTOR2[AT3G08850,AT5G01770] (interacts with) TORC1', 'NPR3[AT5G45110] (interacts with) NPR1[AT1G64280]', 'tZ (interacts with) tZ-glucoside', 'Trp (interacts with) IAM', 'Trp (interacts with) IPA', 'MKD1[AT5G11850] (interacts with) MKK1[AT4G26070]', 'tZ (interacts with) tZ-riboside', 'IAM (interacts with) IAA', 'DZ (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'tZ (interacts with) tZ-ribotide', 'AHK2,3,4[AT1G27320,AT2G01830,AT5G35750] (interacts with) AHP[AT1G03430,AT1G80100,AT3G16360,AT3G21510,AT3G29350,AT5G39340]', 'Trp (interacts with) IAOx', 'DZ (interacts with) DZ-riboside', 'DZ (interacts with) DZ-ribotide', 'SARD1[AT1G73805] (interacts with) TCP8[AT1G58100]', 'DZ (interacts with) DZ-glucosides', 'iaaM[unknown] (interacts with) IAM', 'SARD1[AT1G73805] (interacts with) ICS[AT1G18870,AT1G74710]', 'iP (interacts with) iP-riboside', 'S-alkyl-thiohydroximate (interacts with) Thiohydroximate', 'SUR1[AT2G20610] (interacts with) Thiohydroximate', 'SARD1[AT1G73805] (interacts with) SARD1|TCP8', 'iP (interacts with) AHK2,3,4[AT1G27320,AT2G01830,AT5G35750]', 'MVA (interacts with) 5-phosphomevalonate', 'L-Met (interacts with) SAMe', 'iP (interacts with) iP-glucosides', 'iP (interacts with) iP-ribotide', 'OSCA1.3[AT1G11960] (interacts with) Ca2+', 'SAMe (interacts with) SAH', 'NIMIN[AT1G02450,AT1G09415,AT3G25882] (interacts with) NPR1[AT1G64280]', 'TCP8[AT1G58100] (interacts with) SARD1[AT1G73805]', 'SAMe (interacts with) ACC', 'MVK[AT5G27450] (interacts with) 5-phosphomevalonate', 'TCP8[AT1G58100] (interacts with) ICS[AT1G18870,AT1G74710]', 'ACS[AT1G01480,AT2G22810,AT3G49700,AT3G61510,AT4G08040,AT4G11280,AT4G26200,AT4G37770,AT5G65800] (interacts with) ACC', 'TCP8[AT1G58100] (interacts with) WRKY28[AT4G18170]', 'TCP8[AT1G58100] (interacts with) TCP8|WRKY28', 'TCP8[AT1G58100] (interacts with) SARD1|TCP8', 'ACC (interacts with) ET', 'TCP8[AT1G58100] (interacts with) NAC019|TCP8', 'ACO[AT1G05010,AT1G12010,AT1G62380,AT1G77330,AT2G19590,SOTUB07G018820.1.1] (interacts with) ET', 'ET (interacts with) ETR[AT1G04310,AT1G66340,AT2G40940,AT3G04580,AT3G23150]', 'ET (interacts with) ET|ETR', 'TCP8[AT1G58100] (interacts with) NAC019[AT1G52890]', 'ALA (interacts with) 13-HPOT', 'ROS (interacts with) MDA', 'IAA (interacts with) IAA-Asp', 'ALA (interacts with) MDA', 'IAA-Ala (interacts with) IAA', 'IAA (interacts with) IAA-Glu', 'ROS (interacts with) GRX480[AT1G28480]', 'IAR[AT1G51760,AT1G68100] (interacts with) IAA', 'IPA (interacts with) IAA', 'IAA (interacts with) TIR1[AT3G62980]', 'ROS (interacts with) TRX-H[AT1G45145,AT5G42980]', 'BRI1[AT4G39400] (interacts with) BAK1[AT4G33430]', 'Ile (interacts with) JA-Ile', 'ROS (interacts with) GST[AT1G02920,AT1G02930,AT1G17170,AT2G02930,AT2G47730,AT4G02520]', 'Thr (interacts with) Ile', 'TAA1[AT1G70560] (interacts with) IPA', '13-HPOT (interacts with) 12,13-EOT', 'LOX[AT1G17420,AT1G55020,AT1G67560,AT1G72520,AT3G22400,AT3G45140,SOTUB03G034620.1.1] (interacts with) 13-HPOT', ' ...
# DEBUG:py4...:ǀǀReturning 'get_table_columns':                                                      name
# 376836                    cZ (interacts with) cZ-ribotide
# 376839                 Glu (interacts with) cZ-glucosides
# 377862  GH3[AT2G47750,AT4G27260] (interacts with) IAA-Asp
# 376833                    cZ (interacts with) cZ-riboside
# 377856              TOR[AT1G50030] (interacts with) TORC1
# ...                                                   ...
# 377853  TOR[AT1G50030] (interacts with) RAPTOR2[AT3G08...
# 376830  cZ (interacts with) AHK2,3,4[AT1G27320,AT2G018...
# 376824  UGT[AT1G22400,AT2G36750,AT2G36800,AT5G05860,AT...
# 376827                  cZ (interacts with) cZ-glucosides
# 377850  TOR[AT1G50030] (interacts with) LST8[AT2G22040...
#
# [707 rows x 1 columns]
# DEBUG:py4...:ǀǀCalling cyrest_put('networks/374660/views/379352/edges', parameters={'bypass': True}, body=[{'SUID': '376500', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376353', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376503', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376506', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}], base_url='http://127.0.0.1:1234/v1', require_json=False)
# DEBUG:py4...:ǀǀHTTP PUT(http://127.0.0.1:1234/v1/networks/374660/views/379352/edges), params: {'bypass': True}, json: [{'SUID': '376500', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376353', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376503', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}, {'SUID': '376506', 'view': [{'visualProperty': 'EDGE_UNSELECTED_PAINT', 'value': '#34858d'}]}]
# DEBUG:py4...:ǀǀOK[200], content:
# DEBUG:py4...:ǀǀReturning 'cyrest_put': ''
# DEBUG:py4...:ǀReturning 'set_edge_property_bypass': ''
# DEBUG:py4...:Returning 'set_edge_color_bypass': ''
# DEBUG:py4...:--------------------

# %% [markdown]
# At this point, the Cytoscape session has a network view of the filtered PSS, and highlighting of the paths we extracted from our targeted searches.

# %% [markdown]
# ## Extract subnetworks in Cytoscape
#
# Properly inspecting the identified paths is a bit hard within the complete network, so here we pull out the subnetworks of and surrounding the paths.

# %% [markdown]
# ### The edge induced network
# The first, and smallest network, is created by extracting only the edges that are present on the paths.

# %%
network_edge_induced_suid = cytoscape_utils.subnetwork_edge_induced_from_paths(
    paths=ABA_RD29_paths + JA_paths + SA_paths,
    g=g,
    parent_suid=pss_network_suid,
    name="identified paths (edge induced)",
)

# %% [markdown]
# We apply a new layout to this subnetwork

# %%
_ = p4c.layouts.layout_network('cose', network=network_edge_induced_suid)

# %% [markdown]
# ### The node induced network
#
# Now we extract the network based on the nodes along the paths, meaning any edges between those nodes that are not on the paths are also extracted.

# %%
nodes = list(set([y for x in ABA_RD29_paths + JA_paths + SA_paths for y in x]))

# %%
network_node_induced_suid = cytoscape_utils.subnetwork_node_induced(
    nodes=nodes,
    g=g,
    parent_suid=pss_network_suid,
    name="identified paths (node induced)",
)

# %% [markdown]
# Instead of applying a network layout algorithm, we can copy the layout from the previous subnetwork.

# %%
_ = p4c.layouts.layout_copycat(
    network_edge_induced_suid,
    network_node_induced_suid
)

# %% [markdown]
# ### Neighbours
#
# For more context around our paths, we can include the first neighbours in the view. We can use the Cytoscape first neighbour seletion functionality.

# %%
network_neighbours_suid = cytoscape_utils.subnetwork_neighbouts(
    nodes=nodes,
    g=g,
    parent_suid=pss_network_suid,
    name="identified paths + 1st neighbours",
)

# %%
_ = p4c.layouts.layout_network('cose', network=network_neighbours_suid)

# %% [markdown]
# This network (with manual layout improvements and removal of unrelated nodes) is shown in Figure 3 of the article.

# %% [markdown]
# ### Filtered neighbours
#
# There are many neighbours displayed now, and we are perhaps only interested in the ones that are connected to at least two of the original path nodes, so we can make a filter using networkX neighbour functions.

# %%
filtered_neighbours = []
for n in g.nodes():
    if (len([x for x in nx.MultiGraph(g).neighbors(n) if (x in done_nodes)]) > 1) and (n not in done_nodes):
        filtered_neighbours.append(n)

# %%
network_neighbours_filtered_suid = cytoscape_utils.subnetwork_node_induced(
    nodes=nodes+filtered_neighbours,
    g=g,
    parent_suid=pss_network_suid,
    name="identified paths + 1st neighbours (filtered)",
)

# %%
p4c.layouts.layout_copycat(
    network_edge_induced_suid,
    network_neighbours_filtered_suid
)
# Out:
# {'mappedNodeCount': 13, 'unmappedNodeCount': 5}

# %%
# END
