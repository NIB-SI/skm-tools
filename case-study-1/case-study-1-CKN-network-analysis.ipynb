# %%
from IPython.display import display, Markdown, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#CKN-paths-for-case-1-(ABA/RD29)" data-toc-modified-id="CKN-paths-for-case-1-(ABA/RD29)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>CKN paths for case 1 (ABA/RD29)</a></span><ul class="toc-item"><li><span><a href="#Description" data-toc-modified-id="Description-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Description</a></span></li></ul></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Library-import" data-toc-modified-id="Library-import-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Library import</a></span></li><li><span><a href="#Handy-functions" data-toc-modified-id="Handy-functions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Handy functions</a></span></li><li><span><a href="#Path-and-parameter-definitions" data-toc-modified-id="Path-and-parameter-definitions-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Path and parameter definitions</a></span></li><li><span><a href="#Load-CKN" data-toc-modified-id="Load-CKN-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Load CKN</a></span></li><li><span><a href="#Filtering" data-toc-modified-id="Filtering-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Filtering</a></span><ul class="toc-item"><li><span><a href="#Filtering-node-types" data-toc-modified-id="Filtering-node-types-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Filtering node types</a></span></li><li><span><a href="#Filtering-edge-ranks" data-toc-modified-id="Filtering-edge-ranks-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Filtering edge ranks</a></span></li></ul></li></ul></li><li><span><a href="#Path-extraction" data-toc-modified-id="Path-extraction-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Path extraction</a></span><ul class="toc-item"><li><span><a href="#ABA--->-RD29" data-toc-modified-id="ABA--->-RD29-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>ABA --&gt; RD29</a></span></li><li><span><a href="#JA--->-RD29" data-toc-modified-id="JA--->-RD29-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>JA --&gt; RD29</a></span></li><li><span><a href="#SA--->-RD29" data-toc-modified-id="SA--->-RD29-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SA --&gt; RD29</a></span></li></ul></li><li><span><a href="#Context-graph" data-toc-modified-id="Context-graph-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Context graph</a></span><ul class="toc-item"><li><span><a href="#Node-prioritisation" data-toc-modified-id="Node-prioritisation-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Node prioritisation</a></span></li></ul></li><li><span><a href="#Cytoscape" data-toc-modified-id="Cytoscape-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Cytoscape</a></span><ul class="toc-item"><li><span><a href="#Case-study-complete-context" data-toc-modified-id="Case-study-complete-context-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Case study complete context</a></span></li><li><span><a href="#ABA--->-RD29" data-toc-modified-id="ABA--->-RD29-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ABA --&gt; RD29</a></span></li><li><span><a href="#JA--(ABA)->-RD29" data-toc-modified-id="JA--(ABA)->-RD29-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>JA -(ABA)-&gt; RD29</a></span></li><li><span><a href="#SA--(ABA)->-RD29" data-toc-modified-id="SA--(ABA)->-RD29-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>SA -(ABA)-&gt; RD29</a></span></li><li><span><a href="#Export-networks-to-PDF" data-toc-modified-id="Export-networks-to-PDF-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Export networks to PDF</a></span></li></ul></li></ul></div>

# %% [markdown]
# # CKN paths for case 1 (ABA/RD29)
#
# ## Description
#
#
# This notebook contains the analysis of CKN for the first use case of the SKM publication.
#
# Experimental results showed that ABA is able to induce expression of RD29 in both arabidopsis and potato plants. However, the addition of SA or JA showed attenuation of this induction (while alone they had no effect).
#
# Here, we interogate the CKN network of stress signalling to identify potential points of intersection between the ABA activation of RD29 and SA or JA pathways, to identify potential mechanistic explainations of the observed experimental results.

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries
#
# The non-default libraries are networkX (https://networkx.org/) and py4cytoscape (https://py4cytoscape.readthedocs.io/, only necessary if you wish to view the results in Cytoscape).
#
# You will also need the skm-tools package provided in the same repository as this notebook.

# %%
import sys, re
from pathlib import Path
from datetime import datetime
from IPython.display import Markdown, display
from collections import defaultdict

import pandas as pd

import networkx as nx

# %%
from importlib import reload

# %% [markdown]
# The following allows us to import functions from the skm-tools package.
# Note the relative path to the folder containing the
# "skm-tools" directory.

# %%
sys.path.append("../")
from skm_tools import load_networks, ckn_utils

# %% [markdown]
# ## Handy functions

# %%
# allows viewing colour codes within a notebook
def swatches(colors, sep=' ', width=6):
    display(Markdown(sep.join(
        f'<span style="font-family: monospace">{color} <span style="color: {color}">{chr(9608)*width}</span></span>'
        for color in colors
    )))

# %%
today = datetime.today().strftime('%Y.%m.%d'); today
# Out:
# '2023.08.18'

# %% [markdown]
# ## Path and parameter definitions

# %%
base_dir = Path("./")
data_dir = base_dir / "data"
output_dir = base_dir / "output"

# %%
ckn_edge_path = data_dir / "AtCKN-v2-2023.06.tsv.gz" 
ckn_node_path = data_dir / "AtCKN-v2-2023.06_node-annot.tsv.gz"

# %% [markdown]
# ## Load CKN

# %%
ckn = load_networks.ckn_to_networkx(
    edge_path=ckn_edge_path, 
    node_path=ckn_node_path
)

print(f"\nNumber of nodes: {ckn.number_of_nodes()}\nNumber of edges: {ckn.number_of_edges()}")
# Out:
# Number of nodes: 26234
# Number of edges: 898883

# %% [markdown]
# ## Filtering
#
# ### Filtering node types
# CKN contains some nodes that are not relevent to this study, such as viral proteins (foreign nodes).
#
# * ath – arabidopsis
# * foreign – e.ckn. bacteria, viral, external stress factors
# * ath/foreign – commplexes between ath and foreign
# * nan – species not applicable (e.ckn. metabolites)

# %%
# see the types of nodes present
species = set([data['species'] for n, data in ckn.nodes(data=True)])
species
# Out:
# {'ath', 'ath/foreign', 'foreign', nan}

# %% [markdown]
# Here, we remove them from the network.

# %%
# Define the types we want to keep
keep_species = species.difference(set(['ath/foreign', 'foreign']))
keep_species
# Out:
# {'ath', nan}

# %%
removed = ckn_utils.filter_ckn_nodes(ckn, species=keep_species, remove_isolates=True)
# Out:
# Removed 27 nodes from network.

# %% [markdown]
# You can inspect the `removed` object to see the nodes that were removed,
# and the reasons for the removal

# %%
removed
# Out:
# {'virus_VPg': 'wrong species',
#  'virus_CP': 'wrong species',
#  'virus_dsRNA': 'wrong species',
#  'AGO1|virus_CI': 'wrong species',
#  'RISC|virus_vsiRNA': 'wrong species',
#  'CML|virus_HC-Pro': 'wrong species',
#  'virus_P3': 'wrong species',
#  'virus_vsiRNA': 'wrong species',
#  'virus_me-vsiRNA': 'wrong species',
#  'BAK1|FLS2|bacteria_flg22': 'wrong species',
#  'bacteria_flg22': 'wrong species',
#  'ATPB|virus_HC-Pro': 'wrong species',
#  'R-gene|virus_PVY': 'wrong species',
#  'virus_PVY': 'wrong species',
#  'abiotic_drought': 'wrong species',
#  'abiotic_heat': 'wrong species',
#  'abiotic_waterlogging': 'wrong species',
#  'bacteria': 'wrong species',
#  'virus_6K2': 'wrong species',
#  'virus_CI': 'wrong species',
#  'virus_HC-Pro': 'wrong species',
#  'virus_P1': 'wrong species',
#  'virus_NIa-Pro': 'wrong species',
#  'virus_NIb': 'wrong species',
#  'AT2G24680': 'isolate',
#  'ath_o2-deficit': 'isolate',
#  'ribosome': 'isolate'}

# %%
print(f"\nNumber of nodes: {ckn.number_of_nodes()}\nNumber of edges: {ckn.number_of_edges()}")
# Out:
# Number of nodes: 26207
# Number of edges: 898707

# %% [markdown]
# ### Filtering edge ranks
#
# CKN edges are annotated with edge 'ranks', representing how reliability the edges are:
#
# * 0 – manually curated interactions from PSS,
# * 1 – literature curated interactions detected using targeted experimental methods (e.ckn. luciferase reporter assay, co-immunoprecipitation, enzymatic assays), sometimes complemented with high-throughput technologies,
# * 2 – interactions detected using high-throughput technologies (e.ckn. high throughput yeast two-hybrid, chromatin immunoprecipitation sequencing, degradome sequencing),
# * 3 – interactions extracted from literature (co-citation, but not text mining) or predicted in silico and additionally validated with data,
# * 4 – interactions predicted using purely in silico binding prediction algorithms.
#
# Below, we can count the number of edges fro each rank.

# %%
_ = ckn_utils.rank_counts(ckn)
# Out:
# rank 0:	 2,635
# rank 1:	 36,631
# rank 2:	 67,573
# rank 3:	 718,399
# rank 4:	 73,469

# %% [markdown]
# Since our query space is quite large, for now we'll only consider the higher reliablity edges (rank 0 - rank 2), and filter out the rest. If our query result was not large enough (too large), we could re-run the queries using less strict (stricter) ranks.
#
# We'll used the skm-tools function for filter to our required ranks.

# %%
keep_edge_ranks = [0,  1, 2]
ckn_utils.filter_ckn_edges(ckn, keep_edge_ranks=keep_edge_ranks, remove_isolates=True)
_ = ckn_utils.rank_counts(ckn)
# Out:
# Removed 791868 edges from network.
# rank 0:	 2,635
# rank 1:	 36,631
# rank 2:	 67,573
# rank 3:	 0
# rank 4:	 0

# %%
print(f"\nNumber of nodes: {ckn.number_of_nodes()}\nNumber of edges: {ckn.number_of_edges()}")
# Out:
# Number of nodes: 13477
# Number of edges: 106839

# %% [markdown]
# # Path extraction
#
# First we identify the nodes of interest.

# %%
rd29 = "AT5G52310"

# %%
source_receptors = pd.read_csv(data_dir / "source_receptors.tsv", sep="\t")
source_receptors
# Out:
#          reason  source_id short_name
# 0   JA receptor  AT2G39940       COI1
# 1  ABA receptor  AT4G17870       PYR1
# 2  ABA receptor  AT5G46790       PYL1
# 3  ABA receptor  AT2G26040       PYL2
# 4  ABA receptor  AT1G73000       PYL3
# 5  ABA receptor  AT5G53160       PYL8
# 6  ABA receptor  AT1G01360       PYL9
# 7   SA receptor  AT1G64280       NPR1
# 8   SA receptor  AT5G45110       NPR3
# 9   SA receptor  AT4G19660       NPR4

# %% [markdown]
# We use the networkx function `all_shortest_paths` to find paths between our nodes of interest:
#
# * From ABA receptors to RD29 (`aba_rd29_paths`)
# * From JA receptors to nodes within `aba_rd29_paths`
# * From SA  receptors to nodes within `aba_rd29_paths`

# %% [markdown]
# ## ABA --> RD29

# %%
aba_rd29_paths = {}
for _, row in source_receptors[source_receptors["reason"]=="ABA receptor"].iterrows():
    gene = row["source_id"]
    n = row["short_name"]
    if not gene in ckn.nodes():
        print(f"{n} ({gene}) not in CKN")
        continue
    print(f"{n} ({gene}) --> RD29:  ", end="")
    try: 
        new_paths = nx.all_shortest_paths(ckn, source=gene, target=rd29)
        new_paths = [p for p in new_paths]
        aba_rd29_paths[(gene, rd29)] = new_paths
        print(f"{len(new_paths)} paths")
    
    except nx.exception.NetworkXNoPath:
        print("no paths")
# Out:
# PYR1 (AT4G17870) --> RD29:  9 paths
# PYL1 (AT5G46790) --> RD29:  5 paths
# PYL2 (AT2G26040) --> RD29:  5 paths
# PYL3 (AT1G73000) --> RD29:  5 paths
# PYL8 (AT5G53160) --> RD29:  5 paths
# PYL9 (AT1G01360) --> RD29:  6 paths

# %%
aba_rd29_paths_nodes = {x for y in aba_rd29_paths for z in aba_rd29_paths[y] for x in z}

# %% [markdown]
# ## JA --> RD29
#
# We run the following searches after removing the edges on the above identified paths. Otherwise, the shortest paths include going from
# the source to the target "up" the ABA-RD29 paths

# %%
edges_to_remove = []
for (source, target) in aba_rd29_paths:
    for path in aba_rd29_paths[(source, target)]:
        for s, t in zip(path, path[1:]):
            if ckn.has_edge(s, t):
                edges_to_remove.append((s, t))
            
            if ckn.has_edge(t, s):
                edges_to_remove.append((t, s))

# %%
ckn_to_search = ckn.copy()
ckn_to_search.remove_edges_from(edges_to_remove)

# %%
ja_aba_rd29_paths = {}
for _, row in source_receptors[source_receptors["reason"]=="JA receptor"].iterrows():
    gene = row["source_id"]
    n = row["short_name"]
    if not gene in ckn.nodes():
        print(f"{n} ({gene}) not in CKN")
        continue    
    for node in aba_rd29_paths_nodes:

        print(f"{n} ({gene}) --> {node}:  ", end="")
        try: 
            new_paths = nx.all_shortest_paths(ckn_to_search, source=gene, target=node)
            new_paths = [p for p in new_paths]
            ja_aba_rd29_paths[(gene, node)] = new_paths
            print(f"{len(new_paths)} paths")

        except nx.exception.NetworkXNoPath:
            print("no paths")
# Out:
# COI1 (AT2G39940) --> AT5G66880:  1 paths
# COI1 (AT2G39940) --> AT3G19290:  1 paths
# COI1 (AT2G39940) --> AT3G50500:  4 paths
# COI1 (AT2G39940) --> AT1G45249:  1 paths
# COI1 (AT2G39940) --> AT5G46790:  1 paths
# COI1 (AT2G39940) --> AT1G32640:  6 paths
# COI1 (AT2G39940) --> AT3G11410:  11 paths
# COI1 (AT2G39940) --> AT1G73000:  1 paths
# COI1 (AT2G39940) --> AT1G01360:  2 paths
# COI1 (AT2G39940) --> AT1G27730:  1 paths
# COI1 (AT2G39940) --> AT4G17870:  2 paths
# COI1 (AT2G39940) --> AT5G53160:  1 paths
# COI1 (AT2G39940) --> AT4G34000:  1 paths
# COI1 (AT2G39940) --> AT4G26080:  1 paths
# COI1 (AT2G39940) --> AT1G49720:  1 paths
# COI1 (AT2G39940) --> AT2G26040:  1 paths
# COI1 (AT2G39940) --> AT5G52310:  2 paths

# %%
ja_aba_rd29_paths_nodes = {x for y in ja_aba_rd29_paths for z in ja_aba_rd29_paths[y] for x in z}

# %% [markdown]
# ## SA --> RD29

# %%
sa_aba_rd29_paths = {}
for _, row in source_receptors[source_receptors["reason"]=="SA receptor"].iterrows():
    gene = row["source_id"]
    n = row["short_name"]
    
    for node in aba_rd29_paths_nodes:

        print(f"{n} ({gene}) --> {node}:  ", end="")
        try: 
            new_paths = nx.all_shortest_paths(ckn_to_search, source=gene, target=node)
            new_paths = [p for p in new_paths]
            sa_aba_rd29_paths[(gene, node)] = new_paths
            print(f"{len(new_paths)} paths")

        except nx.exception.NetworkXNoPath:
            print("no paths")
# Out:
# NPR1 (AT1G64280) --> AT5G66880:  7 paths
# NPR1 (AT1G64280) --> AT3G19290:  9 paths
# NPR1 (AT1G64280) --> AT3G50500:  5 paths
# NPR1 (AT1G64280) --> AT1G45249:  3 paths
# NPR1 (AT1G64280) --> AT5G46790:  1 paths
# NPR1 (AT1G64280) --> AT1G32640:  1 paths
# NPR1 (AT1G64280) --> AT3G11410:  9 paths
# NPR1 (AT1G64280) --> AT1G73000:  1 paths
# NPR1 (AT1G64280) --> AT1G01360:  3 paths
# NPR1 (AT1G64280) --> AT1G27730:  1 paths
# NPR1 (AT1G64280) --> AT4G17870:  2 paths
# NPR1 (AT1G64280) --> AT5G53160:  2 paths
# NPR1 (AT1G64280) --> AT4G34000:  1 paths
# NPR1 (AT1G64280) --> AT4G26080:  1 paths
# NPR1 (AT1G64280) --> AT1G49720:  1 paths
# NPR1 (AT1G64280) --> AT2G26040:  1 paths
# NPR1 (AT1G64280) --> AT5G52310:  1 paths
# NPR3 (AT5G45110) --> AT5G66880:  1 paths
# NPR3 (AT5G45110) --> AT3G19290:  3 paths
# NPR3 (AT5G45110) --> AT3G50500:  2 paths
# NPR3 (AT5G45110) --> AT1G45249:  23 paths
# NPR3 (AT5G45110) --> AT5G46790:  5 paths
# NPR3 (AT5G45110) --> AT1G32640:  2 paths
# NPR3 (AT5G45110) --> AT3G11410:  2 paths
# NPR3 (AT5G45110) --> AT1G73000:  5 paths
# NPR3 (AT5G45110) --> AT1G01360:  1 paths
# NPR3 (AT5G45110) --> AT1G27730:  1 paths
# NPR3 (AT5G45110) --> AT4G17870:  1 paths
# NPR3 (AT5G45110) --> AT5G53160:  10 paths
# NPR3 (AT5G45110) --> AT4G34000:  2 paths
# NPR3 (AT5G45110) --> AT4G26080:  4 paths
# NPR3 (AT5G45110) --> AT1G49720:  2 paths
# NPR3 (AT5G45110) --> AT2G26040:  5 paths
# NPR3 (AT5G45110) --> AT5G52310:  1 paths
# NPR4 (AT4G19660) --> AT5G66880:  1 paths
# NPR4 (AT4G19660) --> AT3G19290:  1 paths
# NPR4 (AT4G19660) --> AT3G50500:  2 paths
# NPR4 (AT4G19660) --> AT1G45249:  11 paths
# NPR4 (AT4G19660) --> AT5G46790:  4 paths
# NPR4 (AT4G19660) --> AT1G32640:  2 paths
# NPR4 (AT4G19660) --> AT3G11410:  1 paths
# NPR4 (AT4G19660) --> AT1G73000:  4 paths
# NPR4 (AT4G19660) --> AT1G01360:  1 paths
# NPR4 (AT4G19660) --> AT1G27730:  1 paths
# NPR4 (AT4G19660) --> AT4G17870:  1 paths
# NPR4 (AT4G19660) --> AT5G53160:  7 paths
# NPR4 (AT4G19660) --> AT4G34000:  47 paths
# NPR4 (AT4G19660) --> AT4G26080:  2 paths
# NPR4 (AT4G19660) --> AT1G49720:  27 paths
# NPR4 (AT4G19660) --> AT2G26040:  4 paths
# NPR4 (AT4G19660) --> AT5G52310:  1 paths

# %%
sa_aba_rd29_paths_nodes = {x for y in sa_aba_rd29_paths for z in sa_aba_rd29_paths[y] for x in z}

# %% [markdown]
# # Context graph

# %%
longest_shortest_path_len = max([len(z) for p in [aba_rd29_paths, ja_aba_rd29_paths, sa_aba_rd29_paths] for y in p for z in p[y]])
longest_shortest_path_len
# Out:
# 5

# %%
all_nodes_graph = nx.induced_subgraph(ckn, set.union(aba_rd29_paths_nodes, ja_aba_rd29_paths_nodes, sa_aba_rd29_paths_nodes)).copy()
print(f"\nNumber of nodes: {all_nodes_graph.number_of_nodes()}\nNumber of edges: {all_nodes_graph.number_of_edges()}")
# Out:
# Number of nodes: 128
# Number of edges: 1000

# %%
# all_paths_to_rd29 = []
# for source in source_receptors.loc[source_receptors["reason"]=="JA receptor", 'source_id'].values:
#     for target in aba_rd29_paths_nodes:
#         if nx.has_path(ckn, source, target):
#             paths = nx.all_simple_edge_paths(ckn, source, target, cutoff=longest_shortest_path_len)
#             all_paths_to_rd29 += paths

# %%
# all_edges_to_rd29 = [e for p in all_paths_to_rd29 for e in p]
# len(set(all_edges_to_rd29))

# %%
# context_graph_edge_induced = nx.edge_subgraph(ckn, edges=all_edges_to_rd29).copy()
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")

# %%
# while True:
#     in_degrees = context_graph_edge_induced.in_degree()
#     removables = [n[0] for n in in_degrees if (n[1] == 0) and not (n[0] in source_receptors['source_id'].values)]
#     if len(removables) == 0:
#         break
#     context_graph_edge_induced.remove_nodes_from(removables)
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")

# %%
# context_graph_edge_induced = p4c.networks.create_network_from_networkx(
#     context_graph_edge_induced, 
#     title="JA", 
#     collection=COLLECTION
# )
# cytoscape_utils.apply_builtin_style(ckn_network_suid, 'ckn')
# # p4c.layout_network("cose", network=ckn_network_suid)
# ckn_network_suid

# %%
# g1 = nx.induced_subgraph(g, nx.bfs_predecessors(g, rd29, depth_limit=longest_shortest_path_len))

# %%
# print(f"\nNumber of nodes: {g1.number_of_nodes()}\nNumber of edges: {g1.number_of_edges()}")
# Out:
# Number of nodes: 0
# Number of edges: 0

# %%
# all_reachable_nodes = {x for d in range(longest_shortest_path_len) for x in nx.descendants_at_distance(ckn.to_undirected(), rd29, d)}
# all_reachable_nodes.update([rd29])
# len(all_reachable_nodes)
# Out:
# 4819

# %%
# outer_layer = nx.descendants_at_distance(ckn.to_undirected(), rd29, longest_shortest_path_len)
# print(len(outer_layer))

# %%
# all_paths_to_rd29 = []
# for node in source_receptors['source_id'].values:
#     if nx.has_path(g, node, rd29):
#         paths = nx.all_simple_edge_paths(g, node, rd29, cutoff=longest_shortest_path_len)
#         all_paths_to_rd29 += paths

# %%
# all_edges_to_rd29 = [e for p in all_paths_to_rd29 for e in p]
# len(set(all_edges_to_rd29))
# Out:
# 4490

# %%
# context_graph_edge_induced = nx.edge_subgraph(g, edges=all_edges_to_rd29).copy()
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")
# Out:
# Number of nodes: 768
# Number of edges: 4490

# %%
# while True:
#     in_degrees = context_graph_edge_induced.in_degree()
#     removables = [n[0] for n in in_degrees if (n[1] == 0) and not (n[0] in source_receptors['source_id'].values)]
#     if len(removables) == 0:
#         break
#     context_graph_edge_induced.remove_nodes_from(removables)
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")
# Out:
# Number of nodes: 768
# Number of edges: 4490

# %%
# ckn_network_suid = p4c.networks.create_network_from_networkx(context_graph_edge_induced, title="edge induced context - complete case study subnetwork", collection=COLLECTION)
# cytoscape_utils.apply_builtin_style(ckn_network_suid, 'ckn')
# # p4c.layout_network("cose", network=ckn_network_suid)
# ckn_network_suid
# Out:
# Applying default style...
# Applying preferred layout
# Applied CKN-default to 398050
# 398050

# %%
# # sources (receptors)
# cytoscape_utils.highlight_nodes(
#     list(source_receptors["source_id"]),
#     border_color="red",
#     border_width=14,
#     node_height=80,
#     node_width=80,
#     network=ckn_network_suid
# )

# # target (RD29)
# cytoscape_utils.highlight_nodes(
#     [rd29],
#     border_color="black",
#     border_width=14,
#     node_height=80,
#     node_width=80,
#     network=ckn_network_suid
# )

# %%
# context_graph = nx.DiGraph(nx.induced_subgraph(g, nbunch=all_reachable_nodes))

# %%
# all_reachable_nodes

# %%
# edges = nx.bfs_edges(g, rd29, reverse=True, depth_limit=longest_shortest_path_len)
# # reverse the edges back
# context_graph_edge_induced = nx.edge_subgraph(g, edges=[(e[1], e[0]) for e in edges]).copy()
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")
# Out:
# Number of nodes: 4516
# Number of edges: 4515

# %%
# while True:
#     in_degrees = context_graph_edge_induced.in_degree()
#     removables = [n[0] for n in in_degrees if (n[1] == 0) and not (n[0] in source_receptors['source_id'].values)]
#     if len(removables) == 0:
#         break
#     context_graph_edge_induced.remove_nodes_from(removables)

# %%
# print(f"\nNumber of nodes: {context_graph_edge_induced.number_of_nodes()}\nNumber of edges: {context_graph_edge_induced.number_of_edges()}")
# Out:
# Number of nodes: 16
# Number of edges: 15

# %%
# removables
# Out:
# ['BA-CoA',
#  'Xanthoxin',
#  'ACC',
#  'AT1G07640',
#  'AT1G17080',
#  'AT1G25280',
#  'AT1G32870',
#  'AT1G67970',
#  'AT2G25000',
#  'AT2G31490',
#  'AT2G33120',
#  'AT2G40750',
#  'AT3G02150',
#  'AT3G14420',
#  'AT3G58120',
#  'AT4G00050',
#  'AT4G35580',
#  'AT5G05760',
#  'AT5G08330',
#  'AT5G22570',
#  'AT5G60120',
#  'AT1G11890',
#  'AT1G31780',
#  'AT1G33140',
#  'AT2G34770',
#  'AT2G37270',
#  'AT3G13445',
#  'AT3G18600',
#  'AT3G21540',
#  'AT3G45630',
#  'AT4G16420',
#  'AT5G01820',
#  'AT5G02490',
#  'AT5G09590',
#  'AT5G10480',
#  'AT1G18400',
#  'AT1G19220',
#  'AT1G32330',
#  'AT1G68880',
#  'AT1G71030',
#  'AT1G76420',
#  'AT2G29490',
#  'AT2G46310',
#  'AT2G46870',
#  'AT3G52910',
#  'AT3G61630',
#  'AT4G21750',
#  'AT4G23750',
#  'AT4G26150',
#  'AT4G36870',
#  'AT5G03680',
#  'AT5G08070',
#  'AT5G16560',
#  'AT5G20730',
#  'AT5G41410',
#  'AT5G43700',
#  'AT1G01160',
#  'AT1G03780',
#  'AT1G06960',
#  'AT1G07430',
#  'AT1G11400',
#  'AT1G13120',
#  'AT1G14570',
#  'AT1G16610',
#  'AT1G19120',
#  'AT1G21410',
#  'AT1G22920',
#  'AT1G23260',
#  'AT1G23420',
#  'AT1G23860',
#  'AT1G26110',
#  'AT1G33410',
#  'AT1G44110',
#  'AT1G49590',
#  'AT1G54140',
#  'AT1G54490',
#  'AT1G54610',
#  'AT1G55080',
#  'AT1G55250',
#  'AT1G61010',
#  'AT1G68060',
#  'AT1G70510',
#  'AT1G76300',
#  'AT1G78600',
#  'AT1G78770',
#  'AT1G80840',
#  'AT2G02760',
#  'AT2G03070',
#  'AT2G06510',
#  'AT2G17800',
#  'AT2G18290',
#  'AT2G20580',
#  'AT2G22370',
#  'AT2G23320',
#  'AT2G25850',
#  'AT2G27040',
#  'AT2G27100',
#  'AT2G27250',
#  'AT2G28290',
#  'AT2G29890',
#  'AT2G30470',
#  'AT2G36350',
#  'AT2G37340',
#  'AT2G39090',
#  'AT2G40550',
#  'AT3G01435',
#  'AT3G03300',
#  'AT3G04680',
#  'AT3G04740',
#  'AT3G04840',
#  'AT3G06190',
#  'AT3G13300',
#  'AT3G13570',
#  'AT3G15210',
#  'AT3G15880',
#  'AT3G17590',
#  'AT3G20000',
#  'AT3G20550',
#  'AT3G21060',
#  'AT3G21430',
#  'AT3G21630',
#  'AT3G43920',
#  'AT3G46210',
#  'AT3G47690',
#  'AT3G48040',
#  'AT3G52090',
#  'AT3G52860',
#  'AT3G54010',
#  'AT3G54230',
#  'AT3G55460',
#  'AT3G55840',
#  'AT3G59600',
#  'AT3G62410',
#  'AT3G62800',
#  'AT3G63500',
#  'AT4G02070',
#  'AT4G02460',
#  'AT4G04780',
#  'AT4G09010',
#  'AT4G14180',
#  'AT4G14550',
#  'AT4G14720',
#  'AT4G16265',
#  'AT4G16280',
#  'AT4G22950',
#  'AT4G24500',
#  'AT4G25500',
#  'AT4G29170',
#  'AT4G31160',
#  'AT4G31580',
#  'AT4G32880',
#  'AT4G32910',
#  'AT4G36690',
#  'AT4G37460',
#  'AT5G01400',
#  'AT5G01840',
#  'AT5G02030',
#  'AT5G03220',
#  'AT5G08120',
#  'AT5G13480',
#  'AT5G14620',
#  'AT5G16750',
#  'AT5G18410',
#  'AT5G18810',
#  'AT5G19330',
#  'AT5G20160',
#  'AT5G20320',
#  'AT5G21010',
#  'AT5G24630',
#  'AT5G37055',
#  'AT5G42750',
#  'AT5G42970',
#  'AT5G43060',
#  'AT5G43530',
#  'AT5G43560',
#  'AT5G45970',
#  'AT5G47010',
#  'AT5G48160',
#  'AT5G51660',
#  'AT5G51700',
#  'AT5G52040',
#  'AT5G52830',
#  'AT5G59180',
#  'AT5G60450',
#  'AT5G60550',
#  'AT5G65683',
#  'AT1G04100',
#  'AT1G06040',
#  'AT1G28520',
#  'AT1G30330',
#  'AT1G32900',
#  'AT1G74660',
#  'AT1G75540',
#  'AT1G77850',
#  'AT2G21660',
#  'AT2G33860',
#  'AT2G42400',
#  'AT2G46970',
#  'AT2G46990',
#  'AT3G09600',
#  'AT3G22170',
#  'AT3G23030',
#  'AT3G52770',
#  'AT3G59060',
#  'AT3G62090',
#  'AT3G62100',
#  'AT4G30080',
#  'AT5G04240',
#  'AT5G05660',
#  'AT5G06850',
#  'AT5G15850',
#  'AT5G37020',
#  'AT5G37260',
#  'AT5G56860',
#  'AT5G58140',
#  'AT5G67380',
#  'AT1G31812',
#  'AT2G33430',
#  'AT3G11400',
#  'AT1G01090',
#  'AT1G21400',
#  'AT1G24180',
#  'AT1G54220',
#  'AT1G55490',
#  'AT1G59900',
#  'AT2G25170',
#  'AT2G28000',
#  'AT3G13930',
#  'AT3G25860',
#  'AT3G54320',
#  'AT4G24190',
#  'AT5G09300',
#  'AT5G47670',
#  'AT5G56010',
#  'ATCG00500',
#  'AT1G01100',
#  'AT1G04270',
#  'AT1G08360',
#  'AT1G26910',
#  'AT1G43170',
#  'AT1G64230',
#  'AT1G70600',
#  'AT1G72370',
#  'AT1G74050',
#  'AT1G74060',
#  'AT2G19730',
#  'AT2G27530',
#  'AT2G27710',
#  'AT2G37190',
#  'AT2G39590',
#  'AT2G40010',
#  'AT2G42740',
#  'AT3G06700',
#  'AT3G09200',
#  'AT3G10330',
#  'AT3G11250',
#  'AT3G18130',
#  'AT3G25520',
#  'AT3G28500',
#  'AT3G44590',
#  'AT3G46040',
#  'AT3G46460',
#  'AT3G47370',
#  'AT3G53890',
#  'AT4G00810',
#  'AT4G03520',
#  'AT4G09800',
#  'AT4G18100',
#  'AT4G19210',
#  'AT4G25740',
#  'AT4G27230',
#  'AT4G29430',
#  'AT5G09510',
#  'AT5G10360',
#  'AT5G22440',
#  'AT5G23900',
#  'AT5G35530',
#  'AT5G39950',
#  'AT5G40040',
#  'AT5G41520',
#  'AT5G60670',
#  'AT1G15360',
#  'AT1G17840',
#  'AT1G20850',
#  'AT2G30870',
#  'AT4G00360',
#  'AT5G14930',
#  'AT5G54160',
#  'AT5G62380',
#  'AT1G29230',
#  'AT2G25090',
#  'AT4G14580',
#  'AT4G24400',
#  'AT5G07070',
#  'AT5G10930',
#  'AT5G45820',
#  'AT5G57630',
#  'AT5G58380',
#  'AT1G01140',
#  'AT1G04450',
#  'AT1G31930',
#  'AT2G01980',
#  'AT2G17290',
#  'AT2G19110',
#  'AT2G21410',
#  'AT2G23290',
#  'AT2G26980',
#  'AT2G28910',
#  'AT2G29100',
#  'AT2G32400',
#  'AT2G37560',
#  'AT2G39290',
#  'AT3G02520',
#  'AT3G12810',
#  'AT3G16050',
#  'AT3G26650',
#  'AT3G51860',
#  'AT3G53900',
#  'AT3G56970',
#  'AT3G56980',
#  'AT3G57530',
#  'AT3G59410',
#  'AT4G01400',
#  'AT4G11140',
#  'AT4G20260',
#  'AT4G27280',
#  'AT4G33260',
#  'AT4G34390',
#  'AT4G39050',
#  'AT4G39080',
#  'AT5G09810',
#  'AT5G13820',
#  'AT5G24270',
#  'AT5G28770',
#  'AT5G38480',
#  'AT5G40820',
#  'AT5G48400',
#  'AT5G55000',
#  'AT5G55160',
#  'AT5G57110',
#  'AT5G58720',
#  'AT5G64330',
#  'AT1G03190',
#  'AT1G07130',
#  'AT1G08370',
#  'AT1G15570',
#  'AT1G20780',
#  'AT1G57820',
#  'AT1G67580',
#  'AT1G77920',
#  'AT3G01770',
#  'AT3G02540',
#  'AT3G06010',
#  'AT3G15000',
#  'AT3G16830',
#  'AT3G19210',
#  'AT3G44460',
#  'AT3G51630',
#  'AT3G54170',
#  'AT4G02020',
#  'AT4G02060',
#  'AT4G17880',
#  'AT4G24560',
#  'AT4G34590',
#  'AT4G35900',
#  'AT4G37000',
#  'AT5G06960',
#  'AT5G14960',
#  'AT5G23080',
#  'AT5G26860',
#  'AT5G49450',
#  'AT5G51230',
#  'AT5G57450',
#  'AT5G65210',
#  'AT5G65310',
#  'AT1G52150',
#  'AT2G34710',
#  'AT3G61880',
#  'AT1G09630',
#  'AT2G35190',
#  'AT2G40060',
#  'AT3G01780',
#  'AT3G09900',
#  'AT3G53610',
#  'AT4G17170',
#  'AT4G39990',
#  'AT5G03530',
#  'AT5G45130',
#  'AT1G76920',
#  'AT2G17510',
#  'AT2G22310',
#  'AT2G29540',
#  'AT3G18090',
#  'AT3G23780',
#  'AT5G45140',
#  'AT5G60040',
#  'AT3G06580',
#  'AT3G09100',
#  'AT4G16130',
#  'AT1G14400',
#  'AT1G17280',
#  'AT1G27300',
#  'AT3G06483',
#  'AT3G17000',
#  'AT3G29270',
#  'AT3G51310',
#  'AT3G59790',
#  'AT4G19030',
#  'AT4G23400',
#  'AT4G36450',
#  'AT5G41600',
#  'AT3G27080',
#  'AT3G60360',
#  'AT4G38920',
#  'AT3G01330',
#  'AT3G15500',
#  'AT4G34000',
#  'AT1G01260',
#  'AT1G25550',
#  'AT1G48500',
#  'AT1G51600',
#  'AT2G27050',
#  'AT2G46510',
#  'AT3G04730',
#  'AT3G21175',
#  'AT3G27810',
#  'AT3G43440',
#  'AT3G61830',
#  'AT4G16430',
#  'AT4G17500',
#  'AT5G13220',
#  'AT5G20900',
#  'AT5G46760',
#  'AT3G20110',
#  'AT1G01300',
#  'AT4G26270',
#  'AT5G17770',
#  'AT5G58000',
#  'AT2G33340',
#  'AT1G01560',
#  'AT1G50640',
#  'AT1G52920',
#  'AT2G25140',
#  'AT2G30020',
#  'AT2G31470',
#  'AT3G20310',
#  'AT3G26810',
#  'AT3G29575',
#  'AT3G47620',
#  'AT3G52400',
#  'AT4G01026',
#  'AT4G20940',
#  'AT4G24210',
#  'AT4G29810',
#  'AT5G05440',
#  'AT5G45870',
#  'AT5G66880',
#  'AT1G02970',
#  'AT1G06760',
#  'AT1G13890',
#  'AT1G14850',
#  'AT1G21690',
#  'AT1G26840',
#  'AT1G48920',
#  'AT1G51710',
#  'AT1G65470',
#  'AT1G65650',
#  'AT1G68640',
#  'AT1G69220',
#  'AT1G76310',
#  'AT2G01120',
#  'AT2G16440',
#  'AT2G23430',
#  'AT2G35630',
#  'AT2G38880',
#  'AT2G39460',
#  'AT2G42830',
#  'AT2G45490',
#  'AT3G02310',
#  'AT3G05870',
#  'AT3G16640',
#  'AT3G18730',
#  'AT3G21850',
#  'AT3G24810',
#  'AT3G46320',
#  'AT3G57060',
#  'AT4G00850',
#  'AT4G02740',
#  'AT4G11920',
#  'AT4G12620',
#  'AT4G18130',
#  'AT4G22910',
#  'AT4G29910',
#  'AT4G34160',
#  'AT4G35520',
#  'AT4G40040',
#  'AT5G04470',
#  'AT5G11300',
#  'AT5G24330',
#  'AT5G39340',
#  'AT5G41990',
#  'AT5G43080',
#  'AT5G44190',
#  'AT5G44280',
#  'AT5G44635',
#  'AT5G49880',
#  'AT5G51600',
#  'AT5G54670',
#  'AT5G56280',
#  'AT5G59570',
#  'AT5G63950',
#  'AT5G67100',
#  'AT5G67260',
#  'AT1G01380',
#  'AT1G05690',
#  'AT1G14440',
#  'AT1G22640',
#  'AT1G51070',
#  'AT1G53160',
#  'AT1G66390',
#  'AT1G68520',
#  'AT2G24790',
#  'AT2G30420',
#  'AT2G30432',
#  'AT2G31380',
#  'AT2G37260',
#  'AT2G45650',
#  'AT2G46410',
#  'AT2G47890',
#  'AT3G11280',
#  'AT3G28910',
#  'AT5G06510',
#  'AT5G51060',
#  'AT1G12820',
#  'AT4G39330',
#  'AT5G42800',
#  'AT2G24270',
#  'AT2G29400',
#  'AT3G26030',
#  'AT5G11920',
#  'AT5G27840',
#  'AT1G01440',
#  'AT1G67090',
#  'AT2G28550',
#  'AT2G47700',
#  'AT3G49580',
#  'AT2G06990',
#  'AT1G01480',
#  'AT1G62960',
#  'AT2G05070',
#  'AT3G49700',
#  'AT3G61510',
#  'AT4G08040',
#  'AT4G24240',
#  'AT4G31990',
#  'AT5G20890',
#  'AT5G65800',
#  'AT1G14740',
#  'AT1G15200',
#  'AT1G20930',
#  'AT1G31140',
#  'AT1G48050',
#  'AT1G51170',
#  'AT1G51660',
#  'AT1G70140',
#  'AT1G73360',
#  'AT1G75840',
#  'AT2G02560',
#  'AT2G04660',
#  'AT2G26650',
#  'AT2G31270',
#  'AT2G33410',
#  'AT2G33460',
#  'AT2G34150',
#  'AT2G41370',
#  'AT2G41740',
#  'AT2G46600',
#  'AT3G12480',
#  'AT3G21150',
#  'AT3G48150',
#  'AT3G48160',
#  'AT3G49670',
#  'AT3G54560',
#  'AT3G55000',
#  'AT3G59420',
#  'AT4G02680',
#  'AT4G03190',
#  'AT4G08920',
#  'AT4G20780',
#  'AT4G21100',
#  'AT4G24972',
#  'AT4G25530',
#  'AT4G27180',
#  'AT4G30200',
#  'AT4G33010',
#  'AT4G38510',
#  'AT5G03150',
#  'AT5G03415',
#  'AT5G16490',
#  'AT5G18580',
#  'AT5G18620',
#  'AT5G22330',
#  'AT5G27320',
#  'AT5G28650',
#  'AT5G45710',
#  'AT5G48170',
#  'AT5G54650',
#  'AT5G60410',
#  'AT5G62430',
#  'AT1G07530',
#  'AT1G50420',
#  'AT2G02450',
#  'AT2G24540',
#  'AT4G18170',
#  'AT4G37790',
#  'AT1G01530',
#  'AT1G47760',
#  'AT1G65330',
#  'AT1G65360',
#  'AT1G71692',
#  'AT2G22630',
#  'AT3G04100',
#  'AT3G50070',
#  'AT5G11510',
#  'AT5G23260',
#  'AT5G26650',
#  'AT5G27960',
#  'AT1G80370',
#  'AT2G30360',
#  'AT3G06030',
#  'AT3G45240',
#  'AT3G52890',
#  'AT3G61160',
#  'AT4G27300',
#  'AT4G28540',
#  'AT4G31170',
#  'AT5G13160',
#  'AT5G55910',
#  'AT5G58350',
#  'AT1G63930',
#  'AT1G02170',
#  'AT1G02450',
#  'AT1G06390',
#  'AT1G07880',
#  'AT1G09070',
#  'AT1G12110',
#  'AT1G12360',
#  'AT1G18350',
#  'AT1G20610',
#  'AT1G27970',
#  'AT1G32500',
#  'AT1G47220',
#  'AT1G62170',
#  'AT1G70700',
#  'AT1G72450',
#  'AT1G73080',
#  'AT1G73690',
#  'AT1G76260',
#  'AT1G77390',
#  'AT2G22540',
#  'AT2G23080',
#  'AT2G26760',
#  'AT2G45140',
#  'AT2G46370',
#  'AT2G47510',
#  'AT3G02830',
#  'AT3G06110',
#  'AT3G07360',
#  'AT3G19150',
#  'AT3G50000',
#  'AT3G52180',
#  'AT3G52430',
#  'AT3G53570',
#  'AT3G56710',
#  'AT3G57260',
#  'AT4G01010',
#  'AT4G01050',
#  'AT4G02410',
#  'AT4G04620',
#  'AT4G04910',
#  'AT4G08480',
#  'AT4G12560',
#  'AT4G12720',
#  'AT4G13020',
#  'AT4G18950',
#  'AT4G24740',
#  'AT4G27920',
#  'AT5G10350',
#  'AT5G13190',
#  'AT5G16820',
#  'AT5G20480',
#  'AT5G20910',
#  'AT5G26751',
#  'AT5G36250',
#  'AT5G46570',
#  'AT5G47080',
#  'AT5G53470',
#  'AT5G54490',
#  'AT5G57380',
#  'AT5G58220',
#  'AT5G62390',
#  'AT5G63310',
#  'AT5G63790',
#  'AT5G65420',
#  'AT1G31260',
#  'AT5G58670',
#  'AT2G06850',
#  'AT1G16030',
#  'AT1G53310',
#  'AT1G64860',
#  'AT1G68380',
#  'AT1G77740',
#  'AT2G01420',
#  'AT2G16850',
#  'AT2G39010',
#  'AT2G41010',
#  'AT2G41430',
#  'AT2G42810',
#  'AT2G43010',
#  'AT2G45790',
#  'AT3G18780',
#  'AT3G28200',
#  'AT3G54820',
#  'AT3G59220',
#  'AT4G35100',
#  'AT5G04140',
#  'AT5G16050',
#  'AT5G55630',
#  'AT5G57740',
#  'AT3G09720',
#  'AT3G54850',
#  'AT4G02400',
#  'AT4G32190',
#  'AT1G01640',
#  'AT1G15050',
#  'AT1G21780',
#  'AT1G31350',
#  'AT1G32060',
#  'AT1G52830',
#  'AT2G46260',
#  'AT3G03740',
#  'AT3G07540',
#  'AT3G15970',
#  'AT3G52560',
#  'AT3G57130',
#  'AT3G62440',
#  'AT4G32980',
#  'AT4G37610',
#  'AT5G55250',
#  'AT5G55300',
#  'AT1G01700',
#  'AT3G24620',
#  'AT5G05940',
#  'AT1G06460',
#  'AT1G53880',
#  'AT1G68010',
#  'AT1G72340',
#  'AT3G08680',
#  'AT3G14210',
#  'AT3G17700',
#  'AT3G56460',
#  'AT4G09320',
#  'AT4G14430',
#  'AT4G18290',
#  'AT5G04870',
#  'AT5G16590',
#  'AT5G27600',
#  'AT5G43940',
#  'AT1G12610',
#  'AT1G32770',
#  'AT1G56280',
#  'AT2G20560',
#  'AT2G27300',
#  'AT2G38410',
#  'AT3G11020',
#  'AT4G27410',
#  'AT5G06100',
#  'AT5G10300',
#  'AT5G16830',
#  'AT5G54940',
#  'AT5G66730',
#  'AT1G01740',
#  'AT5G41260',
#  'AT1G16190',
#  'AT2G31200',
#  'AT2G37620',
#  'AT2G42100',
#  'AT3G53750',
#  'AT5G01720',
#  'AT5G59370',
#  'AT5G59880',
#  'AT1G60430',
#  'AT3G03800',
#  'AT3G16500',
#  'AT3G47500',
#  'AT4G27500',
#  'AT5G45050',
#  'AT5G48250',
#  'AT1G80300',
#  'ATCG01130',
#  'AT5G52650',
#  'AT1G12220',
#  'AT1G69390',
#  'AT2G01470',
#  'AT2G22780',
#  'AT2G26350',
#  'AT3G11070',
#  'AT3G19180',
#  'AT3G21510',
#  'AT4G23630',
#  'AT4G35000',
#  'AT4G35090',
#  'AT4G39850',
#  'AT5G37670',
#  'AT5G56290',
#  'AT3G14067',
#  'AT5G19660',
#  'AT1G10630',
#  'AT1G15220',
#  'AT1G27310',
#  'AT1G48760',
#  'AT1G61290',
#  'AT1G75100',
#  'AT1G75750',
#  'AT2G22240',
#  'AT2G24765',
#  'AT2G35210',
#  'AT2G41110',
#  'AT3G03600',
#  'AT3G08950',
#  'AT3G22480',
#  'AT4G00585',
#  'AT4G02930',
#  'AT4G03330',
#  'AT4G08980',
#  'AT4G17890',
#  'AT4G23570',
#  'AT4G26750',
#  'AT4G38900',
#  'AT4G39800',
#  'AT5G07880',
#  'AT5G09260',
#  'AT5G14920',
#  'AT5G15230',
#  'AT5G33280',
#  'AT1G29960',
#  'AT2G32220',
#  'AT1G02100',
#  'AT1G29550',
#  'AT1G52300',
#  'AT1G70490',
#  'AT2G27700',
#  'AT3G49010',
#  'AT3G63280',
#  'AT5G15400',
#  'AT2G16600',
#  'AT2G21130',
#  'AT2G29960',
#  'AT2G36130',
#  'AT2G38730',
#  'AT3G18190',
#  'AT3G22920',
#  'AT3G48870',
#  'AT3G56070',
#  'AT4G32520',
#  'AT4G34870',
#  'AT4G38740',
#  'AT1G05180',
#  'AT1G05520',
#  'AT1G05570',
#  'AT1G12470',
#  'AT1G14640',
#  'AT1G15420',
#  'AT1G23490',
#  'AT1G52980',
#  'AT1G56330',
#  'AT1G73820',
#  'AT2G18390',
#  'AT2G19760',
#  'AT2G45810',
#  'AT2G47170',
#  'AT2G47990',
#  'AT3G07100',
#  'AT3G07300',
#  'AT3G16840',
#  'AT3G25100',
#  'AT3G44340',
#  'AT3G54840',
#  'AT3G62120',
#  'AT4G00660',
#  'AT4G16630',
#  'AT4G31480',
#  'AT4G34450',
#  'AT5G14670',
#  'AT5G26830',
#  'AT1G63000',
#  'AT3G46440',
#  'AT5G08710',
#  'AT1G02010',
#  'AT1G04750',
#  'AT1G26480',
#  'AT1G34760',
#  'AT2G28830',
#  'AT2G42520',
#  'AT4G02195',
#  'AT4G12120',
#  'AT1G19700',
#  'AT1G28420',
#  'AT1G34790',
#  'AT1G46264',
#  'AT1G46768',
#  'AT1G51950',
#  'AT1G53170',
#  'AT1G66380',
#  'AT1G75410',
#  'AT1G80390',
#  'AT2G22670',
#  'AT2G23760',
#  'AT2G27990',
#  'AT2G30590',
#  'AT2G33310',
#  'AT2G44910',
#  'AT3G13540',
#  'AT3G49940',
#  'AT3G56660',
#  'AT3G60390',
#  'AT4G13980',
#  'AT4G27950',
#  'AT4G29080',
#  'AT4G32730',
#  'AT4G34610',
#  'AT5G04390',
#  'AT5G06650',
#  'AT5G09740',
#  'AT5G13180',
#  'AT5G25890',
#  'AT5G26950',
#  'AT5G27050',
#  'AT5G27580',
#  'AT5G27910',
#  'AT5G39660',
#  'AT5G43170',
#  'AT5G43840',
#  'AT5G50570',
#  'AT5G62165',
#  'AT5G64610',
#  'AT5G67420',
#  'AT2G14210',
#  'AT2G42200',
#  'AT3G13890',
#  'AT5G35770',
#  'AT5G43270',
#  'AT1G04950',
#  'AT1G73230',
#  'AT2G32730',
#  'AT2G34210',
#  'AT3G10070',
#  'AT3G27360',
#  'AT3G28710',
#  'AT5G10400',
#  'AT5G19990',
#  'AT5G48630',
#  'AT5G55090',
#  'AT5G57020',
#  'AT5G59710',
#  'AT1G02140',
#  'AT1G10840',
#  'AT1G31810',
#  'AT1G53090',
#  'AT1G79650',
#  'AT2G26990',
#  'AT2G27230',
#  'AT3G10380',
#  'AT3G21860',
#  'AT3G45140',
#  'AT3G45620',
#  'AT3G56900',
#  'AT4G11110',
#  'AT4G16144',
#  'AT4G26430',
#  'AT4G33470',
#  'AT5G07120',
#  'AT5G13490',
#  'AT5G23730',
#  'AT5G25780',
#  'AT5G45620',
#  'AT5G64760',
#  'AT1G07660',
#  'AT1G53900',
#  'AT1G72730',
#  'AT2G17620',
#  'AT2G39840',
#  'AT2G44065',
#  'AT2G47620',
#  'AT3G05580',
#  'AT3G09640',
#  'AT3G13210',
#  'AT4G04340',
#  'AT4G21980',
#  'AT4G34430',
#  ...]

# %%
# context_graph_edge_induced.remove_nodes_from(removables)

# %%
# ckn_network_suid = p4c.networks.create_network_from_networkx(context_graph_edge_induced, title="edge induced context - complete case study subnetwork", collection=COLLECTION)
# cytoscape_utils.apply_builtin_style(ckn_network_suid, 'ckn')
# # p4c.layout_network("cose", network=ckn_network_suid)
# ckn_network_suid
# Out:
# Applying default style...
# Applying preferred layout
# Applied CKN-default to 923401
# 923401

# %% [markdown]
# ## Node prioritisation

# %%
# for u, v, data in ckn.edges(data=True):
#     data['capacity'] = (5 - data['rank'])

# %%
# data
# Out:
# {'effect': 'act',
#  'type': 'other',
#  'rank': 0,
#  'species': 'ath',
#  'isDirected': 1,
#  'isTFregulation': 0,
#  'interactionSources': 'skm:rx00357',
#  'capacity': 5}

# %%
# r = nx.flow.edmonds_karp(g, 'AT1G01360', rd29)

# %%
# r.graph["flow_value"]
# Out:
# 26

# %%
# cut_value, partition = nx.flow.minimum_cut(g, 'AT1G01360', rd29, capacity='capacity', flow_func=nx.flow.edmonds_karp)

# %%
# cut_value
# Out:
# 26

# %%
# len(partition)
# Out:
# 2

# %%
# nx.connectivity.minimum_edge_cut(g, 'AT1G01360', rd29, flow_func=nx.flow.edmonds_karp)
# Out:
# {('AT1G01360', 'AT1G32640'),
#  ('AT1G01360', 'AT1G72770'),
#  ('AT1G01360', 'AT3G11410'),
#  ('AT1G01360', 'AT4G05420'),
#  ('AT1G01360', 'AT4G26080'),
#  ('AT1G01360', 'AT5G57050')}

# %%
## Distance to RD29

# %%
## Distance from source

# %%
## InDegree, OutDegree

# %%
# for path in aba_rd29_paths:
#     break

# %%
# all_nodes = set.union(aba_rd29_paths_nodes, ja_aba_rd29_paths_nodes, sa_aba_rd29_paths_nodes)
# print(len(all_nodes))
# Out:
# 81

# %%
# len([x for x in nx.edge_disjoint_paths(g, node, rd29)])
# Out:
# 15

# %%
# all_node_attributes = {}
# AT3G15210 // JA

# %%
# target = 'RD29'

# for node in all_nodes:
#     if not (node in all_node_attributes or node == rd29):
#         node_attributes = ckn.nodes(data=True)[node]
#         node_attributes[f'distance-to-{target}'] = len(nx.shortest_path(g, source=node, target=rd29)) -1
#         node_attributes['in-degree'] = ckn.in_degree(node)
#         node_attributes['out-degree'] = ckn.out_degree(node)

#         node_attributes[f'disjoint-path-between-{target}'] = len([x for x in nx.edge_disjoint_paths(g, node, rd29) if len(x)<10])

#         all_node_attributes[node] = node_attributes

# %%
# all_node_attributes
# Out:
# {'AT4G02640': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G02640',
#   'short_name': 'BZO2H1',
#   'synonyms': ['BZO2H1',
#    'Arabidopsis thaliana basic leucine zipper 10',
#    'ATBZIP10'],
#   'full_name': 'bZIP transcription factor family protein',
#   'GMM': ['15.2_metal handling.binding, chelation and storage',
#    '27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 19,
#   'out-degree': 19,
#   'disjoint-path-between-RD29': 15},
#  'AT4G05420': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G05420',
#   'short_name': 'DDB1A',
#   'synonyms': ['damaged DNA binding protein 1A', 'DDB1A'],
#   'full_name': 'damaged DNA binding protein 1A',
#   'GMM': ['20.2.5_stress.abiotic.light',
#    '29.5.11.4.6_protein.degradation.ubiquitin.E3.DCX'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 24,
#   'out-degree': 21,
#   'disjoint-path-between-RD29': 15},
#  'AT5G61380': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G61380',
#   'short_name': 'TOC1',
#   'synonyms': ['TIMING OF CAB EXPRESSION 1',
#    'TOC1',
#    'APRR1',
#    'PRR1',
#    'AtTOC1',
#    'PSEUDO-RESPONSE REGULATOR 1'],
#   'full_name': 'TIMING OF CAB EXPRESSION 1',
#   'GMM': ['19.4_tetrapyrrole synthesis.ALA dehydratase',
#    '27.3.66_RNA.regulation of transcription.pseudo ARR transcription factor family',
#    '30.2.99_signalling.receptor kinases.misc'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 21,
#   'out-degree': 20,
#   'disjoint-path-between-RD29': 15},
#  'AT4G30960': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G30960',
#   'short_name': 'SIP3',
#   'synonyms': ['CBL-INTERACTING PROTEIN KINASE 6',
#    'ATCIPK6',
#    'SNF1-RELATED PROTEIN KINASE 3.14',
#    'SNRK3.14',
#    'SIP3',
#    'CIPK6',
#    'SOS3-interacting protein 3'],
#   'full_name': 'SOS3-interacting protein 3',
#   'GMM': ['20.2.99_stress.abiotic.unspecified',
#    '29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 12,
#   'out-degree': 12,
#   'disjoint-path-between-RD29': 12},
#  'AT5G65410': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G65410',
#   'short_name': 'HB25',
#   'synonyms': ['ARABIDOPSIS THALIANA HOMEOBOX PROTEIN 25',
#    'ZINC FINGER HOMEODOMAIN 2',
#    'ZFHD2',
#    'ZHD1',
#    'ZINC FINGER HOMEODOMAIN 1',
#    'ATHB25',
#    'homeobox protein 25',
#    'HB25'],
#   'full_name': 'homeobox protein 25',
#   'GMM': ['20.1.7_stress.biotic.PR-proteins',
#    '27.3.80_RNA.regulation of transcription.zf-HD'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 15,
#   'out-degree': 15,
#   'disjoint-path-between-RD29': 8},
#  'AT4G01420': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G01420',
#   'short_name': 'CBL5',
#   'synonyms': ['calcineurin B-like protein 5', 'CBL5'],
#   'full_name': 'calcineurin B-like protein 5',
#   'GMM': ['30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 13,
#   'out-degree': 13,
#   'disjoint-path-between-RD29': 12},
#  'AT1G69600': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G69600',
#   'short_name': 'ZFHD1',
#   'synonyms': ['ZINC FINGER HOMEODOMAIN 11',
#    'zinc finger homeodomain  1',
#    'ZFHD1',
#    'ARABIDOPSIS THALIANA HOMEOBOX PROTEIN 29',
#    'ATHB29',
#    'ZHD11'],
#   'full_name': 'zinc finger homeodomain  1',
#   'GMM': ['27.3.80_RNA.regulation of transcription.zf-HD'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 25,
#   'out-degree': 30,
#   'disjoint-path-between-RD29': 10},
#  'AT1G19180': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G19180',
#   'short_name': 'JAZ1',
#   'synonyms': ['TIFY10A', 'JAZ1', 'jasmonate-zim-domain protein 1', 'AtJAZ1'],
#   'full_name': 'jasmonate-zim-domain protein 1',
#   'GMM': ['17.7.2_hormone metabolism.jasmonate.signal transduction',
#    '20.1.3_stress.biotic.signalling',
#    '27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 32,
#   'out-degree': 21,
#   'disjoint-path-between-RD29': 15},
#  'AT5G53160': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G53160',
#   'short_name': 'RCAR3',
#   'synonyms': ['PYR1-like 8',
#    'PYL8',
#    'RCAR3',
#    'regulatory components of ABA receptor 3'],
#   'full_name': 'regulatory components of ABA receptor 3',
#   'GMM': ['20.2.99_stress.abiotic.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 7,
#   'out-degree': 7,
#   'disjoint-path-between-RD29': 7},
#  'AT4G19660': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G19660',
#   'short_name': 'NPR4',
#   'synonyms': ['NPR4', 'NPR1-like protein 4', 'ATNPR4'],
#   'full_name': 'NPR1-like protein 4',
#   'GMM': ['31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 7,
#   'out-degree': 8,
#   'disjoint-path-between-RD29': 8},
#  'AT5G14250': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G14250',
#   'short_name': 'COP13',
#   'synonyms': ['CONSTITUTIVE PHOTOMORPHOGENIC 13',
#    'FUS11',
#    'FUSCA 11',
#    'COP9 SIGNALOSOME SUBUNIT 3',
#    'CSN3',
#    'COP13'],
#   'full_name': 'CONSTITUTIVE PHOTOMORPHOGENIC 13',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '30.11.1_signalling.light.COP9 signalosome',
#    '33.99_development.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 7,
#   'out-degree': 7,
#   'disjoint-path-between-RD29': 6},
#  'AT3G24650': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G24650',
#   'short_name': 'ABI3',
#   'synonyms': ['SUGAR INSENSITIVE 10',
#    'ABI3',
#    'ABA INSENSITIVE 3',
#    'SIS10',
#    'AtABI3',
#    'ABSCISIC ACID INSENSITIVE 3'],
#   'full_name': 'ABA INSENSITIVE 3',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '27.3.1_RNA.regulation of transcription.ABI3/VP1-related B3-domain-containing transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 21,
#   'out-degree': 34,
#   'disjoint-path-between-RD29': 15},
#  'AT5G55990': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G55990',
#   'short_name': 'CBL2',
#   'synonyms': ['ATCBL2',
#    'SCaBP1',
#    'calcineurin B-like protein 2',
#    'CBL2',
#    'SOS3-LIKE CALCIUM BINDING PROTEIN 1'],
#   'full_name': 'calcineurin B-like protein 2',
#   'GMM': ['10.1.5_cell wall.precursor synthesis.UXS',
#    '27.3.1_RNA.regulation of transcription.ABI3/VP1-related B3-domain-containing transcription factor family',
#    '30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 21,
#   'out-degree': 19,
#   'disjoint-path-between-RD29': 15},
#  'AT3G01090': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G01090',
#   'short_name': 'KIN10',
#   'synonyms': ['SNF1 kinase homolog 10',
#    'KIN10',
#    'AKIN10',
#    'SNRK1.1',
#    'SNF1-RELATED PROTEIN KINASE 1.1',
#    'SnRK1'],
#   'full_name': 'SNF1 kinase homolog 10',
#   'GMM': ['29.4.1_protein.postranslational modification.kinase',
#    '30.1.1_signalling.in sugar and nutrient physiology.misc'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 14,
#   'out-degree': 16,
#   'disjoint-path-between-RD29': 13},
#  'AT1G74950': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G74950',
#   'short_name': 'TIFY10B',
#   'synonyms': ['JASMONATE-ZIM-DOMAIN PROTEIN 2', 'TIFY10B', 'JAZ2'],
#   'full_name': 'TIFY domain/Divergent CCT motif family protein',
#   'GMM': ['17.7.2_hormone metabolism.jasmonate.signal transduction',
#    '20.1.3_stress.biotic.signalling',
#    '27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 25,
#   'out-degree': 15,
#   'disjoint-path-between-RD29': 13},
#  'AT1G75950': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G75950',
#   'short_name': 'SKP1',
#   'synonyms': ['ASK1',
#    'S phase kinase-associated protein 1',
#    'SKP1',
#    'SKP1A',
#    'UIP1',
#    'ARABIDOPSIS SKP1 HOMOLOGUE 1',
#    'UFO INTERACTING PROTEIN 1',
#    'ATSKP1'],
#   'full_name': 'S phase kinase-associated protein 1',
#   'GMM': ['29.5.11.4.3.1_protein.degradation.ubiquitin.E3.SCF.SKP',
#    '30.2.17_signalling.receptor kinases.DUF 26'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 102,
#   'out-degree': 102,
#   'disjoint-path-between-RD29': 15},
#  'AT2G01570': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G01570',
#   'short_name': 'RGA1',
#   'synonyms': ['REPRESSOR OF GA1-3 1',
#    'repressor of GA',
#    'RGA1',
#    'RGA',
#    'REPRESSOR OF GA',
#    'RGA24'],
#   'full_name': 'REPRESSOR OF GA1-3 1',
#   'GMM': ['17.6.2_hormone metabolism.gibberelin.signal transduction',
#    '30.1.1_signalling.in sugar and nutrient physiology.misc',
#    '17.6.3_hormone metabolism.gibberelin.induced-regulated-responsive-activated',
#    '27.3.21_RNA.regulation of transcription.GRAS transcription factor family',
#    '33.99_development.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 20,
#   'out-degree': 47,
#   'disjoint-path-between-RD29': 15},
#  'AT5G10030': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G10030',
#   'short_name': 'TGA4',
#   'synonyms': ['TGACG motif-binding factor 4',
#    'OBF4',
#    'OCS ELEMENT BINDING FACTOR 4',
#    'TGA4'],
#   'full_name': 'TGACG motif-binding factor 4',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '29.5.11_protein.degradation.ubiquitin'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 9,
#   'out-degree': 9,
#   'disjoint-path-between-RD29': 9},
#  'AT5G15840': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G15840',
#   'short_name': 'CO',
#   'synonyms': ['CONSTANS', 'B-box domain protein 1', 'CO', 'FG', 'BBX1'],
#   'full_name': 'CONSTANS',
#   'GMM': ['33.99_development.unspecified',
#    '27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 41,
#   'out-degree': 40,
#   'disjoint-path-between-RD29': 15},
#  'AT1G45249': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G45249',
#   'short_name': 'AREB1',
#   'synonyms': ['AREB1',
#    'ABF2',
#    'ATAREB1',
#    'AtABF2',
#    'ABSCISIC ACID RESPONSIVE ELEMENTS-BINDING PROTEIN 2',
#    'abscisic acid responsive elements-binding factor 2'],
#   'full_name': 'abscisic acid responsive elements-binding factor 2',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated',
#    '18.2_Co-factor and vitamine metabolism.thiamine',
#    '26.17_misc.dynamin'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 9,
#   'out-degree': 12,
#   'disjoint-path-between-RD29': 9},
#  'AT1G32640': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G32640',
#   'short_name': 'MYC2',
#   'synonyms': ['ZBF1',
#    'JIN1',
#    'MYC2',
#    'JASMONATE INSENSITIVE 1',
#    'ATMYC2',
#    'JAI1',
#    'RD22BP1'],
#   'full_name': 'Basic helix-loop-helix (bHLH) DNA-binding family protein',
#   'GMM': ['20.1.5_stress.biotic.regulation of transcription',
#    '27.3.6_RNA.regulation of transcription.basic helix-loop-helix family (bHLH)',
#    '29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 34,
#   'out-degree': 70,
#   'disjoint-path-between-RD29': 15},
#  'AT3G15210': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G15210',
#   'short_name': 'ERF4',
#   'synonyms': ['ETHYLENE RESPONSIVE ELEMENT BINDING FACTOR 4',
#    'ERF4',
#    'RELATED TO AP2 5',
#    'ATERF-4',
#    'RAP2.5',
#    'ATERF4',
#    'ethylene responsive element binding factor 4'],
#   'full_name': 'ethylene responsive element binding factor 4',
#   'GMM': ['17.5.2_hormone metabolism.ethylene.signal transduction',
#    '20.1.5_stress.biotic.regulation of transcription',
#    '27.3.3_RNA.regulation of transcription.AP2/EREBP, APETALA2/ethylene-responsive element binding protein family'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 4,
#   'out-degree': 7,
#   'disjoint-path-between-RD29': 3},
#  'AT1G66410': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G66410',
#   'short_name': 'CAM4',
#   'synonyms': ['CALMODULIN 4', 'ACAM-4', 'CAM4', 'calmodulin 4'],
#   'full_name': 'calmodulin 4',
#   'GMM': ['1.1.1.2_PS.lightreaction.photosystem II.PSII polypeptide subunits',
#    '30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 128,
#   'out-degree': 128,
#   'disjoint-path-between-RD29': 15},
#  'AT3G45640': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G45640',
#   'short_name': 'MPK3',
#   'synonyms': ['MPK3',
#    'mitogen-activated protein kinase 3',
#    'ATMAPK3',
#    'ATMPK3'],
#   'full_name': 'mitogen-activated protein kinase 3',
#   'GMM': ['29.4_protein.postranslational modification',
#    '30.6_signalling.MAP kinases',
#    '31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 25,
#   'out-degree': 40,
#   'disjoint-path-between-RD29': 15},
#  'AT1G22070': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G22070',
#   'short_name': 'TGA3',
#   'synonyms': ['TGA3', 'TGA1A-related gene 3'],
#   'full_name': 'TGA1A-related gene 3',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '29.5.11_protein.degradation.ubiquitin'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 9,
#   'out-degree': 10,
#   'disjoint-path-between-RD29': 9},
#  'AT4G17870': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G17870',
#   'short_name': 'PYR1',
#   'synonyms': ['PYR1',
#    'PYRABACTIN RESISTANCE 1',
#    'regulatory component of ABA receptor 11',
#    'RCAR11'],
#   'full_name': 'PYRABACTIN RESISTANCE 1',
#   'GMM': ['20.2.99_stress.abiotic.unspecified',
#    '29.5.5_protein.degradation.serine protease'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 13,
#   'out-degree': 13,
#   'disjoint-path-between-RD29': 11},
#  'AT2G39940': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G39940',
#   'short_name': 'COI1',
#   'synonyms': ['CORONATINE INSENSITIVE 1', 'COI1'],
#   'full_name': 'CORONATINE INSENSITIVE 1',
#   'GMM': ['17.7.3_hormone metabolism.jasmonate.induced-regulated-responsive-activated',
#    '29.5.11.4.3.2_protein.degradation.ubiquitin.E3.SCF.FBOX'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 29,
#   'out-degree': 29,
#   'disjoint-path-between-RD29': 15},
#  'AT5G67300': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G67300',
#   'short_name': 'MYBR1',
#   'synonyms': ['ARABIDOPSIS THALIANA MYB DOMAIN PROTEIN 44',
#    'ATMYB44',
#    'ATMYBR1',
#    'MYBR1',
#    'myb domain protein r1',
#    'MYB44'],
#   'full_name': 'myb domain protein r1',
#   'GMM': ['27.3.25_RNA.regulation of transcription.MYB domain transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 7,
#   'out-degree': 8,
#   'disjoint-path-between-RD29': 7},
#  'AT5G46210': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G46210',
#   'short_name': 'CUL4',
#   'synonyms': ['ATCUL4', 'cullin4', 'CUL4'],
#   'full_name': 'cullin4',
#   'GMM': ['29.5.11.4.3.3_protein.degradation.ubiquitin.E3.SCF.cullin'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 20,
#   'out-degree': 17,
#   'disjoint-path-between-RD29': 15},
#  'AT4G14110': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G14110',
#   'short_name': 'COP9',
#   'synonyms': ['EMB143',
#    'FUSCA 7',
#    'FUS7',
#    'COP9 SIGNALOSOME SUBUNIT 8',
#    'CONSTITUTIVE PHOTOMORPHOGENIC 9',
#    'EMBRYO DEFECTIVE 143',
#    'CSN8',
#    'COP9'],
#   'full_name': 'CONSTITUTIVE PHOTOMORPHOGENIC 9',
#   'GMM': ['30.11.1_signalling.light.COP9 signalosome',
#    '33.99_development.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 10,
#   'out-degree': 11,
#   'disjoint-path-between-RD29': 10},
#  'AT5G46790': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G46790',
#   'short_name': 'PYL1',
#   'synonyms': ['PYR1-like 1',
#    'regulatory components of ABA receptor 12',
#    'PYL1',
#    'RCAR12'],
#   'full_name': 'PYR1-like 1',
#   'GMM': ['20.2.99_stress.abiotic.unspecified',
#    '29.5.5_protein.degradation.serine protease'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 5,
#   'out-degree': 5,
#   'disjoint-path-between-RD29': 5},
#  'AT1G49720': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G49720',
#   'short_name': 'ABF1',
#   'synonyms': ['AtABF1',
#    'abscisic acid responsive element-binding factor 1',
#    'ABF1'],
#   'full_name': 'abscisic acid responsive element-binding factor 1',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated',
#    '18.2_Co-factor and vitamine metabolism.thiamine',
#    '26.17_misc.dynamin'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 10,
#   'out-degree': 10,
#   'disjoint-path-between-RD29': 9},
#  'AT5G65210': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G65210',
#   'short_name': 'TGA1',
#   'synonyms': ['TGA1', 'TGACG sequence-specific binding protein 1'],
#   'full_name': 'TGACG sequence-specific binding protein 1',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '29.5.11_protein.degradation.ubiquitin'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 6,
#   'out-degree': 6,
#   'disjoint-path-between-RD29': 6},
#  'AT3G48100': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G48100',
#   'short_name': 'RR5',
#   'synonyms': ['ARABIDOPSIS THALIANA RESPONSE REGULATOR 2',
#    'ATRR2',
#    'response regulator 5',
#    'INDUCED BY CYTOKININ 6',
#    'RR5',
#    'ARR5',
#    'IBC6'],
#   'full_name': 'response regulator 5',
#   'GMM': ['11.1.9_lipid metabolism.FA synthesis and FA elongation.long chain fatty acid CoA ligase',
#    '17.4.2_hormone metabolism.cytokinin.signal transduction',
#    '26.7_misc.oxidases - copper, flavone etc',
#    '27.3.5_RNA.regulation of transcription.ARR',
#    '30.1_signalling.in sugar and nutrient physiology'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 42,
#   'out-degree': 32,
#   'disjoint-path-between-RD29': 15},
#  'AT2G26650': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G26650',
#   'short_name': 'KT1',
#   'synonyms': ['K+ transporter 1', 'AKT1', 'KT1', 'ATAKT1'],
#   'full_name': 'K+ transporter 1',
#   'GMM': ['34.15_transport.potassium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 10,
#   'out-degree': 10,
#   'disjoint-path-between-RD29': 9},
#  'AT5G57050': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G57050',
#   'short_name': 'ABI2',
#   'synonyms': ['ABI2', 'AtABI2', 'ABA INSENSITIVE 2'],
#   'full_name': 'ABA INSENSITIVE 2',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 23,
#   'out-degree': 20,
#   'disjoint-path-between-RD29': 15},
#  'AT5G13220': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G13220',
#   'short_name': 'PW220',
#   'synonyms': ['PW220',
#    'TIFY DOMAIN PROTEIN 9',
#    'JASMONATE-ASSOCIATED 1',
#    'JAZ10',
#    'TIFY9',
#    'JAS1',
#    'jasmonate-zim-domain protein 10'],
#   'full_name': 'jasmonate-zim-domain protein 10',
#   'GMM': ['27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 26,
#   'out-degree': 17,
#   'disjoint-path-between-RD29': 15},
#  'AT5G42970': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G42970',
#   'short_name': 'COP8',
#   'synonyms': ['CONSTITUTIVE PHOTOMORPHOGENIC 14',
#    'COP14',
#    'FUS4',
#    'EMBRYO DEFECTIVE 134',
#    'ATS4',
#    'EMB134',
#    'COP9 SIGNALOSOME SUBUNIT 4',
#    'CSN4',
#    'FUSCA 4',
#    'FUS8',
#    'FUSCA 8',
#    'COP8',
#    'CONSTITUTIVE PHOTOMORPHOGENIC 8'],
#   'full_name': 'CONSTITUTIVE PHOTOMORPHOGENIC 8',
#   'GMM': ['29.2.2_protein.synthesis.ribosome biogenesis',
#    '30.11.1_signalling.light.COP9 signalosome'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 15,
#   'out-degree': 11,
#   'disjoint-path-between-RD29': 10},
#  'AT1G07430': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G07430',
#   'short_name': 'HAI2',
#   'synonyms': ['AKT1 interacting protein phosphatase 1',
#    'AIP1',
#    'highly ABA-induced PP2C gene 2',
#    'AtAIP1',
#    'HON',
#    'HAI2',
#    'HONSU (Korean for abnormal drowsiness)'],
#   'full_name': 'highly ABA-induced PP2C gene 2',
#   'GMM': ['29.4_protein.postranslational modification',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 8,
#   'out-degree': 8,
#   'disjoint-path-between-RD29': 8},
#  'AT1G13740': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G13740',
#   'short_name': 'AFP2',
#   'synonyms': ['LNJ', 'AFP2', 'ABI five binding protein 2', 'LITTLE NINJA'],
#   'full_name': 'ABI five binding protein 2',
#   'GMM': ['29.3.1_protein.targeting.nucleus'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 14,
#   'out-degree': 14,
#   'disjoint-path-between-RD29': 13},
#  'AT4G34000': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G34000',
#   'short_name': 'ABF3',
#   'synonyms': ['abscisic acid responsive elements-binding factor 3',
#    'ABF3',
#    'DC3 PROMOTER-BINDING FACTOR 5',
#    'AtABF3',
#    'DPBF5'],
#   'full_name': 'abscisic acid responsive elements-binding factor 3',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated',
#    '18.2_Co-factor and vitamine metabolism.thiamine',
#    '26.17_misc.dynamin'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 12,
#   'out-degree': 13,
#   'disjoint-path-between-RD29': 12},
#  'AT1G01360': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G01360',
#   'short_name': 'RCAR1',
#   'synonyms': ['PYL9',
#    'regulatory component of ABA receptor 1',
#    'PYRABACTIN RESISTANCE 1-LIKE 9',
#    'RCAR1'],
#   'full_name': 'regulatory component of ABA receptor 1',
#   'GMM': ['20.2.99_stress.abiotic.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 6,
#   'out-degree': 6,
#   'disjoint-path-between-RD29': 6},
#  'AT3G54620': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G54620',
#   'short_name': 'BZIP25',
#   'synonyms': ['BZIP25',
#    'BASIC LEUCINE ZIPPER O2 HOMOLOG 4',
#    'ATBZIP25',
#    'ARABIDOPSIS THALIANA BASIC LEUCINE ZIPPER 25',
#    'BZO2H4',
#    'basic leucine zipper 25'],
#   'full_name': 'basic leucine zipper 25',
#   'GMM': ['15.2_metal handling.binding, chelation and storage',
#    '27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 12,
#   'out-degree': 13,
#   'disjoint-path-between-RD29': 13},
#  'AT2G41070': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G41070',
#   'short_name': 'DPBF4',
#   'synonyms': ['ATBZIP12', 'ENHANCED EM LEVEL', 'DPBF4', 'EEL'],
#   'full_name': 'ENHANCED EM LEVEL',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated',
#    '17.1.2_hormone metabolism.abscisic acid.signal transduction'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 5,
#   'out-degree': 5,
#   'disjoint-path-between-RD29': 5},
#  'AT4G22200': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G22200',
#   'short_name': 'KT2/3',
#   'synonyms': ['AKT2/3', 'AKT3', 'AKT2', 'potassium transport 2/3', 'KT2/3'],
#   'full_name': 'potassium transport 2/3',
#   'GMM': ['34.15_transport.potassium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 10,
#   'out-degree': 10,
#   'disjoint-path-between-RD29': 8},
#  'AT5G05410': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G05410',
#   'short_name': 'DREB2A',
#   'synonyms': ['DREB2',
#    'DRE-binding protein 2A',
#    'DEHYDRATION-RESPONSIVE ELEMENT BINDING PROTEIN 2',
#    'DREB2A'],
#   'full_name': 'DRE-binding protein 2A',
#   'GMM': ['27.3.3_RNA.regulation of transcription.AP2/EREBP, APETALA2/ethylene-responsive element binding protein family'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 32,
#   'out-degree': 43,
#   'disjoint-path-between-RD29': 14},
#  'AT2G37630': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G37630',
#   'short_name': 'AS1',
#   'synonyms': ['AS1',
#    'ASYMMETRIC LEAVES 1',
#    'LL2',
#    'LOTUS LEAF 2',
#    'MYB91',
#    'ATMYB91',
#    'ATPHAN',
#    'MYB DOMAIN PROTEIN 91',
#    'ARABIDOPSIS PHANTASTICA-LIKE 1'],
#   'full_name': 'ASYMMETRIC LEAVES 1',
#   'GMM': ['20.2.1_stress.abiotic.heat',
#    '27.3.25_RNA.regulation of transcription.MYB domain transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 11,
#   'out-degree': 18,
#   'disjoint-path-between-RD29': 14},
#  'AT5G08720': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G08720',
#   'short_name': 'HCF145',
#   'synonyms': ['HIGH CHLOROPHYLL FLUORESCENCE 145',
#    'PPP1',
#    'PIN2 PROMOTER BINDING PROTEIN 1',
#    'HCF145'],
#   'full_name': nan,
#   'GMM': ['35.2_not assigned.unknown'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 10,
#   'out-degree': 10,
#   'disjoint-path-between-RD29': 10},
#  'AT3G19290': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G19290',
#   'short_name': 'ABF4',
#   'synonyms': ['ABF4',
#    'ABRE binding factor 4',
#    'ABA-RESPONSIVE ELEMENT BINDING PROTEIN 2',
#    'AtAREB2',
#    'AREB2'],
#   'full_name': 'ABRE binding factor 4',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated',
#    '18.2_Co-factor and vitamine metabolism.thiamine',
#    '26.17_misc.dynamin'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 23,
#   'out-degree': 22,
#   'disjoint-path-between-RD29': 15},
#  'AT4G26570': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G26570',
#   'short_name': 'CBL3',
#   'synonyms': ['ATCBL3', 'calcineurin B-like 3', 'CBL3'],
#   'full_name': 'calcineurin B-like 3',
#   'GMM': ['10.1.5_cell wall.precursor synthesis.UXS',
#    '27.3.1_RNA.regulation of transcription.ABI3/VP1-related B3-domain-containing transcription factor family',
#    '30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 21,
#   'out-degree': 21,
#   'disjoint-path-between-RD29': 15},
#  'AT2G36270': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G36270',
#   'short_name': 'ABI5',
#   'synonyms': ['ABI5',
#    'GROWTH-INSENSITIVITY TO ABA 1',
#    'DPBF1',
#    'AtABI5',
#    'ABA INSENSITIVE 5',
#    'GIA1'],
#   'full_name': 'ABA INSENSITIVE 5',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family',
#    '17.1.2_hormone metabolism.abscisic acid.signal transduction'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 29,
#   'out-degree': 28,
#   'disjoint-path-between-RD29': 15},
#  'AT4G17615': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G17615',
#   'short_name': 'SCABP5',
#   'synonyms': ['SCABP5',
#    'SOS3-LIKE CALCIUM BINDING PROTEIN 5',
#    'ARABIDOPSIS THALIANA CALCINEURIN B-LIKE PROTEIN',
#    'CBL1',
#    'ATCBL1',
#    'calcineurin B-like protein 1'],
#   'full_name': 'calcineurin B-like protein 1',
#   'GMM': ['30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 25,
#   'out-degree': 25,
#   'disjoint-path-between-RD29': 15},
#  'AT5G35410': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G35410',
#   'short_name': 'SOS2',
#   'synonyms': ['SALT OVERLY SENSITIVE 2',
#    'CIPK24',
#    'SNF1-RELATED PROTEIN KINASE 3.11',
#    'SOS2',
#    'ATSOS2',
#    'SNRK3.11',
#    'CBL-INTERACTING PROTEIN KINASE 24'],
#   'full_name': 'SALT OVERLY SENSITIVE 2',
#   'GMM': ['29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 40,
#   'out-degree': 39,
#   'disjoint-path-between-RD29': 15},
#  'AT1G73000': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G73000',
#   'short_name': 'PYL3',
#   'synonyms': ['regulatory components of ABA receptor 13',
#    'PYL3',
#    'RCAR13',
#    'PYR1-like 3'],
#   'full_name': 'PYR1-like 3',
#   'GMM': ['35.2_not assigned.unknown'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 4,
#   'out-degree': 4,
#   'disjoint-path-between-RD29': 4},
#  'AT4G26560': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G26560',
#   'short_name': 'CBL7',
#   'synonyms': ['(SOS3-LIKE CALCIUM BINDING PROTEIN 3',
#    'CBL7',
#    'SCaBP3',
#    'calcineurin B-like protein 7'],
#   'full_name': 'calcineurin B-like protein 7',
#   'GMM': ['30.3_signalling.calcium'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 2,
#   'out-degree': 2,
#   'disjoint-path-between-RD29': 2},
#  'AT3G50670': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G50670',
#   'short_name': 'U1-70K',
#   'synonyms': ['U1 small nuclear ribonucleoprotein-70K', 'U1-70K', 'U1SNRNP'],
#   'full_name': 'U1 small nuclear ribonucleoprotein-70K',
#   'GMM': ['27.1.1_RNA.processing.splicing',
#    '33.99_development.unspecified',
#    '17.3.1.2.6_hormone metabolism.brassinosteroid.synthesis-degradation.sterols.DWF7',
#    '27.4_RNA.RNA binding'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 15,
#   'out-degree': 14,
#   'disjoint-path-between-RD29': 14},
#  'AT1G02840': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G02840',
#   'short_name': 'SR34',
#   'synonyms': ['At-SR34',
#    'SRP34',
#    'Serine/Arginine-Rich Protein Splicing Factor 34',
#    'SR34',
#    'ATSRP34',
#    'SR1'],
#   'full_name': 'Serine/Arginine-Rich Protein Splicing Factor 34',
#   'GMM': ['27.1.1_RNA.processing.splicing'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 17,
#   'out-degree': 17,
#   'disjoint-path-between-RD29': 14},
#  'AT2G43790': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G43790',
#   'short_name': 'MPK6',
#   'synonyms': ['MAP kinase 6', 'MAPK6', 'ATMPK6', 'ATMAPK6', 'MPK6'],
#   'full_name': 'MAP kinase 6',
#   'GMM': ['29.4_protein.postranslational modification',
#    '30.6_signalling.MAP kinases'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 30,
#   'out-degree': 46,
#   'disjoint-path-between-RD29': 15},
#  'AT1G70700': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G70700',
#   'short_name': 'JAZ9',
#   'synonyms': ['JASMONATE-ZIM-DOMAIN PROTEIN 9', 'TIFY7', 'JAZ9'],
#   'full_name': 'TIFY domain/Divergent CCT motif family protein',
#   'GMM': ['17.6.3_hormone metabolism.gibberelin.induced-regulated-responsive-activated',
#    '21.1_redox.thioredoxin',
#    '27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 25,
#   'out-degree': 17,
#   'disjoint-path-between-RD29': 15},
#  'AT5G45110': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G45110',
#   'short_name': 'NPR3',
#   'synonyms': ['NPR1-like protein 3', 'NPR3', 'ATNPR3'],
#   'full_name': 'NPR1-like protein 3',
#   'GMM': ['31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 6,
#   'out-degree': 6,
#   'disjoint-path-between-RD29': 6},
#  'AT3G03450': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G03450',
#   'short_name': 'RGL2',
#   'synonyms': ['RGL2', 'RGA-like 2'],
#   'full_name': 'RGA-like 2',
#   'GMM': ['30.1.1_signalling.in sugar and nutrient physiology.misc',
#    '17.6.2_hormone metabolism.gibberelin.signal transduction',
#    '17.6.3_hormone metabolism.gibberelin.induced-regulated-responsive-activated',
#    '27.3.21_RNA.regulation of transcription.GRAS transcription factor family',
#    '33.99_development.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 16,
#   'out-degree': 31,
#   'disjoint-path-between-RD29': 15},
#  'AT3G17860': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G17860',
#   'short_name': 'JAZ3',
#   'synonyms': ['TIFY6B',
#    'JAI3',
#    'jasmonate-zim-domain protein 3',
#    'JASMONATE-INSENSITIVE 3',
#    'JAZ3'],
#   'full_name': 'jasmonate-zim-domain protein 3',
#   'GMM': ['27.3.7_RNA.regulation of transcription.C2C2(Zn) Constans-like zinc finger family (CO-like)'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 28,
#   'out-degree': 19,
#   'disjoint-path-between-RD29': 15},
#  'AT1G14920': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G14920',
#   'short_name': 'GAI',
#   'synonyms': ['GIBBERELLIC ACID INSENSITIVE',
#    'GAI',
#    'RESTORATION ON GROWTH ON AMMONIA 2',
#    'RGA2'],
#   'full_name': 'GIBBERELLIC ACID INSENSITIVE',
#   'GMM': ['17.6.3_hormone metabolism.gibberelin.induced-regulated-responsive-activated',
#    '30.1.1_signalling.in sugar and nutrient physiology.misc',
#    '17.6.2_hormone metabolism.gibberelin.signal transduction',
#    '27.3.21_RNA.regulation of transcription.GRAS transcription factor family',
#    '33.99_development.unspecified'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 13,
#   'out-degree': 29,
#   'disjoint-path-between-RD29': 15},
#  'AT5G06960': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G06960',
#   'short_name': 'OBF5',
#   'synonyms': ['OBF5',
#    'TGACG MOTIF-BINDING FACTOR 5',
#    'TGA5',
#    'OCS-element binding factor 5'],
#   'full_name': 'OCS-element binding factor 5',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 16,
#   'out-degree': 22,
#   'disjoint-path-between-RD29': 15},
#  'EDS1|PAD4': {'node_type': 'complex',
#   'species': 'ath',
#   'TAIR': nan,
#   'short_name': 'EDS1|PAD4',
#   'synonyms': None,
#   'full_name': nan,
#   'GMM': None,
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 10,
#   'out-degree': 8,
#   'disjoint-path-between-RD29': 6},
#  'AT3G11410': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G11410',
#   'short_name': 'PP2CA',
#   'synonyms': ['AHG3',
#    'ABA-HYPERSENSITIVE GERMINATION 3',
#    'ATPP2CA',
#    'protein phosphatase 2CA',
#    'ARABIDOPSIS THALIANA PROTEIN PHOSPHATASE 2CA',
#    'PP2CA'],
#   'full_name': 'protein phosphatase 2CA',
#   'GMM': ['29.4_protein.postranslational modification',
#    '17.1.3_hormone metabolism.abscisic acid.induced-regulated-responsive-activated'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 29,
#   'out-degree': 25,
#   'disjoint-path-between-RD29': 15},
#  'AT1G32230': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G32230',
#   'short_name': 'RCD1',
#   'synonyms': ['AtRCD1',
#    'ATP8',
#    'CEO',
#    'ARABIDOPSIS THALIANA P8 (INTERACTING PROTEIN)',
#    'RIMB1',
#    'RADICAL-INDUCED CELL DEATH1',
#    'CEO1',
#    'REDOX IMBALANCED 1',
#    'RCD1'],
#   'full_name': 'RADICAL-INDUCED CELL DEATH1',
#   'GMM': ['20.2.5_stress.abiotic.light',
#    '29.4_protein.postranslational modification',
#    '20.2.3_stress.abiotic.drought/salt'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 26,
#   'out-degree': 26,
#   'disjoint-path-between-RD29': 12},
#  'AT4G26080': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G26080',
#   'short_name': 'ABI1',
#   'synonyms': ['AtABI1', 'ABA INSENSITIVE 1', 'ABI1'],
#   'full_name': 'ABA INSENSITIVE 1',
#   'GMM': ['17.1.2_hormone metabolism.abscisic acid.signal transduction',
#    '29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 41,
#   'out-degree': 40,
#   'disjoint-path-between-RD29': 15},
#  'AT5G39760': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G39760',
#   'short_name': 'HB23',
#   'synonyms': ['HB23',
#    'AtHB23',
#    'ZINC FINGER HOMEODOMAIN 10',
#    'ZHD10',
#    'homeobox protein 23'],
#   'full_name': 'homeobox protein 23',
#   'GMM': ['27.3.80_RNA.regulation of transcription.zf-HD'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 13,
#   'out-degree': 13,
#   'disjoint-path-between-RD29': 9},
#  'AT1G10940': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G10940',
#   'short_name': 'SNRK2.4',
#   'synonyms': ['ASK1',
#    'SNRK2-4',
#    'SRK2A',
#    'SUCROSE NONFERMENTING 1-RELATED PROTEIN KINASE 2-4',
#    'SNRK2.4',
#    'ARABIDOPSIS SERINE/THREONINE KINASE 1',
#    'SNF1-related protein kinase 2.4'],
#   'full_name': 'SNF1-related protein kinase 2.4',
#   'GMM': ['29.4_protein.postranslational modification'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 13,
#   'out-degree': 31,
#   'disjoint-path-between-RD29': 15},
#  'AT1G27730': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G27730',
#   'short_name': 'STZ',
#   'synonyms': ['STZ', 'ZAT10', 'salt tolerance zinc finger'],
#   'full_name': 'salt tolerance zinc finger',
#   'GMM': ['19.1_tetrapyrrole synthesis.glu-tRNA synthetase',
#    '20_stress',
#    '27.3.11_RNA.regulation of transcription.C2H2 zinc finger family'],
#   'note': nan,
#   'distance-to-RD29': 1,
#   'in-degree': 1,
#   'out-degree': 6,
#   'disjoint-path-between-RD29': 5},
#  'AT5G06950': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT5G06950',
#   'short_name': 'AHBP-1B',
#   'synonyms': ['AtTGA2',
#    'AHBP-1B',
#    'TGACG sequence-specific binding protein 2',
#    'TGA2'],
#   'full_name': 'bZIP transcription factor family protein',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 21,
#   'out-degree': 27,
#   'disjoint-path-between-RD29': 15},
#  'AT1G26830': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G26830',
#   'short_name': 'CUL3',
#   'synonyms': ['ATCUL3', 'CUL3', 'cullin 3', 'ATCUL3A', 'CUL3A', 'cullin 3A'],
#   'full_name': 'cullin 3',
#   'GMM': ['29.5.11.4.5.1_protein.degradation.ubiquitin.E3.BTB/POZ Cullin3.Cullin3',
#    '29.5.11.4.3.3_protein.degradation.ubiquitin.E3.SCF.cullin'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 47,
#   'out-degree': 47,
#   'disjoint-path-between-RD29': 15},
#  'AT1G28480': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G28480',
#   'short_name': 'GRX480',
#   'synonyms': ['ROXY19', 'GRXC9', 'GRX480'],
#   'full_name': 'Thioredoxin superfamily protein',
#   'GMM': ['21.4_redox.glutaredoxins'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 11,
#   'out-degree': 11,
#   'disjoint-path-between-RD29': 9},
#  'AT3G62420': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G62420',
#   'short_name': 'BZIP53',
#   'synonyms': ['ATBZIP53', 'basic region/leucine zipper motif 53', 'BZIP53'],
#   'full_name': 'basic region/leucine zipper motif 53',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 2,
#   'in-degree': 21,
#   'out-degree': 23,
#   'disjoint-path-between-RD29': 15},
#  'AT3G12250': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT3G12250',
#   'short_name': 'TGA6',
#   'synonyms': ['TGACG motif-binding factor 6', 'TGA6', 'BZIP45'],
#   'full_name': 'TGACG motif-binding factor 6',
#   'GMM': ['27.3.35_RNA.regulation of transcription.bZIP transcription factor family'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 13,
#   'out-degree': 20,
#   'disjoint-path-between-RD29': 15},
#  'AT1G64280': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT1G64280',
#   'short_name': 'NPR1',
#   'synonyms': ['NIM1',
#    'SALICYLIC ACID INSENSITIVE 1',
#    'NPR1',
#    'ARABIDOPSIS NONEXPRESSER OF PR GENES 1',
#    'SAI1',
#    'ATNPR1',
#    'NON-INDUCIBLE IMMUNITY 1',
#    'NONEXPRESSER OF PR GENES 1'],
#   'full_name': 'NONEXPRESSER OF PR GENES 1',
#   'GMM': ['27.3.61_RNA.regulation of transcription.NPR1/NIM1',
#    '31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 35,
#   'out-degree': 26,
#   'disjoint-path-between-RD29': 15},
#  'AT2G26040': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT2G26040',
#   'short_name': 'PYL2',
#   'synonyms': ['regulatory components of ABA receptor 14',
#    'PYL2',
#    'PYR1-like 2',
#    'RCAR14'],
#   'full_name': 'PYR1-like 2',
#   'GMM': ['20.2.99_stress.abiotic.unspecified',
#    '29.5.5_protein.degradation.serine protease'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 4,
#   'out-degree': 4,
#   'disjoint-path-between-RD29': 4},
#  'AT4G26840': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G26840',
#   'short_name': 'SUMO1',
#   'synonyms': ['small ubiquitin-like modifier 1',
#    'ATSUMO1',
#    'SUMO 1',
#    'SUM1',
#    'SMALL UBIQUITIN-LIKE MODIFIER 1',
#    'SUMO1',
#    'ARABIDOPSIS THALIANA SMALL UBIQUITIN-LIKE MODIFIER 1'],
#   'full_name': 'small ubiquitin-like modifier 1',
#   'GMM': ['29.5.11.1_protein.degradation.ubiquitin.ubiquitin',
#    '31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 3,
#   'in-degree': 31,
#   'out-degree': 31,
#   'disjoint-path-between-RD29': 15},
#  'AT4G04020': {'node_type': 'protein_coding',
#   'species': 'ath',
#   'TAIR': 'AT4G04020',
#   'short_name': 'FIB',
#   'synonyms': ['fibrillin 1a',
#    'fibrillin',
#    'FIB1a',
#    'plastoglobulin 35',
#    'FIB',
#    'PGL35'],
#   'full_name': 'fibrillin',
#   'GMM': ['26.2_misc.UDP glucosyl and glucoronyl transferases',
#    '31.1_cell.organisation'],
#   'note': nan,
#   'distance-to-RD29': 4,
#   'in-degree': 5,
#   'out-degree': 5,
#   'disjoint-path-between-RD29': 5}}

# %%
# x = pd.DataFrame.from_dict(all_node_attributes, orient='index')

# %%
# x.sort_values(by=f'disjoint-path-between-{target}', ascending=True)
# Out:
#                 node_type species       TAIR short_name  \
# AT4G26560  protein_coding     ath  AT4G26560       CBL7
# AT3G15210  protein_coding     ath  AT3G15210       ERF4
# AT2G26040  protein_coding     ath  AT2G26040       PYL2
# AT1G73000  protein_coding     ath  AT1G73000       PYL3
# AT4G04020  protein_coding     ath  AT4G04020        FIB
# ...                   ...     ...        ...        ...
# AT2G01570  protein_coding     ath  AT2G01570       RGA1
# AT1G75950  protein_coding     ath  AT1G75950       SKP1
# AT2G43790  protein_coding     ath  AT2G43790       MPK6
# AT3G19290  protein_coding     ath  AT3G19290       ABF4
# AT4G02640  protein_coding     ath  AT4G02640     BZO2H1
#
#                                                     synonyms  \
# AT4G26560  [(SOS3-LIKE CALCIUM BINDING PROTEIN 3, CBL7, S...
# AT3G15210  [ETHYLENE RESPONSIVE ELEMENT BINDING FACTOR 4,...
# AT2G26040  [regulatory components of ABA receptor 14, PYL...
# AT1G73000  [regulatory components of ABA receptor 13, PYL...
# AT4G04020  [fibrillin 1a, fibrillin, FIB1a, plastoglobuli...
# ...                                                      ...
# AT2G01570  [REPRESSOR OF GA1-3 1, repressor of GA, RGA1, ...
# AT1G75950  [ASK1, S phase kinase-associated protein 1, SK...
# AT2G43790       [MAP kinase 6, MAPK6, ATMPK6, ATMAPK6, MPK6]
# AT3G19290  [ABF4, ABRE binding factor 4, ABA-RESPONSIVE E...
# AT4G02640  [BZO2H1, Arabidopsis thaliana basic leucine zi...
#
#                                               full_name  \
# AT4G26560                  calcineurin B-like protein 7
# AT3G15210  ethylene responsive element binding factor 4
# AT2G26040                                   PYR1-like 2
# AT1G73000                                   PYR1-like 3
# AT4G04020                                     fibrillin
# ...                                                 ...
# AT2G01570                          REPRESSOR OF GA1-3 1
# AT1G75950           S phase kinase-associated protein 1
# AT2G43790                                  MAP kinase 6
# AT3G19290                         ABRE binding factor 4
# AT4G02640      bZIP transcription factor family protein
#
#                                                          GMM  note  \
# AT4G26560                          [30.3_signalling.calcium]   NaN
# AT3G15210  [17.5.2_hormone metabolism.ethylene.signal tra...   NaN
# AT2G26040  [20.2.99_stress.abiotic.unspecified, 29.5.5_pr...   NaN
# AT1G73000                        [35.2_not assigned.unknown]   NaN
# AT4G04020  [26.2_misc.UDP glucosyl and glucoronyl transfe...   NaN
# ...                                                      ...   ...
# AT2G01570  [17.6.2_hormone metabolism.gibberelin.signal t...   NaN
# AT1G75950  [29.5.11.4.3.1_protein.degradation.ubiquitin.E...   NaN
# AT2G43790  [29.4_protein.postranslational modification, 3...   NaN
# AT3G19290  [17.1.2_hormone metabolism.abscisic acid.signa...   NaN
# AT4G02640  [15.2_metal handling.binding, chelation and st...   NaN
#
#            distance-to-RD29  in-degree  out-degree  disjoint-path-between-RD29
# AT4G26560                 3          2           2                           2
# AT3G15210                 4          4           7                           3
# AT2G26040                 3          4           4                           4
# AT1G73000                 3          4           4                           4
# AT4G04020                 4          5           5                           5
# ...                     ...        ...         ...                         ...
# AT2G01570                 2         20          47                          15
# AT1G75950                 3        102         102                          15
# AT2G43790                 4         30          46                          15
# AT3G19290                 1         23          22                          15
# AT4G02640                 2         19          19                          15
#
# [80 rows x 12 columns]

# %%
# source_reason = "ABA-receptors"
# paths = aba_rd29_paths

# for (source, target_path_node) in paths:
#     for path in paths[(source, target_path_node)]:
#         for node in path[:-1]:
#             all_node_attributes[node][f'distance-from-source {source}/{source_reason}'] = len(nx.shortest_path(g, source=source, target=node)) -1
# #             all_node_attributes[node]['distance-to-target-on-ABA-path'] = len(nx.shortest_path(g, source=node, target=target_path_node)) -1
#             all_node_attributes[node][f'source {source_reason}'] = True

# %%
# source_reason = "JA-receptors"
# paths = ja_aba_rd29_paths

# for (source, target_path_node) in paths:
#     for path in paths[(source, target_path_node)]:
#         for node in path[:-1]:
#             all_node_attributes[node][f'distance-from-source {source}/{source_reason}'] = len(nx.shortest_path(g, source=source, target=node)) -1
#             all_node_attributes[node]['distance-to-target-on-ABA-path'] = len(nx.shortest_path(g, source=node, target=target_path_node)) -1
#             all_node_attributes[node][f'source {source_reason}'] = True

# %%
# source_reason = "SA-receptors"
# paths = sa_aba_rd29_paths

# for (source, target_path_node) in paths:
#     for path in paths[(source, target_path_node)]:
#         for node in path[:-1]:
#             all_node_attributes[node][f'distance-from-source {source}/{source_reason}'] = len(nx.shortest_path(g, source=source, target=node)) -1
#             all_node_attributes[node]['distance-to-target-on-ABA-path'] = len(nx.shortest_path(g, source=node, target=target_path_node)) -1
#             all_node_attributes[node][f'source {source_reason}'] = True

# %%
# x= pd.DataFrame.from_dict(all_node_attributes, orient='index')

# %%
# for source in ['ABA', 'JA', 'SA']:
#     print(source)
#     display(x[x[f'source {source}-receptors'] == True].sort_values(by=f'disjoint-path-between-{target}', ascending=True).head())
# Out:
# ABA
#                 node_type species       TAIR short_name  \
# AT1G73000  protein_coding     ath  AT1G73000       PYL3
# AT2G26040  protein_coding     ath  AT2G26040       PYL2
# AT5G46790  protein_coding     ath  AT5G46790       PYL1
# AT1G27730  protein_coding     ath  AT1G27730        STZ
# AT1G01360  protein_coding     ath  AT1G01360      RCAR1
#
#                                                     synonyms  \
# AT1G73000  [regulatory components of ABA receptor 13, PYL...
# AT2G26040  [regulatory components of ABA receptor 14, PYL...
# AT5G46790  [PYR1-like 1, regulatory components of ABA rec...
# AT1G27730           [STZ, ZAT10, salt tolerance zinc finger]
# AT1G01360  [PYL9, regulatory component of ABA receptor 1,...
#
#                                         full_name  \
# AT1G73000                             PYR1-like 3
# AT2G26040                             PYR1-like 2
# AT5G46790                             PYR1-like 1
# AT1G27730              salt tolerance zinc finger
# AT1G01360  regulatory component of ABA receptor 1
#
#                                                          GMM  note  \
# AT1G73000                        [35.2_not assigned.unknown]   NaN
# AT2G26040  [20.2.99_stress.abiotic.unspecified, 29.5.5_pr...   NaN
# AT5G46790  [20.2.99_stress.abiotic.unspecified, 29.5.5_pr...   NaN
# AT1G27730  [19.1_tetrapyrrole synthesis.glu-tRNA syntheta...   NaN
# AT1G01360               [20.2.99_stress.abiotic.unspecified]   NaN
#
#            distance-to-RD29  in-degree  ...  source JA-receptors  \
# AT1G73000                 3          4  ...                  NaN
# AT2G26040                 3          4  ...                  NaN
# AT5G46790                 3          5  ...                  NaN
# AT1G27730                 1          1  ...                  NaN
# AT1G01360                 3          6  ...                  NaN
#
#            distance-from-source AT1G64280/SA-receptors  \
# AT1G73000                                          NaN
# AT2G26040                                          NaN
# AT5G46790                                          NaN
# AT1G27730                                          2.0
# AT1G01360                                          3.0
#
#            distance-from-source AT4G19660/SA-receptors  \
# AT1G73000                                          NaN
# AT2G26040                                          NaN
# AT5G46790                                          NaN
# AT1G27730                                          3.0
# AT1G01360                                          NaN
#
#            distance-from-source AT5G53160/ABA-receptors source ABA-receptors  \
# AT1G73000                                           NaN                 True
# AT2G26040                                           NaN                 True
# AT5G46790                                           NaN                 True
# AT1G27730                                           NaN                 True
# AT1G01360                                           NaN                 True
#
#            distance-from-source AT4G17870/ABA-receptors  \
# AT1G73000                                           NaN
# AT2G26040                                           NaN
# AT5G46790                                           NaN
# AT1G27730                                           NaN
# AT1G01360                                           NaN
#
#           distance-from-source AT5G46790/ABA-receptors  \
# AT1G73000                                          NaN
# AT2G26040                                          NaN
# AT5G46790                                          0.0
# AT1G27730                                          NaN
# AT1G01360                                          NaN
#
#            distance-from-source AT2G26040/ABA-receptors  \
# AT1G73000                                           NaN
# AT2G26040                                           0.0
# AT5G46790                                           NaN
# AT1G27730                                           NaN
# AT1G01360                                           NaN
#
#            distance-from-source AT1G73000/ABA-receptors  \
# AT1G73000                                           0.0
# AT2G26040                                           NaN
# AT5G46790                                           NaN
# AT1G27730                                           NaN
# AT1G01360                                           NaN
#
#            distance-from-source AT1G01360/ABA-receptors
# AT1G73000                                           NaN
# AT2G26040                                           NaN
# AT5G46790                                           NaN
# AT1G27730                                           2.0
# AT1G01360                                           0.0
#
# [5 rows x 26 columns]
# JA
#                 node_type species       TAIR short_name  \
# AT4G04020  protein_coding     ath  AT4G04020        FIB
# AT5G14250  protein_coding     ath  AT5G14250      COP13
# AT1G45249  protein_coding     ath  AT1G45249      AREB1
# AT1G49720  protein_coding     ath  AT1G49720       ABF1
# AT5G42970  protein_coding     ath  AT5G42970       COP8
#
#                                                     synonyms  \
# AT4G04020  [fibrillin 1a, fibrillin, FIB1a, plastoglobuli...
# AT5G14250  [CONSTITUTIVE PHOTOMORPHOGENIC 13, FUS11, FUSC...
# AT1G45249  [AREB1, ABF2, ATAREB1, AtABF2, ABSCISIC ACID R...
# AT1G49720  [AtABF1, abscisic acid responsive element-bind...
# AT5G42970  [CONSTITUTIVE PHOTOMORPHOGENIC 14, COP14, FUS4...
#
#                                                    full_name  \
# AT4G04020                                          fibrillin
# AT5G14250                   CONSTITUTIVE PHOTOMORPHOGENIC 13
# AT1G45249  abscisic acid responsive elements-binding fact...
# AT1G49720  abscisic acid responsive element-binding factor 1
# AT5G42970                    CONSTITUTIVE PHOTOMORPHOGENIC 8
#
#                                                          GMM  note  \
# AT4G04020  [26.2_misc.UDP glucosyl and glucoronyl transfe...   NaN
# AT5G14250  [27.3.35_RNA.regulation of transcription.bZIP ...   NaN
# AT1G45249  [17.1.2_hormone metabolism.abscisic acid.signa...   NaN
# AT1G49720  [17.1.2_hormone metabolism.abscisic acid.signa...   NaN
# AT5G42970  [29.2.2_protein.synthesis.ribosome biogenesis,...   NaN
#
#            distance-to-RD29  in-degree  ...  source JA-receptors  \
# AT4G04020                 4          5  ...                 True
# AT5G14250                 3          7  ...                 True
# AT1G45249                 1          9  ...                 True
# AT1G49720                 1         10  ...                 True
# AT5G42970                 4         15  ...                 True
#
#            distance-from-source AT1G64280/SA-receptors  \
# AT4G04020                                          NaN
# AT5G14250                                          NaN
# AT1G45249                                          3.0
# AT1G49720                                          NaN
# AT5G42970                                          1.0
#
#            distance-from-source AT4G19660/SA-receptors  \
# AT4G04020                                          NaN
# AT5G14250                                          NaN
# AT1G45249                                          NaN
# AT1G49720                                          NaN
# AT5G42970                                          2.0
#
#            distance-from-source AT5G53160/ABA-receptors source ABA-receptors  \
# AT4G04020                                           NaN                  NaN
# AT5G14250                                           NaN                  NaN
# AT1G45249                                           2.0                 True
# AT1G49720                                           NaN                  NaN
# AT5G42970                                           NaN                  NaN
#
#            distance-from-source AT4G17870/ABA-receptors  \
# AT4G04020                                           NaN
# AT5G14250                                           NaN
# AT1G45249                                           2.0
# AT1G49720                                           NaN
# AT5G42970                                           NaN
#
#           distance-from-source AT5G46790/ABA-receptors  \
# AT4G04020                                          NaN
# AT5G14250                                          NaN
# AT1G45249                                          2.0
# AT1G49720                                          NaN
# AT5G42970                                          NaN
#
#            distance-from-source AT2G26040/ABA-receptors  \
# AT4G04020                                           NaN
# AT5G14250                                           NaN
# AT1G45249                                           2.0
# AT1G49720                                           NaN
# AT5G42970                                           NaN
#
#            distance-from-source AT1G73000/ABA-receptors  \
# AT4G04020                                           NaN
# AT5G14250                                           NaN
# AT1G45249                                           2.0
# AT1G49720                                           NaN
# AT5G42970                                           NaN
#
#            distance-from-source AT1G01360/ABA-receptors
# AT4G04020                                           NaN
# AT5G14250                                           NaN
# AT1G45249                                           2.0
# AT1G49720                                           NaN
# AT5G42970                                           NaN
#
# [5 rows x 26 columns]
# SA
#                 node_type species       TAIR short_name  \
# AT4G26560  protein_coding     ath  AT4G26560       CBL7
# AT3G15210  protein_coding     ath  AT3G15210       ERF4
# AT2G41070  protein_coding     ath  AT2G41070      DPBF4
# AT1G27730  protein_coding     ath  AT1G27730        STZ
# AT5G45110  protein_coding     ath  AT5G45110       NPR3
#
#                                                     synonyms  \
# AT4G26560  [(SOS3-LIKE CALCIUM BINDING PROTEIN 3, CBL7, S...
# AT3G15210  [ETHYLENE RESPONSIVE ELEMENT BINDING FACTOR 4,...
# AT2G41070          [ATBZIP12, ENHANCED EM LEVEL, DPBF4, EEL]
# AT1G27730           [STZ, ZAT10, salt tolerance zinc finger]
# AT5G45110                [NPR1-like protein 3, NPR3, ATNPR3]
#
#                                               full_name  \
# AT4G26560                  calcineurin B-like protein 7
# AT3G15210  ethylene responsive element binding factor 4
# AT2G41070                             ENHANCED EM LEVEL
# AT1G27730                    salt tolerance zinc finger
# AT5G45110                           NPR1-like protein 3
#
#                                                          GMM  note  \
# AT4G26560                          [30.3_signalling.calcium]   NaN
# AT3G15210  [17.5.2_hormone metabolism.ethylene.signal tra...   NaN
# AT2G41070  [27.3.35_RNA.regulation of transcription.bZIP ...   NaN
# AT1G27730  [19.1_tetrapyrrole synthesis.glu-tRNA syntheta...   NaN
# AT5G45110                           [31.1_cell.organisation]   NaN
#
#            distance-to-RD29  in-degree  ...  source JA-receptors  \
# AT4G26560                 3          2  ...                  NaN
# AT3G15210                 4          4  ...                  NaN
# AT2G41070                 3          5  ...                  NaN
# AT1G27730                 1          1  ...                  NaN
# AT5G45110                 4          6  ...                  NaN
#
#            distance-from-source AT1G64280/SA-receptors  \
# AT4G26560                                          NaN
# AT3G15210                                          2.0
# AT2G41070                                          NaN
# AT1G27730                                          2.0
# AT5G45110                                          NaN
#
#            distance-from-source AT4G19660/SA-receptors  \
# AT4G26560                                          NaN
# AT3G15210                                          3.0
# AT2G41070                                          NaN
# AT1G27730                                          3.0
# AT5G45110                                          NaN
#
#            distance-from-source AT5G53160/ABA-receptors source ABA-receptors  \
# AT4G26560                                           NaN                  NaN
# AT3G15210                                           NaN                  NaN
# AT2G41070                                           NaN                  NaN
# AT1G27730                                           NaN                 True
# AT5G45110                                           NaN                  NaN
#
#            distance-from-source AT4G17870/ABA-receptors  \
# AT4G26560                                           NaN
# AT3G15210                                           NaN
# AT2G41070                                           NaN
# AT1G27730                                           NaN
# AT5G45110                                           NaN
#
#           distance-from-source AT5G46790/ABA-receptors  \
# AT4G26560                                          NaN
# AT3G15210                                          NaN
# AT2G41070                                          NaN
# AT1G27730                                          NaN
# AT5G45110                                          NaN
#
#            distance-from-source AT2G26040/ABA-receptors  \
# AT4G26560                                           NaN
# AT3G15210                                           NaN
# AT2G41070                                           NaN
# AT1G27730                                           NaN
# AT5G45110                                           NaN
#
#            distance-from-source AT1G73000/ABA-receptors  \
# AT4G26560                                           NaN
# AT3G15210                                           NaN
# AT2G41070                                           NaN
# AT1G27730                                           NaN
# AT5G45110                                           NaN
#
#            distance-from-source AT1G01360/ABA-receptors
# AT4G26560                                           NaN
# AT3G15210                                           NaN
# AT2G41070                                           NaN
# AT1G27730                                           2.0
# AT5G45110                                           NaN
#
# [5 rows x 26 columns]

# %%
# x.to_csv("node-attributes-on-path.tsv", sep="\t")

# %%
# !wc -l node-attributes-on-path.tsv
# Out:
# 81 node-attributes-on-path.tsv

# %% [markdown]
# # Cytoscape

# %% [markdown]
# Load the required library, and make sure you can connect to Cytoscape.
#
# More py4cytoscape documentation is here: https://py4cytoscape.readthedocs.io/

# %%
import py4cytoscape as p4c
p4c.cytoscape_version_info()
# Out:
# {'apiVersion': 'v1',
#  'cytoscapeVersion': '3.10.0',
#  'automationAPIVersion': '1.9.0',
#  'py4cytoscapeVersion': '1.9.0'}

# %%
from skm_tools import cytoscape_utils

# %% [markdown]
# We set the Cytoscape collection name for this notebook.

# %%
COLLECTION = f"Case 1: CKN ranks {'|'.join([str(i) for i in keep_edge_ranks])} ({today})"
COLLECTION
# Out:
# 'Case 1: CKN ranks 0|1|2 (2023.08.18)'

# %% [markdown]
# Generate the basis subnetwork from CKN using all the nodes across all the paths we identified.

# %% [markdown]
# ## Case study complete context

# %%
# all_nodes = list(set.union(aba_rd29_paths_nodes, ja_aba_rd29_paths_nodes, sa_aba_rd29_paths_nodes))
# len(all_nodes)

# %%
# paths_subgraph = nx.DiGraph(nx.induced_subgraph(g, nbunch=all_nodes))

# %%
# print(f"\nNumber of nodes: {paths_subgraph.number_of_nodes()}\nNumber of edges: {paths_subgraph.number_of_edges()}")

# %% [markdown]
# We create the network in Cytoscpe using p4c from networkx, and apply the skm-tools default style for CKN.

# %%
context_graph_node_suid = p4c.networks.create_network_from_networkx(
    all_nodes_graph, 
    title=f"CKN merged paths (node induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}", 
    collection=COLLECTION
)
cytoscape_utils.apply_builtin_style(context_graph_node_suid, 'ckn')
# p4c.layout_network("cose", network=ckn_network_suid)
context_graph_node_suid
# Out:
# Applying default style...
# Applying preferred layout
# Applied CKN-default to 1910716
# 1910716

# %%
# ckn_network_suid = p4c.networks.create_network_from_networkx(context_graph, title="CKN - complete case study subnetwork", collection=COLLECTION)
# cytoscape_utils.apply_builtin_style(ckn_network_suid, 'ckn')
# p4c.layout_network("cose", network=ckn_network_suid)
# ckn_network_suid
# Out:
# Applying default style...
# Applying preferred layout
# Applied CKN-default to 398050
# 398050

# %% [markdown]
# Now we highlight the source and target nodes, by changin their border colour and making them larger.

# %%
# sources (receptors)
cytoscape_utils.highlight_nodes(
    list(source_receptors["source_id"]),
    border_color="red",
    border_width=18,
    node_height=100,
    node_width=100,
    network=context_graph_node_suid
)

# target (RD29)
cytoscape_utils.highlight_nodes(
    [rd29],
    border_color="blue",
    border_width=18,
    node_height=100,
    node_width=100,
    network=context_graph_node_suid
)

# %% [markdown]
# The skm_tools module has a function to restyle the network using the paths we identified, to show how far each node is from the target,
# and which edge is on which path (in order of priority).
#
# May take a while.

# %%
cytoscape_utils.apply_shortest_paths_style(
    sources=['ABA', 'JA', 'SA'], 
    path_lists=[
        [p for sp in aba_rd29_paths.values() for p in sp],
        [p for sp in ja_aba_rd29_paths.values() for p in sp],
        [p for sp in sa_aba_rd29_paths.values() for p in sp]
    ],
    target=rd29,
    g=ckn,
    edge_colors=['#DC1C1C', '#66A61E', '#34858D'],
    node_colors=['#FDE725', '#21918C', '#440154'],
    network=context_graph_node_suid
)

# %% [markdown]
# ## ABA --> RD29
#
# Now we extract the individual subnetworks results as well

# %%
aba_rd29_graph_edge_induced = cytoscape_utils.subnetwork_edge_induced_from_paths(
    [p1 for p in aba_rd29_paths.values() for p1 in p], 
    ckn, 
    context_graph_node_suid,
    name=f"ABA --> RD29  (edge induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)

# %% [markdown]
# Before running the next cell, for bettter layouts, go to Cytoscape manually, and use the "yfiles hierachic layout"

# %%
aba_rd29_graph_node_induced = cytoscape_utils.subnetwork_node_induced(
    aba_rd29_paths_nodes, 
    context_graph_node_suid,
    name=f"ABA --> RD29  (node induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)
p4c.layout_copycat(aba_rd29_graph_edge_induced, aba_rd29_graph_node_induced)
# Out:
# {'mappedNodeCount': 17, 'unmappedNodeCount': 0}

# %% [markdown]
# ## JA -(ABA)-> RD29

# %%
ja_aba_rd29_graph_edge_induced = cytoscape_utils.subnetwork_edge_induced_from_paths(
    [p1 for p in ja_aba_rd29_paths.values() for p1 in p] + [p1 for p in aba_rd29_paths.values() for p1 in p], 
    ckn, 
    context_graph_node_suid,
    name=f"JA -- (ABA) --> RD29  (edge induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)

# %% [markdown]
# Before running the next cell, for bettter layouts, go to Cytoscape manually, and use the "yfiles hierachic layout"

# %%
ja_aba_rd29_graph_node_induced = cytoscape_utils.subnetwork_node_induced(
    ja_aba_rd29_paths_nodes.union(aba_rd29_paths_nodes),
    context_graph_node_suid,
    name=f"JA -- (ABA) --> RD29  (node induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)
p4c.layout_copycat(ja_aba_rd29_graph_edge_induced, ja_aba_rd29_graph_node_induced)
# Out:
# {'mappedNodeCount': 42, 'unmappedNodeCount': 0}

# %% [markdown]
# ## SA -(ABA)-> RD29

# %%
sa_aba_rd29_graph_edge_induced = cytoscape_utils.subnetwork_edge_induced_from_paths(
    [p1 for p in sa_aba_rd29_paths.values() for p1 in p] + [p1 for p in aba_rd29_paths.values() for p1 in p],
    ckn, 
    context_graph_node_suid,
    name=f"SA -- (ABA) --> RD29  (edge induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)

# %% [markdown]
# Before running the next cell, for bettter layouts, go to Cytoscape manually, and use the "yfiles hierachic layout"

# %%
sa_aba_rd29_graph_node_induced = cytoscape_utils.subnetwork_node_induced(
    sa_aba_rd29_paths_nodes.union(aba_rd29_paths_nodes),
    context_graph_node_suid,
    name=f"SA -- (ABA) --> RD29  (node induced) ranks {'|'.join([str(i) for i in keep_edge_ranks])}"
)
p4c.layout_copycat(sa_aba_rd29_graph_edge_induced, sa_aba_rd29_graph_node_induced)
# Out:
# {'mappedNodeCount': 116, 'unmappedNodeCount': 0}

# %% [markdown]
# ## Export networks to PDF

# %%
collection_suid = p4c.collections.get_collection_suid()
collection_name = p4c.collections.get_collection_name(collection_suid)
collection_pdf = output_dir / f"{re.sub('[^a-zA-Z0-9]+', '_', collection_name).strip('_')}.pdf"

# %%
cytoscape_utils.export_collection_to_pdf(collection_suid,  collection_pdf)
# Out:
# 1910716 CKN merged paths (node induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1916504 ABA --> RD29  (edge induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1916793 ABA --> RD29  (node induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1917214 JA -- (ABA) --> RD29  (edge induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1917802 JA -- (ABA) --> RD29  (node induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1918993 SA -- (ABA) --> RD29  (edge induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# 1920540 SA -- (ABA) --> RD29  (node induced) ranks 0|1|2
# Warning: use of resolution=, units=, height= and width= parameters for export_image() is deprecated
# Collection save to output/Case_1_CKN_ranks_0_1_2_2023_08_18.pdf

# %%
# END
